# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import json

# %%
# Load data
df = pd.read_csv('../Output/City_latlng_merge.csv')  # Ensure your CSV has 'latitude' and 'longitude' columns
df
# Out:
#        Unnamed: 0  SIGHTING_ID OCCURRED_DATE           CITY STATE COUNTRY  \
# 0               0            1    2024-06-20       Cranston    RI     USA
# 1              14            2    2024-06-20       Key West    FL     USA
# 2           47463            3    2024-06-20  Oklahoma City    OK     USA
# 3              94            4    2024-06-19  Valley Stream    NY     USA
# 4             101            5    2024-06-19   Jacksonville    FL     USA
# ...           ...          ...           ...            ...   ...     ...
# 44924       34650        50221    2014-02-18         Tucson    AZ     USA
# 44925        9338        50219    2014-02-18        Houston    TX     USA
# 44926       24507        50222    2014-02-18      Fallbrook    CA     USA
# 44927       22963        50223    2014-02-18       Chandler    IN     USA
# 44928       63253        50226    2014-02-18      Lame Deer    MT     USA
#
#           SHAPE                                            SUMMARY  YEAR  \
# ...

# %%
# Create GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=[Point(xy) for xy in zip(df['Lng'], df['Lat'])],
    crs='EPSG:4326'  # EPSG:4326 is the coordinate reference system for WGS84
)
gdf
# Out:
#        Unnamed: 0  SIGHTING_ID OCCURRED_DATE           CITY STATE COUNTRY  \
# 0               0            1    2024-06-20       Cranston    RI     USA
# 1              14            2    2024-06-20       Key West    FL     USA
# 2           47463            3    2024-06-20  Oklahoma City    OK     USA
# 3              94            4    2024-06-19  Valley Stream    NY     USA
# 4             101            5    2024-06-19   Jacksonville    FL     USA
# ...           ...          ...           ...            ...   ...     ...
# 44924       34650        50221    2014-02-18         Tucson    AZ     USA
# 44925        9338        50219    2014-02-18        Houston    TX     USA
# 44926       24507        50222    2014-02-18      Fallbrook    CA     USA
# 44927       22963        50223    2014-02-18       Chandler    IN     USA
# 44928       63253        50226    2014-02-18      Lame Deer    MT     USA
#
#           SHAPE                                            SUMMARY  YEAR  \
# ...

# %%
# Output to GeoJSON
geojson = gdf.to_json()

# %%
# Pretty-print the GeoJSON
geojson_pretty = json.dumps(json.loads(geojson), indent=4)

# %%
# Save to file
with open('../Output/sightings_pretty.geojson', 'w') as f:
    f.write(geojson_pretty)

print("GeoJSON data has been pretty-printed and saved to '../Output/sightings_pretty.geojson'")
# Out:
# GeoJSON data has been pretty-printed and saved to '../Output/sightings_pretty.geojson'
