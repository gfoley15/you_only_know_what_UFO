# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time
import warnings

# Impor the OpenWeatherMap API key
from api_keys import api_key

# %%
# Example API URL
# http://api.openweathermap.org/geo/1.0/direct?q={city_name},{state_code},{country_code}&limit={limit}&appid={API key}

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/geo/1.0/direct?"

# Building test API URL
city_name = "Kansas City"
state_code = "MO"
country_code = "US"
url = f"{base_url}q={city_name},{state_code},{country_code}&appid={api_key}"
url

# %%
# Testing API response
response = requests.get(url, verify=False)
print(response)

# %%
# Get test city weather data from Kansas City to see JSON
test_data = response.json()
test_data

# %%
# Gather variables from Kansas City test data in preparation to be used in Cities For loop
test_name = test_data[0]['name']
test_lat = test_data[0]['lat']
test_lng = test_data[0]['lon']

# %%
print(test_name)
print(test_lat)
print(test_lng)

# %%
usa_sightings_df = pd.read_csv('../Output/usa_sightings_df_.csv')

# %%
usa_sightings_df = pd.DataFrame(usa_sightings_df)

# %%
usa_cities_df = usa_sightings_df.drop_duplicates(subset=['CITY'])
usa_cities_df.reset_index(inplace=True)
usa_cities_df.head(10)
# Out:
#    index  SIGHTING_ID OCCURRED_DATE           CITY STATE COUNTRY     SHAPE  \
# 0      0            1    2024-06-20       Cranston    RI     USA     Flash
# 1      1            2    2024-06-20       Key West    FL     USA     Light
# 2      2            3    2024-06-20  Oklahoma City    OK     USA     Light
# 3      3            4    2024-06-19  Valley Stream    NY     USA    Sphere
# 4      4            5    2024-06-19   Jacksonville    FL     USA  Triangle
# 5      5            6    2024-06-18   Lawrenceburg    KY     USA  Triangle
# 6      6            7    2024-06-18        Leawood    KS     USA    Circle
# 7      7            8    2024-06-18     Washington    DC     USA    Circle
# 8      8            9    2024-06-18   Lee's Summit    MO     USA      Oval
# 9      9           10    2024-06-18        Yardley    PA     USA     Other
#
#                                              SUMMARY    YEAR  \
# 0  My wife and I as well as our 2 children witnes...  2024.0
# 1  Saw unexplainable lights slightly west of Nort...  2024.0
# 2          Erratically moving light at high altitude  2024.0
# 3  Sphere in the sky that glowed like an LED ligh...  2024.0
# 4                   Black triangle very low no noise  2024.0
# 5  Triangular UFO with white, red, maybe blue lig...  2024.0
# 6  Initially seen by naked eye, but slowly elevat...  2024.0
# 7                        Round silver shining object  2024.0
# 8  Two Lights in Lee's Summit, MO SW Sky, One Dis...  2024.0
# 9  Saw black object appear, no noise guessing 500...  2024.0
#
#            CITYSTATE
# 0       Cranston, RI
# 1       Key West, FL
# 2  Oklahoma City, OK
# 3  Valley Stream, NY
# 4   Jacksonville, FL
# 5   Lawrenceburg, KY
# 6        Leawood, KS
# 7     Washington, DC
# 8   Lee's Summit, MO
# 9        Yardley, PA

# %%
len(usa_cities_df)
# Out:
# 12061

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/geo/1.0/direct?"

# %%
city_data = []

# %%
# Iterate over each city in the DataFrame
for index in range(10000, len(usa_cities_df)):
    if index not in usa_cities_df.index:
        print(f"Index {index} not found in usa_cities_df. Skipping...")
        continue
    
    city_name = usa_cities_df.loc[index, 'CITY']
    state_code = usa_cities_df.loc[index, 'STATE']
    country_code = "US"
    
    # Construct the API request URL
    city_url = f"{base_url}q={city_name},{state_code},{country_code}&appid={api_key}"
    
    print(f"Fetching data for: {city_name}, {state_code}")
    try:
        # Make the API request
        req = requests.get(city_url, verify=False)
        req.raise_for_status() 
        city_info = req.json()[0] 
        
        # Extract relevant data
        city_lat = city_info['lat']
        city_lng = city_info['lon']
        city_name = city_info['name'] 
        
        # Append the city information into city_data list
        city_data.append({"City": city_name, 
                          "Lat": city_lat, 
                          "Lng": city_lng
                          })
        
        print(f"Data retrieved successfully for: {city_name}, {state_code}")

    except (KeyError, requests.exceptions.RequestException) as e:
        # Handle KeyError (for missing keys in city_info) and RequestException (for API request failures)
        print(f"Error fetching data for: {city_name}, {state_code}")
        print(e)
        continue  # Skip to the next iteration if there's an error 
    
    except IndexError as e:
        # Handle IndexError (for cases where req.json()[0] doesn't exist)
        print(f"No data found in API response for: {city_name}, {state_code}")
        print(e)
        continue  # Skip to the next iteration if there's an error
        
    time.sleep(4)

# Print completion message
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Fetching data for: Channel Islands Point Magu, CA
# No data found in API response for: Channel Islands Point Magu, CA
# list index out of range
# Fetching data for: Detour Village, MI
# Data retrieved successfully for: DeTour Village, MI
# Fetching data for: Vancouver & Portland, OR
# Data retrieved successfully for: Vancouver, OR
# Fetching data for: South Elgin, IL
# Data retrieved successfully for: South Elgin, IL
# Fetching data for: Hometown, IL
# Data retrieved successfully for: Hometown, IL
# Fetching data for: Jacobus, PA
# Data retrieved successfully for: Jacobus, PA
# Fetching data for: Wingdale, NY
# Data retrieved successfully for: Wingdale, NY
# Fetching data for: Milbury, MA
# Data retrieved successfully for: Milbury, MA
# Fetching data for: Rootstown, OH
# Data retrieved successfully for: Rootstown, OH
# Fetching data for: Dyersville, IA
# Data retrieved successfully for: Dyersville, IA
# Fetching data for: Michigan (Central Upper), MI
# No data found in API response for: Michigan (Central Upper), MI
# list index out of range
# Fetching data for: Pequea, PA
# Data retrieved successfully for: Pequea, PA
# Fetching data for: Lisman, AL
# Data retrieved successfully for: Lisman, AL
# Fetching data for: Kawaihae, HI
# Data retrieved successfully for: Kawaihae, HI
# Fetching data for: Lively Grove, IL
# Data retrieved successfully for: Lively Grove, IL
# Fetching data for: Kings Canyon National Parks, CA
# No data found in API response for: Kings Canyon National Parks, CA
# list index out of range
# Fetching data for: White Center, WA
# Data retrieved successfully for: White Center, WA
# Fetching data for: Schererville, IN
# Data retrieved successfully for: Schererville, IN
# Fetching data for: Northwest Medford, OR
# No data found in API response for: Northwest Medford, OR
# list index out of range
# Fetching data for: placitas, NM
# Data retrieved successfully for: Placitas, NM
# Fetching data for: Mount Laguna, CA
# Data retrieved successfully for: Mount Laguna, CA
# Fetching data for: Kerhonkson, NY
# Data retrieved successfully for: Kerhonkson, NY
# Fetching data for: Chicago (Lake Shafer), IN
# No data found in API response for: Chicago (Lake Shafer), IN
# list index out of range
# Fetching data for: Shavertown, PA
# Data retrieved successfully for: Shavertown, PA
# Fetching data for: Symsonia, KY
# Data retrieved successfully for: Symsonia, KY
# Fetching data for: New Egypt, NJ
# Data retrieved successfully for: New Egypt, NJ
# Fetching data for: Palomar Mountain, CA
# Data retrieved successfully for: Palomar Mountain, CA
# Fetching data for: Swartz Creek, MI
# Data retrieved successfully for: Swartz Creek, MI
# Fetching data for: Zelienople, PA
# Data retrieved successfully for: Zelienople, PA
# Fetching data for: Plainwell, MI
# Data retrieved successfully for: Plainwell, MI
# Fetching data for: Kingston Springs, TN
# Data retrieved successfully for: Kingston Springs, TN
# Fetching data for: Thompson Falls, MT
# Data retrieved successfully for: Thompson Falls, MT
# Fetching data for: Hollidaysburg, PA
# Data retrieved successfully for: Hollidaysburg, PA
# Fetching data for: Flowood, MS
# Data retrieved successfully for: Flowood, MS
# Fetching data for: Newton Falls, OH
# Data retrieved successfully for: Newton Falls, OH
# Fetching data for: Carol Stream, IL
# Data retrieved successfully for: Carol Stream, IL
# Fetching data for: East Oroville, CA
# No data found in API response for: East Oroville, CA
# list index out of range
# Fetching data for: Cataula, GA
# Data retrieved successfully for: Cataula, GA
# Fetching data for: Throop, PA
# Data retrieved successfully for: Throop, PA
# Fetching data for: Bruneau, ID
# Data retrieved successfully for: Bruneau, ID
# Fetching data for: Mount Sinai, NY
# Data retrieved successfully for: Mount Sinai, NY
# Fetching data for: Bogie Sound (Emerald Isle Bridge), NC
# No data found in API response for: Bogie Sound (Emerald Isle Bridge), NC
# list index out of range
# Fetching data for: Idaho City (10.6 miles NW), ID
# No data found in API response for: Idaho City (10.6 miles NW), ID
# list index out of range
# Fetching data for: Barber, OK
# Data retrieved successfully for: Barber, OK
# Fetching data for: Monaca, PA
# Data retrieved successfully for: Monaca, PA
# Fetching data for: Gold Beach, OR
# Data retrieved successfully for: Gold Beach, OR
# Fetching data for: South Barrington, IL
# Data retrieved successfully for: South Barrington, IL
# Fetching data for: Lake Vermilion (near tower), MN
# No data found in API response for: Lake Vermilion (near tower), MN
# list index out of range
# Fetching data for: Rodeo, NM
# Data retrieved successfully for: Rodeo, NM
# Fetching data for: Paige, TX
# Data retrieved successfully for: Paige, TX
# Fetching data for: Cornelia, GA
# Data retrieved successfully for: Cornelia, GA
# Fetching data for: Box Elder, SD
# Data retrieved successfully for: Box Elder, SD
# Fetching data for: Pretty Prairie, KS
# Data retrieved successfully for: Pretty Prairie, KS
# Fetching data for: Bristol tn and bristol va, TN
# No data found in API response for: Bristol tn and bristol va, TN
# list index out of range
# Fetching data for: Eastern Oregon farmland baker valley, OR
# No data found in API response for: Eastern Oregon farmland baker valley, OR
# list index out of range
# Fetching data for: Willisburg, KY
# Data retrieved successfully for: Willisburg, KY
# Fetching data for: Hebe/Klingerstown, PA
# No data found in API response for: Hebe/Klingerstown, PA
# list index out of range
# Fetching data for: Lower Makefield, PA
# Data retrieved successfully for: Lower Makefield Township, PA
# Fetching data for: Front Royal, VA
# Data retrieved successfully for: Front Royal, VA
# Fetching data for: Coffman Cove, AK
# Data retrieved successfully for: Coffman Cove, AK
# Fetching data for: Indian Rock Beach, FL
# No data found in API response for: Indian Rock Beach, FL
# list index out of range
# Fetching data for: West Bangor, PA
# Data retrieved successfully for: West Bangor, PA
# Fetching data for: Fredenberg Township, MN
# Data retrieved successfully for: Fredenberg Township, MN
# Fetching data for: De Tour Village, MI
# Data retrieved successfully for: DeTour Village, MI
# Fetching data for: Lucedale, MS
# Data retrieved successfully for: Lucedale, MS
# Fetching data for: Thomasville/Greensboro, NC
# No data found in API response for: Thomasville/Greensboro, NC
# list index out of range
# Fetching data for: Sentinel Butte, ND
# Data retrieved successfully for: Sentinel Butte, ND
# Fetching data for: Godfrey, IL
# Data retrieved successfully for: Godfrey, IL
# Fetching data for: Cedarcreek, MO
# Data retrieved successfully for: Cedarcreek, MO
# Fetching data for: Elkland, MO
# Data retrieved successfully for: Elkland, MO
# Fetching data for: Troy (NW of), MO
# No data found in API response for: Troy (NW of), MO
# list index out of range
# Fetching data for: Mohave Valley, AZ
# Data retrieved successfully for: Mohave Valley, AZ
# Fetching data for: Quaker Hill, CT
# Data retrieved successfully for: Quaker Hill, CT
# Fetching data for: Longmeadow, MA
# Data retrieved successfully for: Longmeadow, MA
# Fetching data for: Deer Trailer, CO
# No data found in API response for: Deer Trailer, CO
# list index out of range
# Fetching data for: North Hardeeville, SC
# No data found in API response for: North Hardeeville, SC
# list index out of range
# Fetching data for: Cliffdell, WA
# Data retrieved successfully for: Cliffdell, WA
# Fetching data for: Nappannee, IN
# No data found in API response for: Nappannee, IN
# list index out of range
# Fetching data for: Joshua Tree-Twenty Nine Palms, CA
# No data found in API response for: Joshua Tree-Twenty Nine Palms, CA
# list index out of range
# Fetching data for: Algonquin, IL
# Data retrieved successfully for: Algonquin, IL
# Fetching data for: West Greenwich, RI
# Data retrieved successfully for: West Greenwich, RI
# Fetching data for: De Funiak Springs, FL
# No data found in API response for: De Funiak Springs, FL
# list index out of range
# Fetching data for: Pittsburgh (near), PA
# No data found in API response for: Pittsburgh (near), PA
# list index out of range
# Fetching data for: Blue Island, IL
# Data retrieved successfully for: Blue Island, IL
# Fetching data for: North Syracuse, NY
# Data retrieved successfully for: Village of North Syracuse, NY
# Fetching data for: Braidwood, IL
# Data retrieved successfully for: Braidwood, IL
# Fetching data for: Shinnston, WV
# Data retrieved successfully for: Shinnston, WV
# Fetching data for: Miami (South Dade), FL
# No data found in API response for: Miami (South Dade), FL
# list index out of range
# Fetching data for: Montgomery village, MD
# Data retrieved successfully for: Montgomery Village, MD
# Fetching data for: Susquehanna, PA
# Data retrieved successfully for: Susquehanna Trails, PA
# Fetching data for: Gerber, CA
# Data retrieved successfully for: Gerber, CA
# Fetching data for: Sunny View, NC
# Data retrieved successfully for: Sunny View, NC
# Fetching data for: Los Angeles (Del Mar Beach), CA
# No data found in API response for: Los Angeles (Del Mar Beach), CA
# list index out of range
# Fetching data for: Pe Ell, WA
# Data retrieved successfully for: Pe Ell, WA
# Fetching data for: Eads, TN
# Data retrieved successfully for: Eads, TN
# Fetching data for: Sylvan Beach, NY
# Data retrieved successfully for: Village of Sylvan Beach, NY
# Fetching data for: Grand Coulee, WA
# Data retrieved successfully for: Grand Coulee, WA
# Fetching data for: Rosholt, WI
# Data retrieved successfully for: Rosholt, WI
# Fetching data for: Mineral Point, WI
# Data retrieved successfully for: Mineral Point, WI
# Fetching data for: Huntingtion, WV
# No data found in API response for: Huntingtion, WV
# list index out of range
# Fetching data for: Monroe County (Road "V"), WI
# No data found in API response for: Monroe County (Road "V"), WI
# list index out of range
# Fetching data for: Joshua Tree National Park, CA
# No data found in API response for: Joshua Tree National Park, CA
# list index out of range
# Fetching data for: Dorothy, NJ
# Data retrieved successfully for: Dorothy, NJ
# Fetching data for: Carrabassett Valley, ME
# Data retrieved successfully for: Carrabassett Valley, ME
# Fetching data for: Reynoldsville, PA
# Data retrieved successfully for: Reynoldsville, PA
# Fetching data for: Robins, IA
# Data retrieved successfully for: Robins, IA
# Fetching data for: Winston-Salem/Lexington, NC
# No data found in API response for: Winston-Salem/Lexington, NC
# list index out of range
# Fetching data for: Duck Key, FL
# Data retrieved successfully for: Duck Key, FL
# Fetching data for: Elsmere, DE
# Data retrieved successfully for: Elsmere, DE
# Fetching data for: soledad, CA
# Data retrieved successfully for: Soledad, CA
# Fetching data for: Minneapolis-Uptown, MN
# No data found in API response for: Minneapolis-Uptown, MN
# list index out of range
# Fetching data for: Valley springs, CA
# Data retrieved successfully for: Valley Springs, CA
# Fetching data for: East of Kingman (E of; rural), KS
# No data found in API response for: East of Kingman (E of; rural), KS
# list index out of range
# Fetching data for: Palm Beach Lakes, FL
# Data retrieved successfully for: Palm Beach Lakes, FL
# Fetching data for: McQuady, KY
# Data retrieved successfully for: McQuady, KY
# Fetching data for: Hertford, NC
# Data retrieved successfully for: Hertford, NC
# Fetching data for: Buffalo Grove, IL
# Data retrieved successfully for: Buffalo Grove, IL
# Fetching data for: McComb, MS
# Data retrieved successfully for: McComb, MS
# Fetching data for: Mize, MS
# Data retrieved successfully for: Mize, MS
# Fetching data for: Scanlon, MN
# Data retrieved successfully for: Scanlon, MN
# Fetching data for: New York Mills, MN
# Data retrieved successfully for: New York Mills, MN
# Fetching data for: Castiac, CA
# No data found in API response for: Castiac, CA
# list index out of range
# Fetching data for: Hart, MI
# Data retrieved successfully for: Hart, MI
# Fetching data for: Boomer, NC
# Data retrieved successfully for: Boomer, NC
# Fetching data for: Light, AR
# Data retrieved successfully for: Light, AR
# Fetching data for: South Myrtle Beach/ surfside beach, SC
# No data found in API response for: South Myrtle Beach/ surfside beach, SC
# list index out of range
# Fetching data for: Jarrell, TX
# Data retrieved successfully for: Jarrell, TX
# Fetching data for: Cherry  Grove (MCAS), SC
# No data found in API response for: Cherry  Grove (MCAS), SC
# list index out of range
# Fetching data for: Goosecreek, SC
# No data found in API response for: Goosecreek, SC
# list index out of range
# Fetching data for: Barstow (I-15 Fwy), CA
# No data found in API response for: Barstow (I-15 Fwy), CA
# list index out of range
# Fetching data for: Passaic, NJ
# Data retrieved successfully for: Passaic, NJ
# Fetching data for: Harpers Ferry, WV
# Data retrieved successfully for: Harpers Ferry, WV
# Fetching data for: Waleska, GA
# Data retrieved successfully for: Waleska, GA
# Fetching data for: Dederick, MO
# Data retrieved successfully for: Dederick, MO
# Fetching data for: Cibola County (SR 117, MM32), NM
# No data found in API response for: Cibola County (SR 117, MM32), NM
# list index out of range
# Fetching data for: Johns Creek/Atlanta, GA
# No data found in API response for: Johns Creek/Atlanta, GA
# list index out of range
# Fetching data for: Bethany (Route 1), DE
# No data found in API response for: Bethany (Route 1), DE
# list index out of range
# Fetching data for: El Segundo, CA
# Data retrieved successfully for: El Segundo, CA
# Fetching data for: Rothsay, MN
# Data retrieved successfully for: Rothsay, MN
# Fetching data for: Palos Verdes Estates, CA
# Data retrieved successfully for: Palos Verdes Estates, CA
# Fetching data for: E. Parsonsfield, ME
# Data retrieved successfully for: East Parsonsfield, ME
# Fetching data for: Wickenburg, AZ
# Data retrieved successfully for: Wickenburg, AZ
# Fetching data for: South Kingston, RI
# No data found in API response for: South Kingston, RI
# list index out of range
# Fetching data for: Pea Ridge, AR
# Data retrieved successfully for: Pea Ridge, AR
# Fetching data for: Lake Kiowa, TX
# Data retrieved successfully for: Lake Kiowa, TX
# Fetching data for: Lexa, AR
# Data retrieved successfully for: Lexa, AR
# Fetching data for: Millwood Community to the outskirts of Andrews, SC
# No data found in API response for: Millwood Community to the outskirts of Andrews, SC
# list index out of range
# Fetching data for: Lakehurst, NJ
# Data retrieved successfully for: Lakehurst, NJ
# Fetching data for: Lascar (I-25; MM 62), CO
# No data found in API response for: Lascar (I-25; MM 62), CO
# list index out of range
# Fetching data for: Corona (Queens), NY
# No data found in API response for: Corona (Queens), NY
# list index out of range
# Fetching data for: Luella, GA
# Data retrieved successfully for: Luella, GA
# Fetching data for: Brecksville, OH
# Data retrieved successfully for: Brecksville, OH
# Fetching data for: Tappan, NY
# Data retrieved successfully for: Tappan, NY
# Fetching data for: Earl Park, IN
# Data retrieved successfully for: Earl Park, IN
# Fetching data for: Lamberton, MN
# Data retrieved successfully for: Lamberton, MN
# Fetching data for: Summer Lake, OR
# Data retrieved successfully for: Summer Lake, OR
# Fetching data for: Fort Lauderdale Beach, FL
# No data found in API response for: Fort Lauderdale Beach, FL
# list index out of range
# Fetching data for: Mount Dora, FL
# Data retrieved successfully for: Mount Dora, FL
# Fetching data for: Renville, MN
# Data retrieved successfully for: Renville, MN
# Fetching data for: Millers Falls, MA
# Data retrieved successfully for: Millers Falls, MA
# Fetching data for: Priest River, ID
# Data retrieved successfully for: Priest River, ID
# Fetching data for: Krotz Springs, LA
# Data retrieved successfully for: Krotz Springs, LA
# Fetching data for: Red Cross, NC
# Data retrieved successfully for: Red Cross, NC
# Fetching data for: Branson ((possibly; unsure)), MO
# No data found in API response for: Branson ((possibly; unsure)), MO
# list index out of range
# Fetching data for: Hildale, UT
# Data retrieved successfully for: Hildale, UT
# Fetching data for: West Frankfort, IL
# Data retrieved successfully for: West Frankfort, IL
# Fetching data for: Dayton/Fairborn, OH
# No data found in API response for: Dayton/Fairborn, OH
# list index out of range
# Fetching data for: Wickieup, AZ
# No data found in API response for: Wickieup, AZ
# list index out of range
# Fetching data for: New York City (Yonkers), NY
# No data found in API response for: New York City (Yonkers), NY
# list index out of range
# Fetching data for: Shasta Lake, CA
# Data retrieved successfully for: Shasta Lake, CA
# Fetching data for: St. Helens, OR
# Data retrieved successfully for: Saint Helens, OR
# Fetching data for: Denver Metro, CO
# No data found in API response for: Denver Metro, CO
# list index out of range
# Fetching data for: Irondequoit, NY
# Data retrieved successfully for: Town of Irondequoit, NY
# Fetching data for: Lakside, MT
# No data found in API response for: Lakside, MT
# list index out of range
# Fetching data for: Wentzvillle, MO
# No data found in API response for: Wentzvillle, MO
# list index out of range
# Fetching data for: Gum Springs, AR
# Data retrieved successfully for: Gum Springs, AR
# Fetching data for: Chesterville, ME
# Data retrieved successfully for: Chesterville, ME
# Fetching data for: Pelican, AK
# Data retrieved successfully for: Pelican, AK
# Fetching data for: Kirkland/Kenmore, WA
# No data found in API response for: Kirkland/Kenmore, WA
# list index out of range
# Fetching data for: Lorenzo, TX
# Data retrieved successfully for: Lorenzo, TX
# Fetching data for: Voorhees, NJ
# Data retrieved successfully for: Voorhees Township, NJ
# Fetching data for: Lecanto, FL
# Data retrieved successfully for: Lecanto, FL
# Fetching data for: Meadow Creek, KY
# No data found in API response for: Meadow Creek, KY
# list index out of range
# Fetching data for: Byrdstown, TN
# Data retrieved successfully for: Byrdstown, TN
# Fetching data for: Placheville, LA
# No data found in API response for: Placheville, LA
# list index out of range
# Fetching data for: Wylie and Rowlett, TX
# No data found in API response for: Wylie and Rowlett, TX
# list index out of range
# Fetching data for: Eau Gallie, FL
# Data retrieved successfully for: Eau Gallie, FL
# Fetching data for: Franklin Furnace, OH
# Data retrieved successfully for: Franklin Furnace, OH
# Fetching data for: San Ysidro (Baja??), CA
# No data found in API response for: San Ysidro (Baja??), CA
# list index out of range
# Fetching data for: Forrest City, AR
# Data retrieved successfully for: Forrest City, AR
# Fetching data for: Nogal, NM
# Data retrieved successfully for: Nogal, NM
# Fetching data for: Lookout Mountain, GA
# Data retrieved successfully for: Lookout Mountain, GA
# Fetching data for: Saver, PA
# No data found in API response for: Saver, PA
# list index out of range
# Fetching data for: Plymouth Meeting, PA
# No data found in API response for: Plymouth Meeting, PA
# list index out of range
# Fetching data for: Omak, WA
# Data retrieved successfully for: Omak, WA
# Fetching data for: Irrigon, OR
# Data retrieved successfully for: Irrigon, OR
# Fetching data for: Los Fresnos, TX
# Data retrieved successfully for: Los Fresnos, TX
# Fetching data for: Washington, D.C. (above I-295 bridge), DC
# Data retrieved successfully for: Washington DC., DC
# Fetching data for: Mineral Springs, NC
# Data retrieved successfully for: Mineral Springs, NC
# Fetching data for: Ravena, NY
# Data retrieved successfully for: Village of Ravena, NY
# Fetching data for: Kotzebue, AK
# Data retrieved successfully for: Kotzebue, AK
# Fetching data for: Ft. Pierce, FL
# Data retrieved successfully for: Fort Pierce, FL
# Fetching data for: West Farmington, NM
# No data found in API response for: West Farmington, NM
# list index out of range
# Fetching data for: Stirling, NJ
# Data retrieved successfully for: Stirling, NJ
# Fetching data for: McHenrry, IL
# No data found in API response for: McHenrry, IL
# list index out of range
# Fetching data for: Ponce (Puerto Rico), PR
# No data found in API response for: Ponce (Puerto Rico), PR
# list index out of range
# Fetching data for: Biscoe, NC
# Data retrieved successfully for: Biscoe, NC
# Fetching data for: Long Prairie, MN
# Data retrieved successfully for: Long Prairie, MN
# Fetching data for: Ocklawaha, FL
# Data retrieved successfully for: Ocklawaha, FL
# Fetching data for: College Point (Queens), NY
# No data found in API response for: College Point (Queens), NY
# list index out of range
# Fetching data for: Gage (I-10, Exit 67), NM
# No data found in API response for: Gage (I-10, Exit 67), NM
# list index out of range
# Fetching data for: Pasco County, FL
# No data found in API response for: Pasco County, FL
# list index out of range
# Fetching data for: Kalaheo, HI
# Data retrieved successfully for: Kalaheo, HI
# Fetching data for: Baldwinville, MA
# Data retrieved successfully for: Baldwinville, MA
# Fetching data for: West Topsham, VT
# Data retrieved successfully for: West Topsham, VT
# Fetching data for: Scottsdale/Northwest Mesa, AZ
# No data found in API response for: Scottsdale/Northwest Mesa, AZ
# list index out of range
# Fetching data for: Wickieup (south of), AZ
# No data found in API response for: Wickieup (south of), AZ
# list index out of range
# Fetching data for: Stover, MO
# Data retrieved successfully for: Stover, MO
# Fetching data for: Luxora, AR
# Data retrieved successfully for: Luxora, AR
# Fetching data for: Battle Lake, MN
# Data retrieved successfully for: Battle Lake, MN
# Fetching data for: Waterbury (over), CT
# No data found in API response for: Waterbury (over), CT
# list index out of range
# Fetching data for: Bolivar, Hermitage, and Urbana, MO
# Data retrieved successfully for: Bolivar, MO
# Fetching data for: Harbor Beach, MI
# Data retrieved successfully for: Harbor Beach, MI
# Fetching data for: Salunga/Landisville area right by highway 283, PA
# No data found in API response for: Salunga/Landisville area right by highway 283, PA
# list index out of range
# Fetching data for: Rubidoux, CA
# Data retrieved successfully for: Rubidoux, CA
# Fetching data for: Charlotte (outside of; I-485), NC
# No data found in API response for: Charlotte (outside of; I-485), NC
# list index out of range
# Fetching data for: Levene, AZ
# No data found in API response for: Levene, AZ
# list index out of range
# Fetching data for: Ivy Bluff, TN
# Data retrieved successfully for: Ivy Bluff, TN
# Fetching data for: Pray/Livingston (between), MT
# No data found in API response for: Pray/Livingston (between), MT
# list index out of range
# Fetching data for: Rosiclare, IL
# Data retrieved successfully for: Rosiclare, IL
# Fetching data for: Plam Bay, FL
# No data found in API response for: Plam Bay, FL
# list index out of range
# Fetching data for: Lower Mount Bethel, PA
# Data retrieved successfully for: Lower Mount Bethel Township, PA
# Fetching data for: Sacaton, AZ
# Data retrieved successfully for: Sacaton, AZ
# Fetching data for: Cedar Hill/Burnsmill, MO
# No data found in API response for: Cedar Hill/Burnsmill, MO
# list index out of range
# Fetching data for: Johnson Creek (on outskirts of; on Hwy 94 east), WI
# No data found in API response for: Johnson Creek (on outskirts of; on Hwy 94 east), WI
# list index out of range
# Fetching data for: Clements, AL
# No data found in API response for: Clements, AL
# list index out of range
# Fetching data for: Sodaville, OR
# Data retrieved successfully for: Sodaville, OR
# Fetching data for: Copan, OK
# Data retrieved successfully for: Copan, OK
# Fetching data for: Wilkeson, WA
# Data retrieved successfully for: Wilkeson, WA
# Fetching data for: Colerain Township, OH
# Data retrieved successfully for: Colerain Township, OH
# Fetching data for: Tallapoosa, GA
# Data retrieved successfully for: Tallapoosa, GA
# Fetching data for: Estrella (west of Phoenix), AZ
# No data found in API response for: Estrella (west of Phoenix), AZ
# list index out of range
# Fetching data for: Churchville, PA
# Data retrieved successfully for: Churchville, PA
# Fetching data for: Hoffman, IL
# Data retrieved successfully for: Hoffman, IL
# Fetching data for: Gallatin (town of; Red Hook zip), NY
# No data found in API response for: Gallatin (town of; Red Hook zip), NY
# list index out of range
# Fetching data for: Miami (Suburbs), FL
# No data found in API response for: Miami (Suburbs), FL
# list index out of range
# Fetching data for: Spring Prairie, WI
# Data retrieved successfully for: Town of Spring Prairie, WI
# Fetching data for: Farmington/Helenville, WI
# No data found in API response for: Farmington/Helenville, WI
# list index out of range
# Fetching data for: Casa Grande (near), AZ
# No data found in API response for: Casa Grande (near), AZ
# list index out of range
# Fetching data for: Elberon, VA
# Data retrieved successfully for: Elberon, VA
# Fetching data for: Starview, PA
# Data retrieved successfully for: Starview, PA
# Fetching data for: Beacon Falls, CT
# Data retrieved successfully for: Beacon Falls, CT
# Fetching data for: Santa Fe (on ranch), CA
# No data found in API response for: Santa Fe (on ranch), CA
# list index out of range
# Fetching data for: Ran home Santa Fe, CA
# No data found in API response for: Ran home Santa Fe, CA
# list index out of range
# Fetching data for: Wheeler AAF, HI
# No data found in API response for: Wheeler AAF, HI
# list index out of range
# Fetching data for: Carpenteria, CA
# No data found in API response for: Carpenteria, CA
# list index out of range
# Fetching data for: West Mobile, AL
# No data found in API response for: West Mobile, AL
# list index out of range
# Fetching data for: Ojo Caliente, NM
# Data retrieved successfully for: Ojo Caliente, NM
# Fetching data for: La Junta, CO
# Data retrieved successfully for: La Junta, CO
# Fetching data for: Zion, IL
# Data retrieved successfully for: Zion, IL
# Fetching data for: Watchung, NJ
# Data retrieved successfully for: Watchung, NJ
# Fetching data for: Idanha, OR
# Data retrieved successfully for: Idanha, OR
# Fetching data for: Bean Station, TN
# Data retrieved successfully for: Bean Station, TN
# Fetching data for: Bothell/Kirkland, WA
# No data found in API response for: Bothell/Kirkland, WA
# list index out of range
# Fetching data for: Lebo, KS
# Data retrieved successfully for: Lebo, KS
# Fetching data for: Perrine, FL
# Data retrieved successfully for: Perrine, FL
# Fetching data for: Washington, D.C. & Baltimore (between; on I-295), MD
# Data retrieved successfully for: Washington, MD
# Fetching data for: Los Ranchos de Albuquerque, NM
# Data retrieved successfully for: Los Ranchos de Albuquerque, NM
# Fetching data for: Culpeper, VA
# Data retrieved successfully for: Culpeper, VA
# Fetching data for: Camp Lake, WI
# Data retrieved successfully for: Camp Lake, WI
# Fetching data for: Brian Head, UT
# Data retrieved successfully for: Brian Head, UT
# Fetching data for: Claysburg, PA
# Data retrieved successfully for: Claysburg, PA
# Fetching data for: Carefree, AZ
# Data retrieved successfully for: Carefree, AZ
# Fetching data for: Cooleemee, NC
# Data retrieved successfully for: Cooleemee, NC
# Fetching data for: Southmont, NC
# Data retrieved successfully for: Southmont, NC
# Fetching data for: Selkirk, NY
# Data retrieved successfully for: Selkirk, NY
# Fetching data for: Los Angeles (Venice Beach), CA
# No data found in API response for: Los Angeles (Venice Beach), CA
# list index out of range
# Fetching data for: Lupton City, TN
# Data retrieved successfully for: Lupton City, TN
# Fetching data for: Lake Ozark, MO
# Data retrieved successfully for: Lake Ozark, MO
# Fetching data for: Granite Bay, CA
# Data retrieved successfully for: Granite Bay, CA
# Fetching data for: Ten mile, TN
# Data retrieved successfully for: Ten Mile, TN
# Fetching data for: Emigrant Pass (near; foothills of), OR
# No data found in API response for: Emigrant Pass (near; foothills of), OR
# list index out of range
# Fetching data for: Naalehu, HI
# Data retrieved successfully for: Nāʻālehu, HI
# Fetching data for: Rover, TN
# Data retrieved successfully for: Rover, TN
# Fetching data for: Helenville, WI
# Data retrieved successfully for: Helenville, WI
# Fetching data for: Baltimore (West Hampden), MD
# No data found in API response for: Baltimore (West Hampden), MD
# list index out of range
# Fetching data for: Phoenix (Fort McDowell), AZ
# No data found in API response for: Phoenix (Fort McDowell), AZ
# list index out of range
# Fetching data for: Ayer/Harvard, MA
# No data found in API response for: Ayer/Harvard, MA
# list index out of range
# Fetching data for: Tome, NM
# Data retrieved successfully for: Tome, NM
# Fetching data for: Tempe/Phoenix, AZ
# No data found in API response for: Tempe/Phoenix, AZ
# list index out of range
# Fetching data for: La Luz, NM
# Data retrieved successfully for: La Luz, NM
# Fetching data for: Roswell/Ruidoso, NM
# No data found in API response for: Roswell/Ruidoso, NM
# list index out of range
# Fetching data for: Route 66 West (Exit 50), VA
# No data found in API response for: Route 66 West (Exit 50), VA
# list index out of range
# Fetching data for: Ten Mile to Knox, TN
# No data found in API response for: Ten Mile to Knox, TN
# list index out of range
# Fetching data for: Whitestone, NY
# Data retrieved successfully for: Whitestone, NY
# Fetching data for: Four Oaks, NC
# Data retrieved successfully for: Four Oaks, NC
# Fetching data for: Lakveville, MN
# No data found in API response for: Lakveville, MN
# list index out of range
# Fetching data for: Orting, WA
# Data retrieved successfully for: Orting, WA
# Fetching data for: Antinito, CO
# No data found in API response for: Antinito, CO
# list index out of range
# Fetching data for: Barre Town, VT
# Data retrieved successfully for: Barre Town, VT
# Fetching data for: Norwich/Thetford, VT
# No data found in API response for: Norwich/Thetford, VT
# list index out of range
# Fetching data for: Ivor, VA
# Data retrieved successfully for: Ivor, VA
# Fetching data for: Camby/Indianapolis, IN
# No data found in API response for: Camby/Indianapolis, IN
# list index out of range
# Fetching data for: Little Chute, WI
# Data retrieved successfully for: Little Chute, WI
# Fetching data for: Joppatown, MD
# No data found in API response for: Joppatown, MD
# list index out of range
# Fetching data for: Accord, NY
# Data retrieved successfully for: Accord, NY
# Fetching data for: Mineola, TX
# Data retrieved successfully for: Mineola, TX
# Fetching data for: Denvile, NJ
# No data found in API response for: Denvile, NJ
# list index out of range
# Fetching data for: Mill Spring, NC
# Data retrieved successfully for: Mill Spring, NC
# Fetching data for: Woodside, NY
# Data retrieved successfully for: Woodside, NY
# Fetching data for: Neskowin, OR
# Data retrieved successfully for: Neskowin, OR
# Fetching data for: Amery/Star Prairie, WI
# No data found in API response for: Amery/Star Prairie, WI
# list index out of range
# Fetching data for: Road, TX
# Data retrieved successfully for: North Depot Road Colonia, TX
# Fetching data for: Morganza, MD
# Data retrieved successfully for: Morganza, MD
# Fetching data for: I-495 North (driving on), MD
# No data found in API response for: I-495 North (driving on), MD
# list index out of range
# Fetching data for: Woodland Township, NJ
# Data retrieved successfully for: Woodland Township, NJ
# Fetching data for: Colorado Springs (east of), CO
# No data found in API response for: Colorado Springs (east of), CO
# list index out of range
# Fetching data for: Elk Grove Village, IL
# Data retrieved successfully for: Elk Grove Village, IL
# Fetching data for: Lafayette (14 mi. E of), LA
# No data found in API response for: Lafayette (14 mi. E of), LA
# list index out of range
# Fetching data for: Ivanhoe, NC
# Data retrieved successfully for: Ivanhoe, NC
# Fetching data for: Rifton, NY
# Data retrieved successfully for: Rifton, NY
# Fetching data for: Jarvisburg, NC
# Data retrieved successfully for: Jarvisburg, NC
# Fetching data for: Corona del Mar, CA
# Data retrieved successfully for: Corona del Mar, CA
# Fetching data for: Trout Valley, IL
# Data retrieved successfully for: Trout Valley, IL
# Fetching data for: Brodheadsville, PA
# Data retrieved successfully for: Brodheadsville, PA
# Fetching data for: North Riverside, IL
# Data retrieved successfully for: North Riverside, IL
# Fetching data for: Hereford Township, PA
# Data retrieved successfully for: Hereford Township, PA
# Fetching data for: Arlington/Marysville, WA
# No data found in API response for: Arlington/Marysville, WA
# list index out of range
# Fetching data for: Phenix city, AL
# Data retrieved successfully for: Phenix City, AL
# Fetching data for: Vassar, MI
# Data retrieved successfully for: Vassar, MI
# Fetching data for: Goliad, TX
# Data retrieved successfully for: Goliad, TX
# Fetching data for: Lordstown (near; on I-80), OH
# No data found in API response for: Lordstown (near; on I-80), OH
# list index out of range
# Fetching data for: Roberts County, SD
# No data found in API response for: Roberts County, SD
# list index out of range
# Fetching data for: Stanardsville, VA
# Data retrieved successfully for: Stanardsville, VA
# Fetching data for: North Shore, HI
# No data found in API response for: North Shore, HI
# list index out of range
# Fetching data for: New Blaine, AR
# Data retrieved successfully for: New Blaine, AR
# Fetching data for: Forest Acres, SC
# Data retrieved successfully for: Forest Acres, SC
# Fetching data for: Pound Ridge, NY
# Data retrieved successfully for: Town of Pound Ridge, NY
# Fetching data for: Black Canyon City, AZ
# Data retrieved successfully for: Black Canyon City, AZ
# Fetching data for: Branchland, WV
# Data retrieved successfully for: Branchland, WV
# Fetching data for: French Creek, WV
# Data retrieved successfully for: French Creek, WV
# Fetching data for: Avon/Eagle, CO
# No data found in API response for: Avon/Eagle, CO
# list index out of range
# Fetching data for: Wilkes-Barre/Hazleton (between), PA
# No data found in API response for: Wilkes-Barre/Hazleton (between), PA
# list index out of range
# Fetching data for: Harpersville, AL
# Data retrieved successfully for: Harpersville, AL
# Fetching data for: Hilldale, WV
# Data retrieved successfully for: Hilldale, WV
# Fetching data for: Glendale (La Crecenta, CA
# No data found in API response for: Glendale (La Crecenta, CA
# list index out of range
# Fetching data for: DeLuz/Temecula, CA
# No data found in API response for: DeLuz/Temecula, CA
# list index out of range
# Fetching data for: Campobello, SC
# Data retrieved successfully for: Campobello, SC
# Fetching data for: Upton/Millbury, MA
# No data found in API response for: Upton/Millbury, MA
# list index out of range
# Fetching data for: Sligo, PA
# Data retrieved successfully for: Sligo, PA
# Fetching data for: Tomahawk, WV
# Data retrieved successfully for: Tomahawk, WV
# Fetching data for: Plum, PA
# Data retrieved successfully for: Plum, PA
# Fetching data for: Wind Lake, WI
# Data retrieved successfully for: Wind Lake, WI
# Fetching data for: Toluca Lake, CA
# Data retrieved successfully for: Toluca Lake, CA
# Fetching data for: Mill Run, PA
# Data retrieved successfully for: Mill Run, PA
# Fetching data for: Moorpark, CA
# Data retrieved successfully for: Moorpark, CA
# Fetching data for: Sky Valley, CA
# Data retrieved successfully for: Sky Valley, CA
# Fetching data for: Harlansburgh, PA
# No data found in API response for: Harlansburgh, PA
# list index out of range
# Fetching data for: York Valley, AZ
# No data found in API response for: York Valley, AZ
# list index out of range
# Fetching data for: Attelboro, MA
# No data found in API response for: Attelboro, MA
# list index out of range
# Fetching data for: Surrey, ND
# Data retrieved successfully for: Surrey, ND
# Fetching data for: Arabi, GA
# Data retrieved successfully for: Arabi, GA
# Fetching data for: Port Isabel, TX
# Data retrieved successfully for: Port Isabel, TX
# Fetching data for: Pope, MS
# Data retrieved successfully for: Pope, MS
# Fetching data for: North Minneapolis, MN
# No data found in API response for: North Minneapolis, MN
# list index out of range
# Fetching data for: New Haven (Fair Haven/East Haven), CT
# No data found in API response for: New Haven (Fair Haven/East Haven), CT
# list index out of range
# Fetching data for: Larned, KS
# Data retrieved successfully for: Larned, KS
# Fetching data for: Fairgrove, MI
# Data retrieved successfully for: Fairgrove, MI
# Fetching data for: Robbinsville, NJ
# Data retrieved successfully for: Robbinsville Township, NJ
# Fetching data for: Otay Mesa, CA
# Data retrieved successfully for: Otay Mesa, CA
# Fetching data for: Penndel, PA
# Data retrieved successfully for: Penndel, PA
# Fetching data for: Mountatin Top, PA
# No data found in API response for: Mountatin Top, PA
# list index out of range
# Fetching data for: Russell Springs, KY
# Data retrieved successfully for: Russell Springs, KY
# Fetching data for: Milwaukee (north of), WI
# Data retrieved successfully for: Old North Milwaukee, WI
# Fetching data for: Dothan (general area), AL
# No data found in API response for: Dothan (general area), AL
# list index out of range
# Fetching data for: Oakland Township, MI
# Data retrieved successfully for: Oakland Charter Township, MI
# Fetching data for: East Los Angeles (Boyle Heights), CA
# No data found in API response for: East Los Angeles (Boyle Heights), CA
# list index out of range
# Fetching data for: Valley Falls, KS
# Data retrieved successfully for: Valley Falls, KS
# Fetching data for: Bluff City, TN
# Data retrieved successfully for: Bluff City, TN
# Fetching data for: Trumann, AR
# Data retrieved successfully for: Trumann, AR
# Fetching data for: Mount Ida, AR
# Data retrieved successfully for: Mount Ida, AR
# Fetching data for: Frenchtown (Monroe), MI
# No data found in API response for: Frenchtown (Monroe), MI
# list index out of range
# Fetching data for: New Bloomington, OH
# Data retrieved successfully for: New Bloomington, OH
# Fetching data for: Matanzas Inlet, FL
# No data found in API response for: Matanzas Inlet, FL
# list index out of range
# Fetching data for: Bexley, OH
# Data retrieved successfully for: Bexley, OH
# Fetching data for: Cowlington, OK
# Data retrieved successfully for: Cowlington, OK
# Fetching data for: Huntingdon Valley, PA
# Data retrieved successfully for: Huntingdon Valley, PA
# Fetching data for: Green Bay West, WI
# No data found in API response for: Green Bay West, WI
# list index out of range
# Fetching data for: Alanson, MI
# Data retrieved successfully for: Alanson, MI
# Fetching data for: Wilmington (?), NC
# Data retrieved successfully for: Wilmington, NC
# Fetching data for: Catawissa/Burnsville, MO
# No data found in API response for: Catawissa/Burnsville, MO
# list index out of range
# Fetching data for: Clare, MI
# Data retrieved successfully for: Clare, MI
# Fetching data for: Layton (south of), UT
# No data found in API response for: Layton (south of), UT
# list index out of range
# Fetching data for: Richmond (near), VA
# No data found in API response for: Richmond (near), VA
# list index out of range
# Fetching data for: Sea-Tac (to the south of??), WA
# No data found in API response for: Sea-Tac (to the south of??), WA
# list index out of range
# Fetching data for: Brownsville (on I-5 highway), OR
# Error fetching data for: Brownsville (on I-5 highway), OR
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Fetching data for: Continental Divide, NM
# Data retrieved successfully for: Continental Divide, NM
# Fetching data for: Ann Arbor MI, MI
# No data found in API response for: Ann Arbor MI, MI
# list index out of range
# Fetching data for: Pine River, WI
# Data retrieved successfully for: Town of Pine River, WI
# Fetching data for: Suquamish, WA
# Data retrieved successfully for: Port Madison Indian Reservation, WA
# Fetching data for: Capitol Heights, MD
# Data retrieved successfully for: Capitol Heights, MD
# Fetching data for: Eastsound, WA
# Data retrieved successfully for: Eastsound, WA
# Fetching data for: Moline, IL
# Data retrieved successfully for: Moline, IL
# Fetching data for: Dunes City, OR
# Data retrieved successfully for: Dunes City, OR
# Fetching data for: Loleta, CA
# Data retrieved successfully for: Loleta, CA
# Fetching data for: Ft. Myers Beach, FL
# Data retrieved successfully for: Fort Myers Beach, FL
# Fetching data for: Sears Point Raceway, CA
# No data found in API response for: Sears Point Raceway, CA
# list index out of range
# Fetching data for: Polson (north of), MT
# No data found in API response for: Polson (north of), MT
# list index out of range
# Fetching data for: Kenvil, NJ
# Data retrieved successfully for: Kenvil, NJ
# Fetching data for: Tuscarora Indian Reservation, NY
# No data found in API response for: Tuscarora Indian Reservation, NY
# list index out of range
# Fetching data for: Crestone, CO
# Data retrieved successfully for: Crestone, CO
# Fetching data for: Lucasville, OH
# Data retrieved successfully for: Lucasville, OH
# Fetching data for: Beaverdam, VA
# Data retrieved successfully for: Beaverdam, VA
# Fetching data for: burlington, KY
# Data retrieved successfully for: Burlington, KY
# Fetching data for: Vannuys, CA
# No data found in API response for: Vannuys, CA
# list index out of range
# Fetching data for: Indianapolis/Fishers, IN
# No data found in API response for: Indianapolis/Fishers, IN
# list index out of range
# Fetching data for: Salt Lake City (north of), UT
# No data found in API response for: Salt Lake City (north of), UT
# list index out of range
# Fetching data for: Gibsonville, NC
# Data retrieved successfully for: Gibsonville, NC
# Fetching data for: Somerset Center, MI
# Data retrieved successfully for: Somerset Center, MI
# Fetching data for: Glacier, WA
# Data retrieved successfully for: Glacier, WA
# Fetching data for: Brownfield, TX
# Data retrieved successfully for: Brownfield, TX
# Fetching data for: Windgap, PA
# Data retrieved successfully for: Windgap, PA
# Fetching data for: Flowermound, TX
# No data found in API response for: Flowermound, TX
# list index out of range
# Fetching data for: White sands missile range, NM
# No data found in API response for: White sands missile range, NM
# list index out of range
# Fetching data for: rockford, IL
# Data retrieved successfully for: Rockford, IL
# Fetching data for: west union, OH
# Data retrieved successfully for: West Union, OH
# Fetching data for: Bistib, MA
# No data found in API response for: Bistib, MA
# list index out of range
# Fetching data for: east of Lawton, OK
# No data found in API response for: east of Lawton, OK
# list index out of range
# Fetching data for: Soddy Daisy, TN
# Data retrieved successfully for: Soddy-Daisy, TN
# Fetching data for: Soddy Daisy/Hixson, TN
# No data found in API response for: Soddy Daisy/Hixson, TN
# list index out of range
# Fetching data for: Lolo, MT
# Data retrieved successfully for: Lolo, MT
# Fetching data for: Campton, NH
# Data retrieved successfully for: Campton, NH
# Fetching data for: Ocean Beach, CA
# Data retrieved successfully for: Ocean Beach, CA
# Fetching data for: Horseheads, NY
# Data retrieved successfully for: Village of Horseheads, NY
# Fetching data for: Harmonyville, PA
# Data retrieved successfully for: Harmonyville, PA
# Fetching data for: Marshallberg, NC
# Data retrieved successfully for: Marshallberg, NC
# Fetching data for: Ferguson Falls, MN
# No data found in API response for: Ferguson Falls, MN
# list index out of range
# Fetching data for: Wynanskill, NY
# No data found in API response for: Wynanskill, NY
# list index out of range
# Fetching data for: Lake In The Hills, IL
# Data retrieved successfully for: Lake in the Hills, IL
# Fetching data for: Palos Park, IL
# Data retrieved successfully for: Palos Park, IL
# Fetching data for: Dubre, KY
# Data retrieved successfully for: Dubre, KY
# Fetching data for: Cleveland (SE section), TN
# No data found in API response for: Cleveland (SE section), TN
# list index out of range
# Fetching data for: Vandiver, AL
# Data retrieved successfully for: Vandiver, AL
# Fetching data for: San Benito, TX
# Data retrieved successfully for: San Benito, TX
# Fetching data for: none, TX
# No data found in API response for: none, TX
# list index out of range
# Fetching data for: Brown County, Texas, TX
# No data found in API response for: Brown County, Texas, TX
# list index out of range
# Fetching data for: Centre, AL
# Data retrieved successfully for: Centre, AL
# Fetching data for: Hauppauge, NY
# Data retrieved successfully for: Hauppauge, NY
# Fetching data for: Gardiner/Pittston, ME
# No data found in API response for: Gardiner/Pittston, ME
# list index out of range
# Fetching data for: Scenic, AZ
# Data retrieved successfully for: Scenic, AZ
# Fetching data for: Rotterdam/Amsterdam, NY
# No data found in API response for: Rotterdam/Amsterdam, NY
# list index out of range
# Fetching data for: Panguitch, UT
# Data retrieved successfully for: Panguitch, UT
# Fetching data for: Corpus Christi (south of), TX
# No data found in API response for: Corpus Christi (south of), TX
# list index out of range
# Fetching data for: Swain, NY
# Data retrieved successfully for: Swain, NY
# Fetching data for: Rockvile, MD
# No data found in API response for: Rockvile, MD
# list index out of range
# Fetching data for: Abita Springs, LA
# Data retrieved successfully for: Abita Springs, LA
# Fetching data for: Tridelphia, WV
# No data found in API response for: Tridelphia, WV
# list index out of range
# Fetching data for: Walkertown (Johns Road), NC
# No data found in API response for: Walkertown (Johns Road), NC
# list index out of range
# Fetching data for: Trotwood/Englewood, OH
# No data found in API response for: Trotwood/Englewood, OH
# list index out of range
# Fetching data for: Tustin (viewed from), CA
# No data found in API response for: Tustin (viewed from), CA
# list index out of range
# Fetching data for: East Hemet, CA
# Data retrieved successfully for: East Hemet, CA
# Fetching data for: Cardiff by The Sea, CA
# Data retrieved successfully for: Cardiff-by-the-Sea, CA
# Fetching data for: Soledad, CA
# Data retrieved successfully for: Soledad, CA
# Fetching data for: Ozena, CA
# No data found in API response for: Ozena, CA
# list index out of range
# Fetching data for: Newberry Springs, CA
# Data retrieved successfully for: Newberry Springs, CA
# Fetching data for: Lomira, CA
# No data found in API response for: Lomira, CA
# list index out of range
# Fetching data for: San Diego (Mission Valley), CA
# No data found in API response for: San Diego (Mission Valley), CA
# list index out of range
# Fetching data for: Boyle Heights, CA
# Data retrieved successfully for: Boyle Heights, CA
# Fetching data for: Filmore, CA
# No data found in API response for: Filmore, CA
# list index out of range
# Fetching data for: San Diego/Mira Mesa, CA
# No data found in API response for: San Diego/Mira Mesa, CA
# list index out of range
# Fetching data for: Electra, TX
# Data retrieved successfully for: Electra, TX
# Fetching data for: Isla Vista, CA
# Data retrieved successfully for: Isla Vista, CA
# Fetching data for: Carmel Valley, CA
# Data retrieved successfully for: Carmel Valley, CA
# Fetching data for: Wilows, CA
# No data found in API response for: Wilows, CA
# list index out of range
# Fetching data for: Encintas, CA
# No data found in API response for: Encintas, CA
# list index out of range
# Fetching data for: Buellton (near), CA
# No data found in API response for: Buellton (near), CA
# list index out of range
# Fetching data for: Pie Town, NM
# Data retrieved successfully for: Pie Town, NM
# Fetching data for: South Phoenix/Laveen, AZ
# No data found in API response for: South Phoenix/Laveen, AZ
# list index out of range
# Fetching data for: All over, CA
# No data found in API response for: All over, CA
# list index out of range
# Fetching data for: Manoa Hills, HI
# No data found in API response for: Manoa Hills, HI
# list index out of range
# Fetching data for: East Irondequoit, NY
# No data found in API response for: East Irondequoit, NY
# list index out of range
# Fetching data for: Knights Landing, CA
# Data retrieved successfully for: Knights Landing, CA
# Fetching data for: Las Vegas/Summerlin, NV
# No data found in API response for: Las Vegas/Summerlin, NV
# list index out of range
# Fetching data for: Bay Area, CA
# Data retrieved successfully for: San Francisco Bay Area, CA
# Fetching data for: Long Beach/Los Angles, CA
# No data found in API response for: Long Beach/Los Angles, CA
# list index out of range
# Fetching data for: 29 Palms, CA
# Data retrieved successfully for: Twentynine Palms, CA
# Fetching data for: Mira Mesa, CA
# Data retrieved successfully for: Mira Mesa, CA
# Fetching data for: Manchester to Baltimore, MD, NH
# No data found in API response for: Manchester to Baltimore, MD, NH
# list index out of range
# Fetching data for: East Rutherford, NJ
# Data retrieved successfully for: East Rutherford, NJ
# Fetching data for: Elm City, NC
# Data retrieved successfully for: Elm City, NC
# Fetching data for: La Crescenta, CA
# Data retrieved successfully for: La Crescenta, CA
# Fetching data for: Hollis, ME
# Data retrieved successfully for: Hollis, ME
# Fetching data for: Menifeeca, CA
# No data found in API response for: Menifeeca, CA
# list index out of range
# Fetching data for: Appalachia, VA
# Data retrieved successfully for: Appalachia, VA
# Fetching data for: Paris-Winchester, KY
# No data found in API response for: Paris-Winchester, KY
# list index out of range
# ...
# Data retrieved successfully for: New Concord, OH
# Fetching data for: Seagrove Beach, FL
# Data retrieved successfully for: Seagrove Beach, FL
# Fetching data for: San Isidro, NM
# No data found in API response for: San Isidro, NM
# list index out of range
# Fetching data for: Mendon, MA
# Data retrieved successfully for: Mendon, MA
# Fetching data for: Cherryville/North Brook, NC
# No data found in API response for: Cherryville/North Brook, NC
# list index out of range
# Fetching data for: Schwenksville, PA
# Data retrieved successfully for: Schwenksville, PA
# Fetching data for: Waikiki Beach, HI
# No data found in API response for: Waikiki Beach, HI
# list index out of range
# Fetching data for: South Tamworth, NH
# Data retrieved successfully for: South Tamworth, NH
# Fetching data for: Accokeek, MD
# Data retrieved successfully for: Accokeek, MD
# Fetching data for: McNary, OR
# Data retrieved successfully for: McNary, OR
# Fetching data for: Belgreen, AL
# Data retrieved successfully for: Belgreen, AL
# Fetching data for: East Bend/Lewisville, NC
# No data found in API response for: East Bend/Lewisville, NC
# list index out of range
# Fetching data for: Iron Gate, VA
# Data retrieved successfully for: Iron Gate, VA
# Fetching data for: Portland (northeast area), OR
# No data found in API response for: Portland (northeast area), OR
# list index out of range
# Fetching data for: Lysander, NY
# Data retrieved successfully for: Town of Lysander, NY
# Fetching data for: West Paducah, KY
# Data retrieved successfully for: West Paducah, KY
# Fetching data for: White Bear Lake, MN
# Data retrieved successfully for: White Bear Lake, MN
# Fetching data for: Azuza, CA
# No data found in API response for: Azuza, CA
# list index out of range
# Fetching data for: Columia, KY
# No data found in API response for: Columia, KY
# list index out of range
# Fetching data for: Ahwatukee, AZ
# Data retrieved successfully for: Ahwatukee Foothills, AZ
# Fetching data for: Raceland, LA
# Data retrieved successfully for: Raceland, LA
# Fetching data for: Springlake, MI
# No data found in API response for: Springlake, MI
# list index out of range
# Fetching data for: Moss Bluff, LA
# Data retrieved successfully for: Moss Bluff, LA
# Fetching data for: Maud, TX
# Data retrieved successfully for: Maud, TX
# Fetching data for: Pantego, TX
# Data retrieved successfully for: Pantego, TX
# Fetching data for: Grandbay, AL
# No data found in API response for: Grandbay, AL
# list index out of range
# Fetching data for: Henderson/Las Vegas, NV
# No data found in API response for: Henderson/Las Vegas, NV
# list index out of range
# Fetching data for: Dauphin Island (off the coast of), AL
# No data found in API response for: Dauphin Island (off the coast of), AL
# list index out of range
# Fetching data for: Memphis (north of), TX
# No data found in API response for: Memphis (north of), TX
# list index out of range
# Fetching data for: Raywick, KY
# Data retrieved successfully for: Raywick, KY
# Fetching data for: Sam's Gap (Top of NC/TN Mountain), NC
# No data found in API response for: Sam's Gap (Top of NC/TN Mountain), NC
# list index out of range
# Fetching data for: San Rafael (near), NM
# No data found in API response for: San Rafael (near), NM
# list index out of range
# Fetching data for: Cajah's Mountain, NC
# Data retrieved successfully for: Cajah's Mountain, NC
# Fetching data for: Ft. Campbell, TN
# No data found in API response for: Ft. Campbell, TN
# list index out of range
# Fetching data for: Twilight, WV
# Data retrieved successfully for: Twilight, WV
# Fetching data for: Mount Pulaski, IL
# Data retrieved successfully for: Mount Pulaski, IL
# Fetching data for: Backus, MN
# Data retrieved successfully for: Backus, MN
# Fetching data for: North Atlanta, GA
# No data found in API response for: North Atlanta, GA
# list index out of range
# Fetching data for: Ozark (5 miles south of), MO
# No data found in API response for: Ozark (5 miles south of), MO
# list index out of range
# Fetching data for: Manhatten Beach, CA
# No data found in API response for: Manhatten Beach, CA
# list index out of range
# Fetching data for: New Glarus, WI
# Data retrieved successfully for: New Glarus, WI
# Fetching data for: Portage Lakes, OH
# Data retrieved successfully for: Portage Lakes, OH
# Fetching data for: Hillsborough Beach, FL
# No data found in API response for: Hillsborough Beach, FL
# list index out of range
# Fetching data for: Tieton, WA
# Data retrieved successfully for: Tieton, WA
# Fetching data for: Villa Ridge, MO
# Data retrieved successfully for: Villa Ridge, MO
# Fetching data for: Yellowstone North Entrance, WY
# No data found in API response for: Yellowstone North Entrance, WY
# list index out of range
# Fetching data for: Hallsville, OH
# Data retrieved successfully for: Hallsville, OH
# Fetching data for: Arizona/California border, CA
# No data found in API response for: Arizona/California border, CA
# list index out of range
# Fetching data for: Forbes Road, PA
# Data retrieved successfully for: Forbes Road, PA
# Fetching data for: Couer d'Alene, ID
# No data found in API response for: Couer d'Alene, ID
# list index out of range
# Fetching data for: Mollusk, VA
# Data retrieved successfully for: Mollusk, VA
# Fetching data for: Mexico (close to; on US 31), IN
# No data found in API response for: Mexico (close to; on US 31), IN
# list index out of range
# Fetching data for: Location unspecified by witness, GA
# No data found in API response for: Location unspecified by witness, GA
# list index out of range
# Fetching data for: Blue Bell, PA
# Data retrieved successfully for: Blue Bell, PA
# Fetching data for: Lordsburg, NM
# Data retrieved successfully for: Lordsburg, NM
# Fetching data for: Sylva, NC
# Data retrieved successfully for: Sylva, NC
# Fetching data for: Ashe Fork, NV
# No data found in API response for: Ashe Fork, NV
# list index out of range
# Fetching data for: Lenwood, CA
# Data retrieved successfully for: Lenwood, CA
# Fetching data for: Conkling Marina, ID
# No data found in API response for: Conkling Marina, ID
# list index out of range
# Fetching data for: Rochester (?), NY
# Data retrieved successfully for: City of Rochester, NY
# Fetching data for: Headland, AL
# Data retrieved successfully for: Headland, AL
# Fetching data for: Houston (Katy area), TX
# No data found in API response for: Houston (Katy area), TX
# list index out of range
# Fetching data for: Pevely, MO
# Data retrieved successfully for: Pevely, MO
# Fetching data for: Southbend, IN
# No data found in API response for: Southbend, IN
# list index out of range
# Fetching data for: North Plainfield, NJ
# Data retrieved successfully for: North Plainfield, NJ
# Fetching data for: Howard Lake, MN
# Data retrieved successfully for: Howard Lake, MN
# Fetching data for: Dexterville, WI
# Data retrieved successfully for: Dexterville, WI
# Fetching data for: Lacon, IL
# Data retrieved successfully for: Lacon, IL
# Fetching data for: East Jackson, MI
# No data found in API response for: East Jackson, MI
# list index out of range
# Fetching data for: Pilot Hill, CA
# Data retrieved successfully for: Pilot Hill, CA
# Fetching data for: Centerline, MI
# No data found in API response for: Centerline, MI
# list index out of range
# Fetching data for: Kingman (~30 miles n on 93), AZ
# No data found in API response for: Kingman (~30 miles n on 93), AZ
# list index out of range
# Fetching data for: De Land, IL
# Data retrieved successfully for: De Land, IL
# Fetching data for: Iowa City Hwy 218 north, I-380 north, Cedar Rapids), IA
# Error fetching data for: Iowa City Hwy 218 north, I-380 north, Cedar Rapids), IA
# 404 Client Error: Not Found for url: http://api.openweathermap.org/geo/1.0/direct?q=Iowa%20City%20Hwy%20218%20north,%20I-380%20north,%20Cedar%20Rapids),IA,US&appid=4b05a84f281638c6482f2fe919ea6a27
# Fetching data for: West Peabody, MA
# Data retrieved successfully for: West Peabody, MA
# Fetching data for: Marreo/Lafitte, LA
# No data found in API response for: Marreo/Lafitte, LA
# list index out of range
# Fetching data for: Pengilly, MN
# Data retrieved successfully for: Pengilly, MN
# Fetching data for: Hammocks, FL
# Data retrieved successfully for: Parker Hammocks, FL
# Fetching data for: Manns Choice, PA
# Data retrieved successfully for: Manns Choice, PA
# Fetching data for: Hastings (south of), NE
# No data found in API response for: Hastings (south of), NE
# list index out of range
# Fetching data for: Abbeville, LA
# Data retrieved successfully for: Abbeville, LA
# Fetching data for: Topanga Beach, CA
# No data found in API response for: Topanga Beach, CA
# list index out of range
# Fetching data for: Celebration, FL
# Data retrieved successfully for: Celebration Village, FL
# Fetching data for: Decorah, IA
# Data retrieved successfully for: Decorah, IA
# Fetching data for: EL Cajon, CA
# Data retrieved successfully for: El Cajon, CA
# Fetching data for: MADISON, CT
# Data retrieved successfully for: Madison, CT
# Fetching data for: Coward, SC
# Data retrieved successfully for: Coward, SC
# Fetching data for: Oklahoma City (southwest of), OK
# No data found in API response for: Oklahoma City (southwest of), OK
# list index out of range
# Fetching data for: Oaklandon, IN
# Data retrieved successfully for: Oaklandon, IN
# Fetching data for: Wallkill, NY
# Data retrieved successfully for: Town of Wallkill, NY
# Fetching data for: Nine Mile Falls, WA
# Data retrieved successfully for: Nine Mile Falls, WA
# Fetching data for: Clam Gulch, AK
# Data retrieved successfully for: Clam Gulch, AK
# Fetching data for: Mona (just north of), UT
# No data found in API response for: Mona (just north of), UT
# list index out of range
# Fetching data for: Eugene (general area), OR
# No data found in API response for: Eugene (general area), OR
# list index out of range
# Fetching data for: Gila Bend-Aztec, AZ
# No data found in API response for: Gila Bend-Aztec, AZ
# list index out of range
# Fetching data for: Kerman, CA
# Data retrieved successfully for: Kerman, CA
# Fetching data for: MacDill Air Force Base Tampa, FL
# No data found in API response for: MacDill Air Force Base Tampa, FL
# list index out of range
# Fetching data for: Corvallis/Monmouth/Jefferson, OR
# No data found in API response for: Corvallis/Monmouth/Jefferson, OR
# list index out of range
# Fetching data for: University Place/Fircrest, WA
# No data found in API response for: University Place/Fircrest, WA
# list index out of range
# Fetching data for: Miami/Globe, AZ
# No data found in API response for: Miami/Globe, AZ
# list index out of range
# Fetching data for: Pavo (NE of), GA
# No data found in API response for: Pavo (NE of), GA
# list index out of range
# Fetching data for: Providence/Johnston (between; traveling), RI
# No data found in API response for: Providence/Johnston (between; traveling), RI
# list index out of range
# Fetching data for: West Fork (I-540; MM32), AR
# No data found in API response for: West Fork (I-540; MM32), AR
# list index out of range
# Fetching data for: Florence Township, NJ
# Data retrieved successfully for: Florence Township, NJ
# Fetching data for: Brookfield (town of), WI
# Data retrieved successfully for: Town of Brookfield, WI
# Fetching data for: Chester Heights, PA
# Data retrieved successfully for: Chester Heights, PA
# Fetching data for: Logandale, NV
# Data retrieved successfully for: Logandale, NV
# Fetching data for: Mauldin, SC
# Data retrieved successfully for: Mauldin, SC
# Fetching data for: Williamburg, VA
# No data found in API response for: Williamburg, VA
# list index out of range
# Fetching data for: Ainsworth, IA
# Data retrieved successfully for: Ainsworth, IA
# Fetching data for: Landrum, SC
# Data retrieved successfully for: Landrum, SC
# Fetching data for: Coto de Caza, CA
# Data retrieved successfully for: Coto de Caza, CA
# Fetching data for: St. Matthews, SC
# Data retrieved successfully for: St. Matthews, SC
# Fetching data for: Everett/Snohomish, WA
# No data found in API response for: Everett/Snohomish, WA
# list index out of range
# Fetching data for: Los Lunas/Albuqerque, NM
# No data found in API response for: Los Lunas/Albuqerque, NM
# list index out of range
# Fetching data for: Mountain Brook, AL
# Data retrieved successfully for: Mountain Brook, AL
# Fetching data for: Pilot hill, CA
# Data retrieved successfully for: Pilot Hill, CA
# Fetching data for: Bartonsville, PA
# Data retrieved successfully for: Bartonsville, PA
# Fetching data for: Lacy Springs, AL
# No data found in API response for: Lacy Springs, AL
# list index out of range
# Fetching data for: Crouse, NC
# Data retrieved successfully for: Crouse, NC
# Fetching data for: Ward Cove, AK
# Data retrieved successfully for: Ward Cove, AK
# Fetching data for: Topping, VA
# Data retrieved successfully for: Topping, VA
# Fetching data for: Golden Meadow, LA
# Data retrieved successfully for: Golden Meadow, LA
# Fetching data for: Riva, MD
# Data retrieved successfully for: Riva, MD
# Fetching data for: Bentleyville (3-5 miles east of; on I-70), PA
# No data found in API response for: Bentleyville (3-5 miles east of; on I-70), PA
# list index out of range
# Fetching data for: Stedman, NC
# Data retrieved successfully for: Stedman, NC
# Fetching data for: Churchton, MD
# Data retrieved successfully for: Churchton, MD
# Fetching data for: Scott Depot, WV
# Data retrieved successfully for: Scott Depot, WV
# Fetching data for: Montgomery/Millbrook, AL
# No data found in API response for: Montgomery/Millbrook, AL
# list index out of range
# Fetching data for: Glenelg, MD
# Data retrieved successfully for: Glenelg, MD
# Fetching data for: Liberty County (rural area in), MT
# No data found in API response for: Liberty County (rural area in), MT
# list index out of range
# Fetching data for: Mokena/Matteson, IL
# No data found in API response for: Mokena/Matteson, IL
# list index out of range
# Fetching data for: Firebaugh (near), CA
# No data found in API response for: Firebaugh (near), CA
# list index out of range
# Fetching data for: Briceville, TN
# Data retrieved successfully for: Briceville, TN
# Fetching data for: In flight (southern U.S.), TX
# No data found in API response for: In flight (southern U.S.), TX
# list index out of range
# Fetching data for: West Chester (near), PA
# No data found in API response for: West Chester (near), PA
# list index out of range
# Fetching data for: Olean, NY
# Data retrieved successfully for: City of Olean, NY
# Fetching data for: Fritch, TX
# Data retrieved successfully for: Fritch, TX
# Fetching data for: Balboa Island, CA
# Data retrieved successfully for: Balboa Island, CA
# Fetching data for: Latham, NY
# Data retrieved successfully for: Latham, NY
# Fetching data for: Sacramento (east), CA
# Data retrieved successfully for: East Sacramento, CA
# Fetching data for: Brownsmills, NJ
# No data found in API response for: Brownsmills, NJ
# list index out of range
# Fetching data for: Punt Gorda, FL
# No data found in API response for: Punt Gorda, FL
# list index out of range
# Fetching data for: Grenville, SC
# No data found in API response for: Grenville, SC
# list index out of range
# Fetching data for: Thurmond, WV
# Data retrieved successfully for: Thurmond, WV
# Fetching data for: Winter Park (Orlando), FL
# No data found in API response for: Winter Park (Orlando), FL
# list index out of range
# Fetching data for: Grand Rivers, KY
# Data retrieved successfully for: Grand Rivers, KY
# Fetching data for: Scottsville, VA
# Data retrieved successfully for: Scottsville, VA
# Fetching data for: (City not specified), MO
# No data found in API response for: (City not specified), MO
# list index out of range
# Fetching data for: Newark (I-95; near PA border), DE
# No data found in API response for: Newark (I-95; near PA border), DE
# list index out of range
# Fetching data for: Stoney Beach, MD
# No data found in API response for: Stoney Beach, MD
# list index out of range
# Fetching data for: Aguadilla (Puerto Rico), PR
# No data found in API response for: Aguadilla (Puerto Rico), PR
# list index out of range
# Fetching data for: Tehama, CA
# Data retrieved successfully for: Tehama, CA
# Fetching data for: Wirtz, VA
# Data retrieved successfully for: Wirtz, VA
# Fetching data for: Monterey Bay, CA
# No data found in API response for: Monterey Bay, CA
# list index out of range
# Fetching data for: Lame Deer, MT
# Data retrieved successfully for: Lame Deer, MT
# Fetching data for: Warr acres, OK
# Data retrieved successfully for: Warr Acres, OK
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'DeTour Village', 'Lat': 45.9935112, 'Lng': -83.9019487}, {'City': 'Vancouver', 'Lat': 49.2608724, 'Lng': -123.113952}, {'City': 'South Elgin', 'Lat': 41.9941938, 'Lng': -88.2922996}, {'City': 'Hometown', 'Lat': 41.731246, 'Lng': -87.7309534}, {'City': 'Jacobus', 'Lat': 39.8831558, 'Lng': -76.7105245}, {'City': 'Wingdale', 'Lat': 41.6470383, 'Lng': -73.5681816}, {'City': 'Milbury', 'Lat': 32.9243262, 'Lng': -81.4301071}, {'City': 'Rootstown', 'Lat': 41.0990792, 'Lng': -81.2424901}, {'City': 'Dyersville', 'Lat': 42.4844602, 'Lng': -91.1211058}, {'City': 'Pequea', 'Lat': 39.8881566, 'Lng': -76.367183}, {'City': 'Lisman', 'Lat': 32.1687554, 'Lng': -88.2825251}, {'City': 'Kawaihae', 'Lat': 20.0397244, 'Lng': -155.8291338}, {'City': 'Lively Grove', 'Lat': 38.3064384, 'Lng': -89.6114824}, {'City': 'White Center', 'Lat': 47.5164297, 'Lng': -122.355739}, {'City': 'Schererville', 'Lat': 41.4789246, 'Lng': -87.4547605}, {'City': 'Placitas', 'Lat': 35.3069101, 'Lng': -106.424655}, {'City': 'Mount Laguna', 'Lat': 32.8669744, 'Lng': -116.4188217}, {'City': 'Kerhonkson', 'Lat': 41.7748155, 'Lng': -74.2982059}, {'City': 'Shavertown', 'Lat': 41.3198025, 'Lng': -75.9379761}, {'City': 'Symsonia', 'Lat': 36.9203351, 'Lng': -88.520045}, {'City': 'New Egypt', 'Lat': 40.0654375, 'Lng': -74.52266813721602}, {'City': 'Palomar Mountain', 'Lat': 33.3228128, 'Lng': -116.8786359}, {'City': 'Swartz Creek', 'Lat': 42.9572508, 'Lng': -83.8305144}, {'City': 'Zelienople', 'Lat': 40.7957622, 'Lng': -80.1370795}, {'City': 'Plainwell', 'Lat': 42.4400357, 'Lng': -85.6489035}, {'City': 'Kingston Springs', 'Lat': 36.1020038, 'Lng': -87.1150054}, {'City': 'Thompson Falls', 'Lat': 47.5971287, 'Lng': -115.344309}, {'City': 'Hollidaysburg', 'Lat': 40.430774, 'Lng': -78.3900826}, {'City': 'Flowood', 'Lat': 32.3092861, 'Lng': -90.1386811}, {'City': 'Newton Falls', 'Lat': 41.18839, 'Lng': -80.978147}, {'City': 'Carol Stream', 'Lat': 41.9125286, 'Lng': -88.1347927}, {'City': 'Cataula', 'Lat': 32.655414, 'Lng': -84.8685418}, {'City': 'Throop', 'Lat': 41.4514694, 'Lng': -75.6118548}, {'City': 'Bruneau', 'Lat': 42.8810312, 'Lng': -115.7989401}, {'City': 'Mount Sinai', 'Lat': 40.9470432, 'Lng': -73.0295495}, {'City': 'Barber', 'Lat': 35.7573133, 'Lng': -94.8677286}, {'City': 'Monaca', 'Lat': 40.6872885, 'Lng': -80.2714505}, {'City': 'Gold Beach', 'Lat': 42.4074459, 'Lng': -124.4217418}, {'City': 'South Barrington', 'Lat': 42.088522, 'Lng': -88.14840371084922}, {'City': 'Rodeo', 'Lat': 31.8364383, 'Lng': -109.030309}, {'City': 'Paige', 'Lat': 30.2116519, 'Lng': -97.1132832}, {'City': 'Cornelia', 'Lat': 34.5114883, 'Lng': -83.5271166}, {'City': 'Box Elder', 'Lat': 44.1333654, 'Lng': -103.064514}, {'City': 'Pretty Prairie', 'Lat': 37.7800136, 'Lng': -98.0197792}, {'City': 'Willisburg', 'Lat': 37.8097892, 'Lng': -85.126347}, {'City': 'Lower Makefield Township', 'Lat': 40.2312713, 'Lng': -74.84670236269929}, {'City': 'Front Royal', 'Lat': 38.9178538, 'Lng': -78.1917718}, {'City': 'Coffman Cove', 'Lat': 56.0139933, 'Lng': -132.827889}, {'City': 'West Bangor', 'Lat': 39.7301046, 'Lng': -76.3130139}, {'City': 'Fredenberg Township', 'Lat': 46.982052350000004, 'Lng': -92.23874323340263}, {'City': 'DeTour Village', 'Lat': 45.9935112, 'Lng': -83.9019487}, {'City': 'Lucedale', 'Lat': 30.9251869, 'Lng': -88.5900235}, {'City': 'Sentinel Butte', 'Lat': 46.9183469, 'Lng': -103.8388108}, {'City': 'Godfrey', 'Lat': 38.9556031, 'Lng': -90.1867765}, {'City': 'Cedarcreek', 'Lat': 36.578953, 'Lng': -92.9976756}, {'City': 'Elkland', 'Lat': 37.4430998, 'Lng': -93.031015}, {'City': 'Mohave Valley', 'Lat': 34.9827252, 'Lng': -114.589433}, {'City': 'Quaker Hill', 'Lat': 41.4036987, 'Lng': -72.1061564}, {'City': 'Longmeadow', 'Lat': 42.0504498, 'Lng': -72.5824639}, {'City': 'Cliffdell', 'Lat': 46.9462292, 'Lng': -121.0689708}, {'City': 'Algonquin', 'Lat': 42.1655801, 'Lng': -88.2942493}, {'City': 'West Greenwich', 'Lat': 41.6226185, 'Lng': -71.6657892}, {'City': 'Blue Island', 'Lat': 41.6572753, ...

# %%
batch03_10000to12061_cities = pd.DataFrame(city_data)
batch03_10000to12061_cities
# Out:
#                 City        Lat         Lng
# 0     DeTour Village  45.993511  -83.901949
# 1          Vancouver  49.260872 -123.113952
# 2        South Elgin  41.994194  -88.292300
# 3           Hometown  41.731246  -87.730953
# 4            Jacobus  39.883156  -76.710525
# ...              ...        ...         ...
# 1266     Scottsville  37.798757  -78.495566
# 1267          Tehama  40.027102 -122.123322
# 1268           Wirtz  37.076529  -79.889478
# 1269       Lame Deer  45.623048 -106.666698
# 1270      Warr Acres  35.522557  -97.618935
#
# [1271 rows x 3 columns]

# %%
batch03_10000to12061_cities.to_csv('../Output/batch03_10000to12061_cities.csv')
