# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import json

# %%
# Load data
df = pd.read_csv('Output/City_latlng_merge.csv')  # Ensure your CSV has 'latitude' and 'longitude' columns
df
# Out:
#        Unnamed: 0  SIGHTING_ID OCCURRED_DATE         CITY STATE COUNTRY  \
# 0               0          1.0    2024-06-20     Cranston    RI     USA
# 1               1      10490.0    2021-06-17     Cranston    RI     USA
# 2               2      18342.0    2019-12-19     Cranston    RI     USA
# 3               3      21138.0    2019-07-15     Cranston    RI     USA
# 4               4      21951.0    2019-05-25     Cranston    RI     USA
# ...           ...          ...           ...          ...   ...     ...
# 63250       63250      50157.0    2014-02-21  Scottsville    VA     USA
# 63251       63251      50194.0    2014-02-20       Tehama    CA     USA
# 63252       63252      50208.0    2014-02-19        Wirtz    VA     USA
# 63253       63253      50226.0    2014-02-18    Lame Deer    MT     USA
# 63254       63254          NaN           NaN   Warr Acres   NaN     NaN
#
#            SHAPE                                            SUMMARY    YEAR  \
# 0          Flash  My wife and I as well as our 2 children witnes...  2024.0
# 1         Circle  At 11:50 am on june 17 2021 i seen a jet aircr...  2021.0
# 2       Fireball  I was driving to work and i saw a ball of fire...  2019.0
# 3          Other             Object appears, moves, and disappears.  2019.0
# 4         Circle  Circular looking UFO comes out of a chemtrail ...  2019.0
# ...          ...                                                ...     ...
# 63250    Diamond  It's still going on S in the sky stationary fl...  2014.0
# 63251    Chevron  Saw bright white stringy chevron shape heading...  2014.0
# 63252  Formation  Curved line of 6 or 7 red lights in Western sk...  2014.0
# 63253    Unknown          Orange lights slowly from south to north.  2014.0
# 63254        NaN                                                NaN     NaN
#
#              CITYSTATE      Lat       Lng
# 0         Cranston, RI  41.7798  -71.4373
# 1         Cranston, RI  41.7798  -71.4373
# 2         Cranston, RI  41.7798  -71.4373
# 3         Cranston, RI  41.7798  -71.4373
# 4         Cranston, RI  41.7798  -71.4373
# ...                ...      ...       ...
# 63250  Scottsville, VA  36.7534  -86.1905
# 63251       Tehama, CA  40.1332 -122.3011
# 63252        Wirtz, VA  37.0765  -79.8895
# 63253    Lame Deer, MT  45.6231 -106.6667
# 63254              NaN  35.5226  -97.6189
#
# [63255 rows x 12 columns]

# %%
# Create GeoDataFrame
gdf = gpd.GeoDataFrame(
    df,
    geometry=[Point(xy) for xy in zip(df['Lng'], df['Lat'])],
    crs='EPSG:4326'  # EPSG:4326 is the coordinate reference system for WGS84
)
gdf
# Out:
#        Unnamed: 0  SIGHTING_ID OCCURRED_DATE         CITY STATE COUNTRY  \
# 0               0          1.0    2024-06-20     Cranston    RI     USA
# 1               1      10490.0    2021-06-17     Cranston    RI     USA
# 2               2      18342.0    2019-12-19     Cranston    RI     USA
# 3               3      21138.0    2019-07-15     Cranston    RI     USA
# 4               4      21951.0    2019-05-25     Cranston    RI     USA
# ...           ...          ...           ...          ...   ...     ...
# 63250       63250      50157.0    2014-02-21  Scottsville    VA     USA
# 63251       63251      50194.0    2014-02-20       Tehama    CA     USA
# 63252       63252      50208.0    2014-02-19        Wirtz    VA     USA
# 63253       63253      50226.0    2014-02-18    Lame Deer    MT     USA
# 63254       63254          NaN           NaN   Warr Acres   NaN     NaN
#
#            SHAPE                                            SUMMARY    YEAR  \
# 0          Flash  My wife and I as well as our 2 children witnes...  2024.0
# 1         Circle  At 11:50 am on june 17 2021 i seen a jet aircr...  2021.0
# 2       Fireball  I was driving to work and i saw a ball of fire...  2019.0
# 3          Other             Object appears, moves, and disappears.  2019.0
# 4         Circle  Circular looking UFO comes out of a chemtrail ...  2019.0
# ...          ...                                                ...     ...
# 63250    Diamond  It's still going on S in the sky stationary fl...  2014.0
# 63251    Chevron  Saw bright white stringy chevron shape heading...  2014.0
# 63252  Formation  Curved line of 6 or 7 red lights in Western sk...  2014.0
# 63253    Unknown          Orange lights slowly from south to north.  2014.0
# 63254        NaN                                                NaN     NaN
#
#              CITYSTATE      Lat       Lng                     geometry
# 0         Cranston, RI  41.7798  -71.4373   POINT (-71.43730 41.77980)
# 1         Cranston, RI  41.7798  -71.4373   POINT (-71.43730 41.77980)
# 2         Cranston, RI  41.7798  -71.4373   POINT (-71.43730 41.77980)
# 3         Cranston, RI  41.7798  -71.4373   POINT (-71.43730 41.77980)
# 4         Cranston, RI  41.7798  -71.4373   POINT (-71.43730 41.77980)
# ...                ...      ...       ...                          ...
# 63250  Scottsville, VA  36.7534  -86.1905   POINT (-86.19050 36.75340)
# 63251       Tehama, CA  40.1332 -122.3011  POINT (-122.30110 40.13320)
# 63252        Wirtz, VA  37.0765  -79.8895   POINT (-79.88950 37.07650)
# 63253    Lame Deer, MT  45.6231 -106.6667  POINT (-106.66670 45.62310)
# 63254              NaN  35.5226  -97.6189   POINT (-97.61890 35.52260)
#
# [63255 rows x 13 columns]

# %%
# Output to GeoJSON
geojson = gdf.to_json()

# %%
# Pretty-print the GeoJSON
geojson_pretty = json.dumps(json.loads(geojson), indent=4)

# %%
# Save to file
with open('sightings_pretty.geojson', 'w') as f:
    f.write(geojson_pretty)

print("GeoJSON data has been pretty-printed and saved to 'locations_pretty.geojson'")
# Out:
# GeoJSON data has been pretty-printed and saved to 'locations_pretty.geojson'
