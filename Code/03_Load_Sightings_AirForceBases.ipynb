# %%
# Import dependencies
from pymongo import MongoClient
import json
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# assign the database to a variable name
db = mongo['nuforc']

# %% [markdown]
# # Step 1: Load USA Sightings CSV

# %% [markdown]
# ### Step 1a: Empty the collection, as needed

# %%
# # Empty the collection
# usa_sightings.delete_many({})

# %% [markdown]
# ### Step 1b: Create the collection

# %%
# assign collection to a variable
usa_sightings = db['usa_sightings']

# %%
# Read in usa_sightings dataframe with lat / long
usa_sightings_df = pd.read_csv('../Output/City_latlng_merge.csv')

# %%
# Create a data frame for flight search df
usa_sightings_df = pd.DataFrame(usa_sightings_df)
usa_sightings_df
# Out:
#        Unnamed: 0  SIGHTING_ID OCCURRED_DATE           CITY STATE COUNTRY  \
# 0               0            1    2024-06-20       Cranston    RI     USA
# 1              14            2    2024-06-20       Key West    FL     USA
# 2           47463            3    2024-06-20  Oklahoma City    OK     USA
# 3              94            4    2024-06-19  Valley Stream    NY     USA
# 4             101            5    2024-06-19   Jacksonville    FL     USA
# ...           ...          ...           ...            ...   ...     ...
# 44924       34650        50221    2014-02-18         Tucson    AZ     USA
# 44925        9338        50219    2014-02-18        Houston    TX     USA
# 44926       24507        50222    2014-02-18      Fallbrook    CA     USA
# 44927       22963        50223    2014-02-18       Chandler    IN     USA
# 44928       63253        50226    2014-02-18      Lame Deer    MT     USA
#
#           SHAPE                                            SUMMARY  YEAR  \
# 0         Flash  My wife and I as well as our 2 children witnes...  2024
# 1         Light  Saw unexplainable lights slightly west of Nort...  2024
# 2         Light          Erratically moving light at high altitude  2024
# 3        Sphere  Sphere in the sky that glowed like an LED ligh...  2024
# 4      Triangle                   Black triangle very low no noise  2024
# ...         ...                                                ...   ...
# 44924       Orb  REPORT FROM ATP PILOT:  3 orange orbs size, di...  2014
# 44925      Disk  Silver disc on the right of me and then golden...  2014
# 44926       Orb                 Orange orb with some intelligence.  2014
# 44927     Other  Lighted object larger than a commercial a/c ho...  2014
# 44928   Unknown          Orange lights slowly from south to north.  2014
#
#                CITYSTATE    Lat     Lng
# 0           Cranston, RI  41.78  -71.44
# 1           Key West, FL  24.56  -81.78
# 2      Oklahoma City, OK  35.47  -97.52
# 3      Valley Stream, NY  40.66  -73.71
# 4       Jacksonville, FL  30.33  -81.66
# ...                  ...    ...     ...
# 44924         Tucson, AZ  32.22 -110.93
# 44925        Houston, TX  29.76  -95.36
# 44926      Fallbrook, CA  33.38 -117.25
# 44927       Chandler, IN  33.31 -111.84
# 44928      Lame Deer, MT  45.62 -106.67
#
# [44929 rows x 12 columns]

# %%
# Convert DataFrame to list of dictionaries
usa_sightings_dict = usa_sightings_df.to_dict(orient='records')
usa_sightings_dict
# Out:
# [{'Unnamed: 0': 0,
#   'SIGHTING_ID': 1,
#   'OCCURRED_DATE': '2024-06-20',
#   'CITY': 'Cranston',
#   'STATE': 'RI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Flash',
#   'SUMMARY': 'My wife and I as well as our 2 children witnessed multiple flashing silent objects .',
#   'YEAR': 2024,
#   'CITYSTATE': 'Cranston, RI',
#   'Lat': 41.78,
#   'Lng': -71.44},
#  {'Unnamed: 0': 14,
#   'SIGHTING_ID': 2,
#   'OCCURRED_DATE': '2024-06-20',
#   'CITY': 'Key West',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Saw unexplainable lights slightly west of North in Key West',
#   'YEAR': 2024,
#   'CITYSTATE': 'Key West, FL',
#   'Lat': 24.56,
#   'Lng': -81.78},
#  {'Unnamed: 0': 47463,
#   'SIGHTING_ID': 3,
#   'OCCURRED_DATE': '2024-06-20',
#   'CITY': 'Oklahoma City',
#   'STATE': 'OK',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Erratically moving light at high altitude',
#   'YEAR': 2024,
#   'CITYSTATE': 'Oklahoma City, OK',
#   'Lat': 35.47,
#   'Lng': -97.52},
#  {'Unnamed: 0': 94,
#   'SIGHTING_ID': 4,
#   'OCCURRED_DATE': '2024-06-19',
#   'CITY': 'Valley Stream',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Sphere in the sky that glowed like an LED light and appeared/disappeared multiple times, at times pulsating.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Valley Stream, NY',
#   'Lat': 40.66,
#   'Lng': -73.71},
#  {'Unnamed: 0': 101,
#   'SIGHTING_ID': 5,
#   'OCCURRED_DATE': '2024-06-19',
#   'CITY': 'Jacksonville',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Black triangle very low no noise',
#   'YEAR': 2024,
#   'CITYSTATE': 'Jacksonville, FL',
#   'Lat': 30.33,
#   'Lng': -81.66},
#  {'Unnamed: 0': 58135,
#   'SIGHTING_ID': 8,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': 'Washington',
#   'STATE': 'DC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Round silver shining object',
#   'YEAR': 2024,
#   'CITYSTATE': 'Washington, DC',
#   'Lat': 47.5,
#   'Lng': -120.5},
#  {'Unnamed: 0': 39085,
#   'SIGHTING_ID': 9,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': "Lee's Summit",
#   'STATE': 'MO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': "Two Lights in Lee's Summit, MO SW Sky, One Disappeared while other Remained for 45 min.",
#   'YEAR': 2024,
#   'CITYSTATE': "Lee's Summit, MO",
#   'Lat': 38.91,
#   'Lng': -94.38},
#  {'Unnamed: 0': 36284,
#   'SIGHTING_ID': 11,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': 'Boise',
#   'STATE': 'ID',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Adult male and 9 year old child watched a orb/sphere move slowly in the sky, and it looked like there was propulsion out of bottom.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Boise, ID',
#   'Lat': 43.61,
#   'Lng': -116.2},
#  {'Unnamed: 0': 312,
#   'SIGHTING_ID': 10,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': 'Yardley',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Saw black object appear, no noise guessing 5000 feet in the air. Seemed smaller than a Cessna aircraft. No lights or sound.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Yardley, PA',
#   'Lat': 40.25,
#   'Lng': -74.85},
#  {'Unnamed: 0': 259,
#   'SIGHTING_ID': 7,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': 'Leawood',
#   'STATE': 'KS',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Initially seen by naked eye, but slowly elevated and was out of sight within 30 minutes.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Leawood, KS',
#   'Lat': 38.97,
#   'Lng': -94.62},
#  {'Unnamed: 0': 250,
#   'SIGHTING_ID': 6,
#   'OCCURRED_DATE': '2024-06-18',
#   'CITY': 'Lawrenceburg',
#   'STATE': 'KY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Triangular UFO with white, red, maybe blue lights.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lawrenceburg, KY',
#   'Lat': 38.04,
#   'Lng': -84.9},
#  {'Unnamed: 0': 460,
#   'SIGHTING_ID': 13,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Del Rey',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Silver then changed to translucent',
#   'YEAR': 2024,
#   'CITYSTATE': 'Del Rey, CA',
#   'Lat': 36.66,
#   'Lng': -119.59},
#  {'Unnamed: 0': 25331,
#   'SIGHTING_ID': 17,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Sacramento',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Comet like object',
#   'YEAR': 2024,
#   'CITYSTATE': 'Sacramento, CA',
#   'Lat': 38.47,
#   'Lng': -121.32},
#  {'Unnamed: 0': 461,
#   'SIGHTING_ID': 14,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Marietta',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Spinning green light moving extremely fast as seen in video',
#   'YEAR': 2024,
#   'CITYSTATE': 'Marietta, GA',
#   'Lat': 33.95,
#   'Lng': -84.55},
#  {'Unnamed: 0': 511,
#   'SIGHTING_ID': 15,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Gunnison',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Multiple craft flying in multiple directions even from straight up from the ground. Cows are losing it right now.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Gunnison, CO',
#   'Lat': 38.7,
#   'Lng': -107.07},
#  {'Unnamed: 0': 653,
#   'SIGHTING_ID': 20,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Yakima',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Strange craft "swimming" in sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Yakima, WA',
#   'Lat': 46.47,
#   'Lng': -120.67},
#  {'Unnamed: 0': 520,
#   'SIGHTING_ID': 16,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Spicer City',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Have video of white light/formation. Then 7 star like lights sped away 30 second intervals',
#   'YEAR': 2024,
#   'CITYSTATE': 'Spicer City, CA',
#   'Lat': 35.5,
#   'Lng': -119.6},
#  {'Unnamed: 0': 637,
#   'SIGHTING_ID': 19,
#   'OCCURRED_DATE': '2024-06-17',
#   'CITY': 'Deer Park',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'It was about the length of a school bus shot straight up in the air and shot off to the north while getting very bright and left trail',
#   'YEAR': 2024,
#   'CITYSTATE': 'Deer Park, WA',
#   'Lat': 29.71,
#   'Lng': -95.12},
#  {'Unnamed: 0': 681,
#   'SIGHTING_ID': 21,
#   'OCCURRED_DATE': '2024-06-16',
#   'CITY': 'Oyster Bay',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Looked like 2 orbs spinning around each other. And reflecting sunlight as it’s spinning. No sound and floating like balloons very high',
#   'YEAR': 2024,
#   'CITYSTATE': 'Oyster Bay, NY',
#   'Lat': 40.87,
#   'Lng': -73.53},
#  {'Unnamed: 0': 25332,
#   'SIGHTING_ID': 24,
#   'OCCURRED_DATE': '2024-06-16',
#   'CITY': 'Sacramento',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Green “meteor” enters atmosphere',
#   'YEAR': 2024,
#   'CITYSTATE': 'Sacramento, CA',
#   'Lat': 38.47,
#   'Lng': -121.32},
#  {'Unnamed: 0': 698,
#   'SIGHTING_ID': 25,
#   'OCCURRED_DATE': '2024-06-16',
#   'CITY': 'Battle Creek',
#   'STATE': 'MI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'I saw a oval object with a very bright light zoom from behind me then stopped and disappeared.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Battle Creek, MI',
#   'Lat': 42.32,
#   'Lng': -85.18},
#  {'Unnamed: 0': 684,
#   'SIGHTING_ID': 22,
#   'OCCURRED_DATE': '2024-06-16',
#   'CITY': 'Montclair',
#   'STATE': 'NJ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Just noticed this in the sky while laying in the yard. It slowly moved across the sky until disappearing behind a tree.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Montclair, NJ',
#   'Lat': 40.83,
#   'Lng': -74.21},
#  {'Unnamed: 0': 695,
#   'SIGHTING_ID': 23,
#   'OCCURRED_DATE': '2024-06-16',
#   'CITY': 'Anchor Point',
#   'STATE': 'AK',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Large object hovering over summit of Redoubt volcano',
#   'YEAR': 2024,
#   'CITYSTATE': 'Anchor Point, AK',
#   'Lat': 59.78,
#   'Lng': -151.83},
#  {'Unnamed: 0': 808,
#   'SIGHTING_ID': 30,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Palmer',
#   'STATE': 'AK',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'My wife and I were leasing at Jim Lake near Palmer and saw this object and then we saw it in a picture I took.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Palmer, AK',
#   'Lat': 42.16,
#   'Lng': -72.33},
#  {'Unnamed: 0': 805,
#   'SIGHTING_ID': 29,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Waterboro',
#   'STATE': 'ME',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'A small bright light in the sky that appeared suddenly then faded away with no trail, and was moving slowly for ~5 seconds',
#   'YEAR': 2024,
#   'CITYSTATE': 'Waterboro, ME',
#   'Lat': 43.54,
#   'Lng': -70.72},
#  {'Unnamed: 0': 864,
#   'SIGHTING_ID': 32,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Alamogordo',
#   'STATE': 'NM',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'White orb hovering over mountain.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Alamogordo, NM',
#   'Lat': 32.9,
#   'Lng': -105.96},
#  {'Unnamed: 0': 803,
#   'SIGHTING_ID': 28,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Dillingham',
#   'STATE': 'AK',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': '2 light naked eye thought they were stars but they moved',
#   'YEAR': 2024,
#   'CITYSTATE': 'Dillingham, AK',
#   'Lat': 59.04,
#   'Lng': -158.46},
#  {'Unnamed: 0': 715,
#   'SIGHTING_ID': 27,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Richmond',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Three orbs in a line coming up from the ground',
#   'YEAR': 2024,
#   'CITYSTATE': 'Richmond, CA',
#   'Lat': 37.55,
#   'Lng': -77.46},
#  {'Unnamed: 0': 38522,
#   'SIGHTING_ID': 26,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'West Milford',
#   'STATE': 'NJ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Saw a large disk hovering -flying over the mountain top really close to the tree line and went up and over bearfort mountain.',
#   'YEAR': 2024,
#   'CITYSTATE': 'West Milford, NJ',
#   'Lat': 41.13,
#   'Lng': -74.37},
#  {'Unnamed: 0': 824,
#   'SIGHTING_ID': 31,
#   'OCCURRED_DATE': '2024-06-15',
#   'CITY': 'Troy',
#   'STATE': 'MI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Saw 2 flying objects that looked like planes, but were stopping and turning randomly in different directions.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Troy, MI',
#   'Lat': 42.61,
#   'Lng': -83.15},
#  {'Unnamed: 0': 1060,
#   'SIGHTING_ID': 34,
#   'OCCURRED_DATE': '2024-06-14',
#   'CITY': 'Oldtown',
#   'STATE': 'KY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'It came down from the clouds then disappeared over the tree line heading almost true North .',
#   'YEAR': 2024,
#   'CITYSTATE': 'Oldtown, KY',
#   'Lat': 53.53,
#   'Lng': -6.32},
#  {'Unnamed: 0': 879,
#   'SIGHTING_ID': 33,
#   'OCCURRED_DATE': '2024-06-14',
#   'CITY': 'Los Angeles',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'We were laying in the front yard and looking up in the sky and my friend saw something shinny and bright and round.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Los Angeles, CA',
#   'Lat': 34.05,
#   'Lng': -118.24},
#  {'Unnamed: 0': 55889,
#   'SIGHTING_ID': 36,
#   'OCCURRED_DATE': '2024-06-13',
#   'CITY': 'Pittsburgh',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Very bright light. It was still light out. The light stayed around for 5 to 10 minutes and then just disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Pittsburgh, PA',
#   'Lat': 40.44,
#   'Lng': -80.0},
#  {'Unnamed: 0': 1061,
#   'SIGHTING_ID': 35,
#   'OCCURRED_DATE': '2024-06-13',
#   'CITY': 'Boothbay',
#   'STATE': 'ME',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Heard a giant boom then saw this very bright slowly rise up behind the trees. It got faster and faster.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Boothbay, ME',
#   'Lat': 43.88,
#   'Lng': -69.63},
#  {'Unnamed: 0': 1154,
#   'SIGHTING_ID': 37,
#   'OCCURRED_DATE': '2024-06-13',
#   'CITY': 'Wills Point',
#   'STATE': 'TX',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Flash',
#   'SUMMARY': 'Walking home I seen white lights flash for an instant, above and in front of the moon.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Wills Point, TX',
#   'Lat': 32.71,
#   'Lng': -96.01},
#  {'Unnamed: 0': 27564,
#   'SIGHTING_ID': 39,
#   'OCCURRED_DATE': '2024-06-12',
#   'CITY': 'Orlando',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'While driving back into town from the north I noticed a luminous craft over Downtown Orlando or slightly East of.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Orlando, FL',
#   'Lat': 28.54,
#   'Lng': -81.38},
#  {'Unnamed: 0': 1419,
#   'SIGHTING_ID': 41,
#   'OCCURRED_DATE': '2024-06-12',
#   'CITY': 'Seattle',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Dark object that seems to have multiple shapes and genetic makeup (smokey yet also partly physical object)',
#   'YEAR': 2024,
#   'CITYSTATE': 'Seattle, WA',
#   'Lat': 47.61,
#   'Lng': -122.33},
#  {'Unnamed: 0': 1155,
#   'SIGHTING_ID': 38,
#   'OCCURRED_DATE': '2024-06-12',
#   'CITY': 'Pacifica',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Triangle shaped aircraft made up of 3 bright blinking lights and one very faint light',
#   'YEAR': 2024,
#   'CITYSTATE': 'Pacifica, CA',
#   'Lat': 37.61,
#   'Lng': -122.49},
#  {'Unnamed: 0': 1325,
#   'SIGHTING_ID': 40,
#   'OCCURRED_DATE': '2024-06-12',
#   'CITY': 'Charlotte',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Viewed 4 metallic objects shaped like a football, smaller than a plane, but bigger than a car.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Charlotte, NC',
#   'Lat': 35.23,
#   'Lng': -80.84},
#  {'Unnamed: 0': 1583,
#   'SIGHTING_ID': 42,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Round Hill',
#   'STATE': 'VA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Lights near the Big Dipper appear, travel with constant velocity, brighten to yellow and dim to white before disappearing.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Round Hill, VA',
#   'Lat': 53.17,
#   'Lng': -112.64},
#  {'Unnamed: 0': 1627,
#   'SIGHTING_ID': 45,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Portland',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Three bright lights in a triangle shape',
#   'YEAR': 2024,
#   'CITYSTATE': 'Portland, OR',
#   'Lat': 45.52,
#   'Lng': -122.68},
#  {'Unnamed: 0': 60137,
#   'SIGHTING_ID': 45,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Portland',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Three bright lights in a triangle shape',
#   'YEAR': 2024,
#   'CITYSTATE': 'Portland, OR',
#   'Lat': 43.66,
#   'Lng': -70.25},
#  {'Unnamed: 0': 1863,
#   'SIGHTING_ID': 46,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Lee',
#   'STATE': 'NH',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Saw a light come into my yard',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lee, NH',
#   'Lat': 26.57,
#   'Lng': -81.88},
#  {'Unnamed: 0': 1869,
#   'SIGHTING_ID': 47,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Cookeville',
#   'STATE': 'TN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Red and green lights were expanding and contracting repeatedly while also remaining in the same position in the sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Cookeville, TN',
#   'Lat': 36.16,
#   'Lng': -85.5},
#  {'Unnamed: 0': 1606,
#   'SIGHTING_ID': 44,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Pawleys Island',
#   'STATE': 'SC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Bright, orange lights over the ocean seen with erratic, white lights.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Pawleys Island, SC',
#   'Lat': 33.43,
#   'Lng': -79.12},
#  {'Unnamed: 0': 1584,
#   'SIGHTING_ID': 43,
#   'OCCURRED_DATE': '2024-06-11',
#   'CITY': 'Winston-Salem',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Witnessed two flashing objects moving very erratically',
#   'YEAR': 2024,
#   'CITYSTATE': 'Winston-Salem, NC',
#   'Lat': 36.1,
#   'Lng': -80.24},
#  {'Unnamed: 0': 1913,
#   'SIGHTING_ID': 51,
#   'OCCURRED_DATE': '2024-06-10',
#   'CITY': 'La Pine',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Orb shape that flickered or pulsed (visible to the naked eye) in the western sky as it moved erratically and randomly.',
#   'YEAR': 2024,
#   'CITYSTATE': 'La Pine, OR',
#   'Lat': 43.67,
#   'Lng': -121.5},
#  {'Unnamed: 0': 1911,
#   'SIGHTING_ID': 50,
#   'OCCURRED_DATE': '2024-06-10',
#   'CITY': 'Glennville',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'Strange object caught on my home camera shooting across the sky.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Glennville, GA',
#   'Lat': 31.94,
#   'Lng': -81.93},
#  {'Unnamed: 0': 1881,
#   'SIGHTING_ID': 49,
#   'OCCURRED_DATE': '2024-06-10',
#   'CITY': 'Ocala',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Group observed a helicopter circling a lighted object for several minutes. Object changed shape and departed rapidly to the east.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Ocala, FL',
#   'Lat': 29.19,
#   'Lng': -82.14},
#  {'Unnamed: 0': 1872,
#   'SIGHTING_ID': 48,
#   'OCCURRED_DATE': '2024-06-10',
#   'CITY': 'Summerfield',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Bright Triangle Craft Hovering Next to Cloud',
#   'YEAR': 2024,
#   'CITYSTATE': 'Summerfield, NC',
#   'Lat': 36.21,
#   'Lng': -79.9},
#  {'Unnamed: 0': 56859,
#   'SIGHTING_ID': 55,
#   'OCCURRED_DATE': '2024-06-09',
#   'CITY': 'New York',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'silver sphere or disc hovering and rotating',
#   'YEAR': 2024,
#   'CITYSTATE': 'New York, NY',
#   'Lat': 40.71,
#   'Lng': -74.01},
#  {'Unnamed: 0': 35685,
#   'SIGHTING_ID': 53,
#   'OCCURRED_DATE': '2024-06-09',
#   'CITY': 'Satellite Beach',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'I saw an oblong shaped white object above to my left that was low altitude moving from E to W with slight more westerly direction.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Satellite Beach, FL',
#   'Lat': 28.18,
#   'Lng': -80.59},
#  {'Unnamed: 0': 1917,
#   'SIGHTING_ID': 52,
#   'OCCURRED_DATE': '2024-06-09',
#   'CITY': 'Coopersville',
#   'STATE': 'MI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': '8-12 white lights in a straight, horizontal line just above the trees.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Coopersville, MI',
#   'Lat': 43.06,
#   'Lng': -85.93},
#  {'Unnamed: 0': 1925,
#   'SIGHTING_ID': 54,
#   'OCCURRED_DATE': '2024-06-09',
#   'CITY': 'Hillsboro',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Oval shaped object circled around directly above, then dipped down, changed form, became obscured by blurry air and disappeared.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Hillsboro, OR',
#   'Lat': 45.52,
#   'Lng': -122.99},
#  {'Unnamed: 0': 33880,
#   'SIGHTING_ID': 59,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Orlando',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'We were sitting on our balcony and looked up to see 3 oval/spherical objects flying in a triangular formation. .',
#   'YEAR': 2024,
#   'CITYSTATE': 'Orlando, FL',
#   'Lat': 28.54,
#   'Lng': -81.38},
#  {'Unnamed: 0': 2116,
#   'SIGHTING_ID': 63,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Colorado Springs',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Steady Horizontal Light',
#   'YEAR': 2024,
#   'CITYSTATE': 'Colorado Springs, CO',
#   'Lat': 38.83,
#   'Lng': -104.82},
#  {'Unnamed: 0': 2096,
#   'SIGHTING_ID': 62,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Brooksville',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Moving light shining down on me',
#   'YEAR': 2024,
#   'CITYSTATE': 'Brooksville, FL',
#   'Lat': 28.56,
#   'Lng': -82.39},
#  {'Unnamed: 0': 2095,
#   'SIGHTING_ID': 61,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Des Allemands',
#   'STATE': 'LA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Flash',
#   'SUMMARY': 'Flashing light hovering for several minutes above the cloud height that proceeded to move to the north west and vanishing',
#   'YEAR': 2024,
#   'CITYSTATE': 'Des Allemands, LA',
#   'Lat': 29.82,
#   'Lng': -90.48},
#  {'Unnamed: 0': 2029,
#   'SIGHTING_ID': 57,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Corona',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Light appears, bright, catching my attention…. Disappears instantly',
#   'YEAR': 2024,
#   'CITYSTATE': 'Corona, CA',
#   'Lat': 33.88,
#   'Lng': -117.57},
#  {'Unnamed: 0': 2070,
#   'SIGHTING_ID': 60,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Summerville',
#   'STATE': 'SC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'I saw one irregular black object. My picture shows up to 11 maybe more',
#   'YEAR': 2024,
#   'CITYSTATE': 'Summerville, SC',
#   'Lat': 33.02,
#   'Lng': -80.18},
#  {'Unnamed: 0': 2069,
#   'SIGHTING_ID': 58,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Willow Canyon',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'A long blue nebula like haze was spotted while driving down Mt. Lemmon, it turned into white lights (12-16) which rotated around a disc',
#   'YEAR': 2024,
#   'CITYSTATE': 'Willow Canyon, AZ',
#   'Lat': 32.39,
#   'Lng': -110.7},
#  {'Unnamed: 0': 2021,
#   'SIGHTING_ID': 56,
#   'OCCURRED_DATE': '2024-06-08',
#   'CITY': 'Boone',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Craft moved rapidly lighting up on and off',
#   'YEAR': 2024,
#   'CITYSTATE': 'Boone, NC',
#   'Lat': 39.03,
#   'Lng': -92.33},
#  {'Unnamed: 0': 2355,
#   'SIGHTING_ID': 69,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Calverton',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Small grey arc got closer and closer and seemed to become gigantic disk shaped object',
#   'YEAR': 2024,
#   'CITYSTATE': 'Calverton, NY',
#   'Lat': 39.06,
#   'Lng': -76.94},
#  {'Unnamed: 0': 36787,
#   'SIGHTING_ID': 66,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Portland',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'I was sitting on my back porch looking north, and I saw a shimmering object standing still, and then it flew over my apartment.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Portland, OR',
#   'Lat': 45.52,
#   'Lng': -122.68},
#  {'Unnamed: 0': 2352,
#   'SIGHTING_ID': 68,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Manistique',
#   'STATE': 'MI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Was gazing out window and saw strange lights over the lake',
#   'YEAR': 2024,
#   'CITYSTATE': 'Manistique, MI',
#   'Lat': 45.96,
#   'Lng': -86.25},
#  {'Unnamed: 0': 2348,
#   'SIGHTING_ID': 67,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'North Arlington',
#   'STATE': 'NJ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'I look up for one second to look outside and I see a flying donut.',
#   'YEAR': 2024,
#   'CITYSTATE': 'North Arlington, NJ',
#   'Lat': 40.79,
#   'Lng': -74.13},
#  {'Unnamed: 0': 60138,
#   'SIGHTING_ID': 66,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Portland',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'I was sitting on my back porch looking north, and I saw a shimmering object standing still, and then it flew over my apartment.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Portland, OR',
#   'Lat': 43.66,
#   'Lng': -70.25},
#  {'Unnamed: 0': 2344,
#   'SIGHTING_ID': 65,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Orangevale',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Craft sighted two nights in row now',
#   'YEAR': 2024,
#   'CITYSTATE': 'Orangevale, CA',
#   'Lat': 38.68,
#   'Lng': -121.23},
#  {'Unnamed: 0': 2253,
#   'SIGHTING_ID': 64,
#   'OCCURRED_DATE': '2024-06-07',
#   'CITY': 'Salt Lake City',
#   'STATE': 'UT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Rectangle',
#   'SUMMARY': '3 photos taken seconds apart all timed stamped 12:35',
#   'YEAR': 2024,
#   'CITYSTATE': 'Salt Lake City, UT',
#   'Lat': 40.76,
#   'Lng': -111.89},
#  {'Unnamed: 0': 2358,
#   'SIGHTING_ID': 70,
#   'OCCURRED_DATE': '2024-06-06',
#   'CITY': 'Leavenworth',
#   'STATE': 'IN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'UFO above the river.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Leavenworth, IN',
#   'Lat': 39.23,
#   'Lng': -95.03},
#  {'Unnamed: 0': 2368,
#   'SIGHTING_ID': 71,
#   'OCCURRED_DATE': '2024-06-06',
#   'CITY': 'Tigard',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'Observed a TicTac',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tigard, OR',
#   'Lat': 45.43,
#   'Lng': -122.77},
#  {'Unnamed: 0': 2383,
#   'SIGHTING_ID': 72,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Cedartown',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'A strange light arrangement that is not seen on normal aircraft',
#   'YEAR': 2024,
#   'CITYSTATE': 'Cedartown, GA',
#   'Lat': 34.05,
#   'Lng': -85.26},
#  {'Unnamed: 0': 42933,
#   'SIGHTING_ID': 77,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Lakewood',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Crazy maneuvering',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lakewood, CO',
#   'Lat': 39.7,
#   'Lng': -105.08},
#  {'Unnamed: 0': 2390,
#   'SIGHTING_ID': 75,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Spokane',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Zooming at a blistering speed, a streak in the sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Spokane, WA',
#   'Lat': 47.62,
#   'Lng': -117.37},
#  {'Unnamed: 0': 2388,
#   'SIGHTING_ID': 74,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Fort Leavenworth',
#   'STATE': 'KS',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'While looking at vultures circling above I noticed something glinting sunlight above at approximately 65-70° that was silver and silent',
#   'YEAR': 2024,
#   'CITYSTATE': 'Fort Leavenworth, KS',
#   'Lat': 39.35,
#   'Lng': -94.92},
#  {'Unnamed: 0': 2386,
#   'SIGHTING_ID': 73,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Raytown',
#   'STATE': 'MO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Flying object',
#   'YEAR': 2024,
#   'CITYSTATE': 'Raytown, MO',
#   'Lat': 39.01,
#   'Lng': -94.46},
#  {'Unnamed: 0': 2507,
#   'SIGHTING_ID': 76,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Rock Island',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'I saw a large white cylinder in the sky over Rock Island Washington',
#   'YEAR': 2024,
#   'CITYSTATE': 'Rock Island, WA',
#   'Lat': 41.45,
#   'Lng': -90.52},
#  {'Unnamed: 0': 2598,
#   'SIGHTING_ID': 78,
#   'OCCURRED_DATE': '2024-06-05',
#   'CITY': 'Golden',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'We saw a large disc shaped craft with three levels of windows. It hovered silently and then disappeared into thin air.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Golden, CO',
#   'Lat': 39.76,
#   'Lng': -105.22},
#  {'Unnamed: 0': 2391,
#   'SIGHTING_ID': 79,
#   'OCCURRED_DATE': '2024-06-04',
#   'CITY': 'Spokane',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Seen by naked eye and thru camera lens with pictures. Then all of a sudden the camera froze and turned darker blue',
#   'YEAR': 2024,
#   'CITYSTATE': 'Spokane, WA',
#   'Lat': 47.62,
#   'Lng': -117.37},
#  {'Unnamed: 0': 2617,
#   'SIGHTING_ID': 81,
#   'OCCURRED_DATE': '2024-06-04',
#   'CITY': 'Kitty Hawk',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Family noticed a slow moving object with no sound. The object was red and faint to the eye. No sound and slow moving',
#   'YEAR': 2024,
#   'CITYSTATE': 'Kitty Hawk, NC',
#   'Lat': 36.06,
#   'Lng': -75.71},
#  {'Unnamed: 0': 2615,
#   'SIGHTING_ID': 80,
#   'OCCURRED_DATE': '2024-06-04',
#   'CITY': 'Merrill',
#   'STATE': 'IA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Fast moving orbs of light',
#   'YEAR': 2024,
#   'CITYSTATE': 'Merrill, IA',
#   'Lat': 45.18,
#   'Lng': -89.68},
#  {'Unnamed: 0': 2718,
#   'SIGHTING_ID': 86,
#   'OCCURRED_DATE': '2024-06-03',
#   'CITY': 'Baxter',
#   'STATE': 'TN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'An orb like object luminated white, or light yellow light intensely, close to the surface.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Baxter, TN',
#   'Lat': 46.34,
#   'Lng': -94.29},
#  {'Unnamed: 0': 2717,
#   'SIGHTING_ID': 85,
#   'OCCURRED_DATE': '2024-06-03',
#   'CITY': 'Marathon City',
#   'STATE': 'WI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Red non blinking, completely silent light that turned into 3',
#   'YEAR': 2024,
#   'CITYSTATE': 'Marathon City, WI',
#   'Lat': 44.93,
#   'Lng': -89.84},
#  {'Unnamed: 0': 2624,
#   'SIGHTING_ID': 82,
#   'OCCURRED_DATE': '2024-06-03',
#   'CITY': 'Olathe',
#   'STATE': 'KS',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Formation',
#   'SUMMARY': 'A line of hovering blinking lights',
#   'YEAR': 2024,
#   'CITYSTATE': 'Olathe, KS',
#   'Lat': 38.88,
#   'Lng': -94.82},
#  {'Unnamed: 0': 2641,
#   'SIGHTING_ID': 83,
#   'OCCURRED_DATE': '2024-06-03',
#   'CITY': 'Laguna',
#   'STATE': 'NM',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': '2 triangular (like a paper airplane) flying objects',
#   'YEAR': 2024,
#   'CITYSTATE': 'Laguna, NM',
#   'Lat': 38.42,
#   'Lng': -121.42},
#  {'Unnamed: 0': 2643,
#   'SIGHTING_ID': 84,
#   'OCCURRED_DATE': '2024-06-03',
#   'CITY': 'Nashville',
#   'STATE': 'TN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Morphing UAP',
#   'YEAR': 2024,
#   'CITYSTATE': 'Nashville, TN',
#   'Lat': 36.17,
#   'Lng': -86.78},
#  {'Unnamed: 0': 2719,
#   'SIGHTING_ID': 87,
#   'OCCURRED_DATE': '2024-06-02',
#   'CITY': 'Omaha',
#   'STATE': 'NE',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Orb dimming and brightening, then making high speed maneuvers.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Omaha, NE',
#   'Lat': 41.26,
#   'Lng': -95.94},
#  {'Unnamed: 0': 2765,
#   'SIGHTING_ID': 88,
#   'OCCURRED_DATE': '2024-06-02',
#   'CITY': 'Davenport',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Diamond',
#   'SUMMARY': 'In daylight a black object stopped in the sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Davenport, CA',
#   'Lat': 41.52,
#   'Lng': -90.58},
#  {'Unnamed: 0': 33647,
#   'SIGHTING_ID': 89,
#   'OCCURRED_DATE': '2024-06-02',
#   'CITY': 'Kennesaw',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Saw two objects in sky, one floated and one sped away within half a second.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Kennesaw, GA',
#   'Lat': 34.02,
#   'Lng': -84.62},
#  {'Unnamed: 0': 2817,
#   'SIGHTING_ID': 90,
#   'OCCURRED_DATE': '2024-06-02',
#   'CITY': 'Bloomington',
#   'STATE': 'IN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Caught on Drone Video',
#   'YEAR': 2024,
#   'CITYSTATE': 'Bloomington, IN',
#   'Lat': 44.84,
#   'Lng': -93.3},
#  {'Unnamed: 0': 2853,
#   'SIGHTING_ID': 91,
#   'OCCURRED_DATE': '2024-06-01',
#   'CITY': 'Hamburg',
#   'STATE': 'NJ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Flash',
#   'SUMMARY': 'High altitude stationary object reflecting sunlight every few seconds.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Hamburg, NJ',
#   'Lat': 53.55,
#   'Lng': 10.0},
#  {'Unnamed: 0': 2866,
#   'SIGHTING_ID': 92,
#   'OCCURRED_DATE': '2024-06-01',
#   'CITY': 'Tacoma',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'It was seen by two people and it was the best feeling ever',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tacoma, WA',
#   'Lat': 47.25,
#   'Lng': -122.44},
#  {'Unnamed: 0': 49471,
#   'SIGHTING_ID': 93,
#   'OCCURRED_DATE': '2024-06-01',
#   'CITY': 'Huntsville',
#   'STATE': 'TX',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Made strange movements then went 90 degrees right then 90 degrees left in about a second.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Huntsville, TX',
#   'Lat': 34.73,
#   'Lng': -86.59},
#  {'Unnamed: 0': 2989,
#   'SIGHTING_ID': 95,
#   'OCCURRED_DATE': '2024-06-01',
#   'CITY': 'East Hartford',
#   'STATE': 'CT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Large craft seen in the sky on Main Street in East Hartford, CT. Craft seen changing directions and hovering.',
#   'YEAR': 2024,
#   'CITYSTATE': 'East Hartford, CT',
#   'Lat': 41.78,
#   'Lng': -72.61},
#  {'Unnamed: 0': 2983,
#   'SIGHTING_ID': 94,
#   'OCCURRED_DATE': '2024-06-01',
#   'CITY': 'Perkasie',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Cigar shaped and slow moving then silver sun reflection disappearing into low lying clouds',
#   'YEAR': 2024,
#   'CITYSTATE': 'Perkasie, PA',
#   'Lat': 40.37,
#   'Lng': -75.29},
#  {'Unnamed: 0': 3361,
#   'SIGHTING_ID': 113,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Camp Verde',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Diamond',
#   'SUMMARY': 'Diamond shaped white center glow/haze',
#   'YEAR': 2024,
#   'CITYSTATE': 'Camp Verde, AZ',
#   'Lat': 34.56,
#   'Lng': -111.85},
#  {'Unnamed: 0': 39150,
#   'SIGHTING_ID': 98,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Apple Valley',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Second time seeing same craft in 7 day period',
#   'YEAR': 2024,
#   'CITYSTATE': 'Apple Valley, CA',
#   'Lat': 34.5,
#   'Lng': -117.19},
#  {'Unnamed: 0': 2996,
#   'SIGHTING_ID': 96,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Lincoln City',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Leaving store and seen a shimmering white object floating through the sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lincoln City, OR',
#   'Lat': 44.96,
#   'Lng': -124.02},
#  {'Unnamed: 0': 34441,
#   'SIGHTING_ID': 116,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Tucson',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Hovering blurry orb with dilating pinpoint of white light in the center',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tucson, AZ',
#   'Lat': 32.22,
#   'Lng': -110.93},
#  {'Unnamed: 0': 3165,
#   'SIGHTING_ID': 104,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Lenoir',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Rounded shiny object which disappeared after 3 min or so observation',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lenoir, NC',
#   'Lat': 35.23,
#   'Lng': -77.65},
#  {'Unnamed: 0': 3115,
#   'SIGHTING_ID': 103,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Tempe',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Round white object with white shaped aura around each side',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tempe, AZ',
#   'Lat': 33.41,
#   'Lng': -111.91},
#  {'Unnamed: 0': 39151,
#   'SIGHTING_ID': 101,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Apple Valley',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Bright object flying west to east',
#   'YEAR': 2024,
#   'CITYSTATE': 'Apple Valley, CA',
#   'Lat': 34.5,
#   'Lng': -117.19},
#  {'Unnamed: 0': 32779,
#   'SIGHTING_ID': 119,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Henderson',
#   'STATE': 'NV',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Came out of the north Las Vegas Valley and headed south toward Anthem in Henderson NV a white ball with a bright light in the center',
#   'YEAR': 2024,
#   'CITYSTATE': 'Henderson, NV',
#   'Lat': 36.04,
#   'Lng': -114.98},
#  {'Unnamed: 0': 3357,
#   'SIGHTING_ID': 110,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Tonto Basin',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Orb of light floating from north to south. Extremely bright, orb of light around it like a plane in the clouds but there were no clouds',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tonto Basin, AZ',
#   'Lat': 33.83,
#   'Lng': -111.29},
#  {'Unnamed: 0': 38177,
#   'SIGHTING_ID': 106,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Myrtle Beach',
#   'STATE': 'SC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Blinking light. It blinked very fast every couple of seconds. Blinked so fast impossible to freeze frame to see it.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Myrtle Beach, SC',
#   'Lat': 33.69,
#   'Lng': -78.89},
#  {'Unnamed: 0': 3341,
#   'SIGHTING_ID': 109,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Prescott',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Small object seen hovering above with orb/fog like light surrounding it that changed in size, color, and intensity',
#   'YEAR': 2024,
#   'CITYSTATE': 'Prescott, AZ',
#   'Lat': 34.54,
#   'Lng': -112.47},
#  {'Unnamed: 0': 62481,
#   'SIGHTING_ID': 97,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Fresno',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'High in the sky a circular dark white center with lighter white fan shape on either side of the circle',
#   'YEAR': 2024,
#   'CITYSTATE': 'Fresno, CA',
#   'Lat': 36.67,
#   'Lng': -119.83},
#  {'Unnamed: 0': 3367,
#   'SIGHTING_ID': 114,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Grass Valley',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'No noise, one speed, no blinking lights and not a normal satellite orbit.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Grass Valley, CA',
#   'Lat': 39.22,
#   'Lng': -121.06},
#  {'Unnamed: 0': 3107,
#   'SIGHTING_ID': 100,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Tonawanda',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Huge white Orb seen in Western NY that suddenly appeared, then moved Northwest and began to move away and fade away.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tonawanda, NY',
#   'Lat': 42.98,
#   'Lng': -78.88},
#  {'Unnamed: 0': 3104,
#   'SIGHTING_ID': 99,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Red Rock',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'At night, a white glow.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Red Rock, AZ',
#   'Lat': -29.98,
#   'Lng': 153.23},
#  {'Unnamed: 0': 3172,
#   'SIGHTING_ID': 105,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Sheboygan',
#   'STATE': 'WI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Saw what looked like a square box carrying a balloon underneath it traveling north',
#   'YEAR': 2024,
#   'CITYSTATE': 'Sheboygan, WI',
#   'Lat': 43.73,
#   'Lng': -87.93},
#  {'Unnamed: 0': 3340,
#   'SIGHTING_ID': 108,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Lake Montezuma',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Saw a large light surrounded by mist or clouds. Moving -it disappeared then showed up across the sky with a big flare.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lake Montezuma, AZ',
#   'Lat': 34.63,
#   'Lng': -111.78},
#  {'Unnamed: 0': 25333,
#   'SIGHTING_ID': 102,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Sacramento',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Triangle going way beyond the speed of sound heading north and no sound or sonic boom.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Sacramento, CA',
#   'Lat': 38.47,
#   'Lng': -121.32},
#  {'Unnamed: 0': 512,
#   'SIGHTING_ID': 112,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Gunnison',
#   'STATE': 'UT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Sitting around a campfire seen moving erratically around. Then just gone',
#   'YEAR': 2024,
#   'CITYSTATE': 'Gunnison, UT',
#   'Lat': 38.7,
#   'Lng': -107.07},
#  {'Unnamed: 0': 3594,
#   'SIGHTING_ID': 117,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Maricopa',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Appeared west out of nowhere, no clouds in sky, flew steady above us east/ disappeared, reappeared for a few seconds then disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Maricopa, AZ',
#   'Lat': 33.06,
#   'Lng': -112.05},
#  {'Unnamed: 0': 3324,
#   'SIGHTING_ID': 107,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Hemet',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Bright White Light with Foggy Glow but clear skys',
#   'YEAR': 2024,
#   'CITYSTATE': 'Hemet, CA',
#   'Lat': 33.75,
#   'Lng': -116.97},
#  {'Unnamed: 0': 3718,
#   'SIGHTING_ID': 120,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Flagstaff',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Inexplicable, variable very fast and bright pinpoint light moving faster than satellite, symmetric halo/no trail',
#   'YEAR': 2024,
#   'CITYSTATE': 'Flagstaff, AZ',
#   'Lat': 35.2,
#   'Lng': -111.65},
#  {'Unnamed: 0': 3623,
#   'SIGHTING_ID': 118,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Surprise',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Fireball',
#   'SUMMARY': 'Looked like a huge fuzzy white object',
#   'YEAR': 2024,
#   'CITYSTATE': 'Surprise, AZ',
#   'Lat': 33.63,
#   'Lng': -112.33},
#  {'Unnamed: 0': 3381,
#   'SIGHTING_ID': 115,
#   'OCCURRED_DATE': '2024-05-31',
#   'CITY': 'Summit',
#   'STATE': 'UT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Bright white light with a blue orb moved low and slowly across sky before disappearing into blue dust.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Summit, UT',
#   'Lat': 41.12,
#   'Lng': -81.53},
#  {'Unnamed: 0': 3737,
#   'SIGHTING_ID': 124,
#   'OCCURRED_DATE': '2024-05-30',
#   'CITY': 'Junction City',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'This has been ongoing',
#   'YEAR': 2024,
#   'CITYSTATE': 'Junction City, OR',
#   'Lat': 39.03,
#   'Lng': -96.83},
#  {'Unnamed: 0': 3735,
#   'SIGHTING_ID': 123,
#   'OCCURRED_DATE': '2024-05-30',
#   'CITY': 'Shingle Springs',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Brilliant Round Orange light slowly coming in from the Southeast and heading Northwest.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Shingle Springs, CA',
#   'Lat': 38.67,
#   'Lng': -120.93},
#  {'Unnamed: 0': 3730,
#   'SIGHTING_ID': 122,
#   'OCCURRED_DATE': '2024-05-30',
#   'CITY': 'Oak Park',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Pinpoint of light appeared at mountain ridge, streaked across sky, grew bigger than the moon within 0.3 seconds',
#   'YEAR': 2024,
#   'CITYSTATE': 'Oak Park, CA',
#   'Lat': 41.88,
#   'Lng': -87.78},
#  {'Unnamed: 0': 3729,
#   'SIGHTING_ID': 121,
#   'OCCURRED_DATE': '2024-05-30',
#   'CITY': 'Croton-on-Hudson',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'A star I thought, that I was wishing on, and it suddenly moved to the left and hung there, then it moved to the right. Then back .',
#   'YEAR': 2024,
#   'CITYSTATE': 'Croton-on-Hudson, NY',
#   'Lat': 41.21,
#   'Lng': -73.89},
#  {'Unnamed: 0': 25653,
#   'SIGHTING_ID': 126,
#   'OCCURRED_DATE': '2024-05-29',
#   'CITY': 'Los Angeles',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Fireball',
#   'SUMMARY': 'Looked like a rocket launch but with no tail',
#   'YEAR': 2024,
#   'CITYSTATE': 'Los Angeles, CA',
#   'Lat': 34.05,
#   'Lng': -118.24},
#  {'Unnamed: 0': 3814,
#   'SIGHTING_ID': 128,
#   'OCCURRED_DATE': '2024-05-29',
#   'CITY': 'Kinston',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'It was 1 craft then it split in half.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Kinston, NC',
#   'Lat': 35.26,
#   'Lng': -77.58},
#  {'Unnamed: 0': 3765,
#   'SIGHTING_ID': 127,
#   'OCCURRED_DATE': '2024-05-29',
#   'CITY': 'Milford',
#   'STATE': 'CT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Saw an object go by very fast then came to a complete stop. It was changing shapes and looked like it had some kind of energy field',
#   'YEAR': 2024,
#   'CITYSTATE': 'Milford, CT',
#   'Lat': 41.22,
#   'Lng': -73.06},
#  {'Unnamed: 0': 3750,
#   'SIGHTING_ID': 125,
#   'OCCURRED_DATE': '2024-05-29',
#   'CITY': 'Windham',
#   'STATE': 'ME',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Regular intervals: ≥8 lights traveled one at a time moving N to S high in atmosphere. No tail/flickering. Disappeared ⅝ way across.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Windham, ME',
#   'Lat': 41.83,
#   'Lng': -72.0},
#  {'Unnamed: 0': 40817,
#   'SIGHTING_ID': 129,
#   'OCCURRED_DATE': '2024-05-29',
#   'CITY': 'Philadelphia',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Star',
#   'SUMMARY': 'I was sitting in my car writing music and watching the stars. I noticed one moving and recorded it traveling unusual pattern',
#   'YEAR': 2024,
#   'CITYSTATE': 'Philadelphia, PA',
#   'Lat': 39.95,
#   'Lng': -75.16},
#  {'Unnamed: 0': 3919,
#   'SIGHTING_ID': 132,
#   'OCCURRED_DATE': '2024-05-28',
#   'CITY': 'Ormond Beach',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Oval-shaped, no wings, shiny chrome, flying higher than the airplanes',
#   'YEAR': 2024,
#   'CITYSTATE': 'Ormond Beach, FL',
#   'Lat': 29.29,
#   'Lng': -81.06},
#  {'Unnamed: 0': 3915,
#   'SIGHTING_ID': 131,
#   'OCCURRED_DATE': '2024-05-28',
#   'CITY': 'Lake George',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cube',
#   'SUMMARY': 'Two “women” were walking down the road and two white cubes appeared and took them up into the sky and they disappeared.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lake George, NY',
#   'Lat': 38.98,
#   'Lng': -105.36},
#  {'Unnamed: 0': 3937,
#   'SIGHTING_ID': 133,
#   'OCCURRED_DATE': '2024-05-27',
#   'CITY': 'Overland',
#   'STATE': 'MO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Diamond',
#   'SUMMARY': '7 then 5 then one alone all white diamonds with bright red-orange inner circle no noise moved left to right all three groups vanished',
#   'YEAR': 2024,
#   'CITYSTATE': 'Overland, MO',
#   'Lat': 38.7,
#   'Lng': -90.36},
#  {'Unnamed: 0': 3940,
#   'SIGHTING_ID': 134,
#   'OCCURRED_DATE': '2024-05-27',
#   'CITY': 'Susanville',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Pairs of white lights that slowly disappear going straight up',
#   'YEAR': 2024,
#   'CITYSTATE': 'Susanville, CA',
#   'Lat': 40.42,
#   'Lng': -120.65},
#  {'Unnamed: 0': 3946,
#   'SIGHTING_ID': 135,
#   'OCCURRED_DATE': '2024-05-26',
#   'CITY': 'Northport',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Saw a UAP at northport middle school on 5/26/24 at 5pm',
#   'YEAR': 2024,
#   'CITYSTATE': 'Northport, NY',
#   'Lat': 33.23,
#   'Lng': -87.58},
#  {'Unnamed: 0': 32780,
#   'SIGHTING_ID': 140,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'Henderson',
#   'STATE': 'NV',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'I was traveling on an comercial flight when I look up in the window of the airplane and saw 2 lights that transformed into 3.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Henderson, NV',
#   'Lat': 36.04,
#   'Lng': -114.98},
#  {'Unnamed: 0': 3955,
#   'SIGHTING_ID': 137,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'Cumming',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'Very high up slow pulsing cylinder',
#   'YEAR': 2024,
#   'CITYSTATE': 'Cumming, GA',
#   'Lat': 34.21,
#   'Lng': -84.14},
#  {'Unnamed: 0': 3990,
#   'SIGHTING_ID': 138,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'Delhi',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'Saw a cylindrical object that was stationary and it disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Delhi, CA',
#   'Lat': 28.67,
#   'Lng': 77.22},
#  {'Unnamed: 0': 3996,
#   'SIGHTING_ID': 141,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'Paris',
#   'STATE': 'ME',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Saw craft with low light move quick across are observe. Then it look as if it turned on thrusters to push itself away into space',
#   'YEAR': 2024,
#   'CITYSTATE': 'Paris, ME',
#   'Lat': 48.85,
#   'Lng': 2.35},
#  {'Unnamed: 0': 3992,
#   'SIGHTING_ID': 139,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'West Islip',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Weekend of Bethpage Airshow - was looking for anything in the sky. Saw UAP.',
#   'YEAR': 2024,
#   'CITYSTATE': 'West Islip, NY',
#   'Lat': 40.71,
#   'Lng': -73.31},
#  {'Unnamed: 0': 3952,
#   'SIGHTING_ID': 136,
#   'OCCURRED_DATE': '2024-05-25',
#   'CITY': 'Mulberry',
#   'STATE': 'IN',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Solid bright light that faded and disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Mulberry, IN',
#   'Lat': 27.9,
#   'Lng': -81.97},
#  {'Unnamed: 0': 4019,
#   'SIGHTING_ID': 144,
#   'OCCURRED_DATE': '2024-05-24',
#   'CITY': 'Chatham',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Black stone like object disappear',
#   'YEAR': 2024,
#   'CITYSTATE': 'Chatham, NY',
#   'Lat': 51.38,
#   'Lng': 0.53},
#  {'Unnamed: 0': 4008,
#   'SIGHTING_ID': 142,
#   'OCCURRED_DATE': '2024-05-24',
#   'CITY': 'Wantagh',
#   'STATE': 'NY',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Cigar shape lasted 5 mins up in sky next to multiple planes that went by and when ran for camera and binoculars it disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Wantagh, NY',
#   'Lat': 40.68,
#   'Lng': -73.51},
#  {'Unnamed: 0': 4015,
#   'SIGHTING_ID': 143,
#   'OCCURRED_DATE': '2024-05-24',
#   'CITY': 'Loomis',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Recorded video of a glowing green-white orb over new Costco in Loomis, CA.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Loomis, CA',
#   'Lat': 38.82,
#   'Lng': -121.19},
#  {'Unnamed: 0': 37562,
#   'SIGHTING_ID': 155,
#   'OCCURRED_DATE': '2024-05-23',
#   'CITY': 'Tempe',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Saw an object in the sky of a very different shape',
#   'YEAR': 2024,
#   'CITYSTATE': 'Tempe, AZ',
#   'Lat': 33.41,
#   'Lng': -111.91},
#  {'Unnamed: 0': 49586,
#   'SIGHTING_ID': 158,
#   'OCCURRED_DATE': '2024-05-23',
#   'CITY': 'Phoenix',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
# ...
#   'SIGHTING_ID': 981,
#   'OCCURRED_DATE': '2024-01-03',
#   'CITY': 'Port St. Lucie',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Fireball',
#   'SUMMARY': 'A large cloud appeared and had a Bright light called for wife to come out to look and a bright light appered out of the cloud',
#   'YEAR': 2024,
#   'CITYSTATE': 'Port St. Lucie, FL',
#   'Lat': 27.29,
#   'Lng': -80.35},
#  {'Unnamed: 0': 14461,
#   'SIGHTING_ID': 983,
#   'OCCURRED_DATE': '2024-01-03',
#   'CITY': 'Lake Havasu City',
#   'STATE': 'AZ',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'We were driving up Jamaica Boulevard when we saw the first sighting and then saw it 3 more times',
#   'YEAR': 2024,
#   'CITYSTATE': 'Lake Havasu City, AZ',
#   'Lat': 34.48,
#   'Lng': -114.32},
#  {'Unnamed: 0': 14372,
#   'SIGHTING_ID': 980,
#   'OCCURRED_DATE': '2024-01-03',
#   'CITY': 'Marysville',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Triangle',
#   'SUMMARY': 'Large object 200 yards away hovering above the trees',
#   'YEAR': 2024,
#   'CITYSTATE': 'Marysville, WA',
#   'Lat': 48.05,
#   'Lng': -122.18},
#  {'Unnamed: 0': 23,
#   'SIGHTING_ID': 984,
#   'OCCURRED_DATE': '2024-01-02',
#   'CITY': 'Oklahoma City',
#   'STATE': 'OK',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Seen the blue white oval object dart right to left from upstairs windows. When I fist witnessed It was stationary.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Oklahoma City, OK',
#   'Lat': 35.47,
#   'Lng': -97.52},
#  {'Unnamed: 0': 14483,
#   'SIGHTING_ID': 986,
#   'OCCURRED_DATE': '2024-01-02',
#   'CITY': 'Newtown',
#   'STATE': 'CT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Elongated white light moving slowly or not at all, which then also displayed a series of colored lights in a line as I got closer.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Newtown, CT',
#   'Lat': -33.9,
#   'Lng': 151.18},
#  {'Unnamed: 0': 10164,
#   'SIGHTING_ID': 985,
#   'OCCURRED_DATE': '2024-01-02',
#   'CITY': 'Plymouth',
#   'STATE': 'CT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'Ferris wheel shaped craft floating in the South Eastern sky',
#   'YEAR': 2024,
#   'CITYSTATE': 'Plymouth, CT',
#   'Lat': 41.83,
#   'Lng': -70.83},
#  {'Unnamed: 0': 14492,
#   'SIGHTING_ID': 987,
#   'OCCURRED_DATE': '2024-01-02',
#   'CITY': 'Richlandtown',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Observed a dull, reddish brown colored cigar-shaped object approach from Southwest of Richlandtown, PA and move Northeast',
#   'YEAR': 2024,
#   'CITYSTATE': 'Richlandtown, PA',
#   'Lat': 40.47,
#   'Lng': -75.32},
#  {'Unnamed: 0': 7037,
#   'SIGHTING_ID': 993,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Ann Arbor',
#   'STATE': 'MI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'A bright orange light hovered motionless shining in my window.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Ann Arbor, MI',
#   'Lat': 42.28,
#   'Lng': -83.74},
#  {'Unnamed: 0': 12213,
#   'SIGHTING_ID': 997,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Costa Mesa',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': '3-6 here daily each slightly different . They are bright and right in front for everyone to see.How cone I hear nothing about at all',
#   'YEAR': 2024,
#   'CITYSTATE': 'Costa Mesa, CA',
#   'Lat': 33.64,
#   'Lng': -117.92},
#  {'Unnamed: 0': 5053,
#   'SIGHTING_ID': 995,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Manteca',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Three orbs with plane near by, orbs crisscrossing high speed',
#   'YEAR': 2024,
#   'CITYSTATE': 'Manteca, CA',
#   'Lat': 37.8,
#   'Lng': -121.22},
#  {'Unnamed: 0': 41221,
#   'SIGHTING_ID': 996,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Bradenton',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'light came down, move sideways then back upwards until it disappeared',
#   'YEAR': 2024,
#   'CITYSTATE': 'Bradenton, FL',
#   'Lat': 27.5,
#   'Lng': -82.57},
#  {'Unnamed: 0': 14580,
#   'SIGHTING_ID': 990,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Eagle',
#   'STATE': 'ID',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Star',
#   'SUMMARY': 'Five red stars',
#   'YEAR': 2024,
#   'CITYSTATE': 'Eagle, ID',
#   'Lat': 43.7,
#   'Lng': -116.35},
#  {'Unnamed: 0': 14601,
#   'SIGHTING_ID': 994,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Flagler',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Three orbs fluctuating randomly from dim to bright accelerating and slowing down maintains distance from vehicle while traveling.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Flagler, CO',
#   'Lat': 29.46,
#   'Lng': -81.29},
#  {'Unnamed: 0': 14592,
#   'SIGHTING_ID': 991,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Red Bluff',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Fireball',
#   'SUMMARY': '8-10 orange fireball-like lights in the western California sky shortly after midnight.',
#   'YEAR': 2024,
#   'CITYSTATE': 'Red Bluff, CA',
#   'Lat': 40.18,
#   'Lng': -122.24},
#  {'Unnamed: 0': 14493,
#   'SIGHTING_ID': 989,
#   'OCCURRED_DATE': '2024-01-01',
#   'CITY': 'Aurora',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Witnessed a UFO flying',
#   'YEAR': 2024,
#   'CITYSTATE': 'Aurora, CO',
#   'Lat': 39.73,
#   'Lng': -104.83},
#  {'Unnamed: 0': 14629,
#   'SIGHTING_ID': 1004,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Allentown',
#   'STATE': 'PA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Orange light in the sky moving quickly from northwest to Southeast direction',
#   'YEAR': 2023,
#   'CITYSTATE': 'Allentown, PA',
#   'Lat': 40.61,
#   'Lng': -75.49},
#  {'Unnamed: 0': 14621,
#   'SIGHTING_ID': 1003,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Muskego',
#   'STATE': 'WI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'A formation of five focused areas of light, objects-, moving incredibly fast from west to east, and east to west',
#   'YEAR': 2023,
#   'CITYSTATE': 'Muskego, WI',
#   'Lat': 42.91,
#   'Lng': -88.14},
#  {'Unnamed: 0': 14659,
#   'SIGHTING_ID': 1005,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Wesley Chapel',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Bright light',
#   'YEAR': 2023,
#   'CITYSTATE': 'Wesley Chapel, FL',
#   'Lat': 28.24,
#   'Lng': -82.33},
#  {'Unnamed: 0': 36287,
#   'SIGHTING_ID': 1001,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Boise',
#   'STATE': 'ID',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Vertical, black, slow moving/hovering, then quickly moved towards the mountains and lost sight.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Boise, ID',
#   'Lat': 43.61,
#   'Lng': -116.2},
#  {'Unnamed: 0': 14618,
#   'SIGHTING_ID': 1002,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Broadway',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Three orange orbs two in front one trailing behind came directly over our home going generally west to east',
#   'YEAR': 2023,
#   'CITYSTATE': 'Broadway, NC',
#   'Lat': 38.61,
#   'Lng': -78.8},
#  {'Unnamed: 0': 14604,
#   'SIGHTING_ID': 998,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Hartselle',
#   'STATE': 'AL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'High Altitude Craft, Fires object, Capable of stopping.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Hartselle, AL',
#   'Lat': 34.44,
#   'Lng': -86.94},
#  {'Unnamed: 0': 14609,
#   'SIGHTING_ID': 1000,
#   'OCCURRED_DATE': '2023-12-31',
#   'CITY': 'Lake Wales',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cylinder',
#   'SUMMARY': 'Huge Invasion Size Fleet',
#   'YEAR': 2023,
#   'CITYSTATE': 'Lake Wales, FL',
#   'Lat': 27.9,
#   'Lng': -81.59},
#  {'Unnamed: 0': 14672,
#   'SIGHTING_ID': 1006,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Collinsville',
#   'STATE': 'IL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Diamond',
#   'SUMMARY': 'Black and shaped like a diamond with 5 lights underneath. One blinking, the other 4 solid.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Collinsville, IL',
#   'Lat': 38.67,
#   'Lng': -89.98},
#  {'Unnamed: 0': 49180,
#   'SIGHTING_ID': 1007,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Boca Raton',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'It wavered and seemed way to large to be a drone',
#   'YEAR': 2023,
#   'CITYSTATE': 'Boca Raton, FL',
#   'Lat': 26.36,
#   'Lng': -80.08},
#  {'Unnamed: 0': 14717,
#   'SIGHTING_ID': 1009,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Beaverton',
#   'STATE': 'OR',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': 'Unidentified formation of lights seen on walk with a friend. Slowly rotating, & massive. Had a contour like it was a disk on its side.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Beaverton, OR',
#   'Lat': 45.49,
#   'Lng': -122.8},
#  {'Unnamed: 0': 55488,
#   'SIGHTING_ID': 1010,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Chicago',
#   'STATE': 'IL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Cigar',
#   'SUMMARY': 'Very bright rocket with a few objects off to the left',
#   'YEAR': 2023,
#   'CITYSTATE': 'Chicago, IL',
#   'Lat': 41.85,
#   'Lng': -87.65},
#  {'Unnamed: 0': 14757,
#   'SIGHTING_ID': 1011,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Diamond Bar',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'I was asleep and I heard a low rumbling from outside',
#   'YEAR': 2023,
#   'CITYSTATE': 'Diamond Bar, CA',
#   'Lat': 34.03,
#   'Lng': -117.81},
#  {'Unnamed: 0': 14716,
#   'SIGHTING_ID': 1008,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Humptulips',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Unknown',
#   'SUMMARY': 'Formation of around ten diamond shape lights in the sky',
#   'YEAR': 2023,
#   'CITYSTATE': 'Humptulips, WA',
#   'Lat': 47.23,
#   'Lng': -123.96},
#  {'Unnamed: 0': 14761,
#   'SIGHTING_ID': 1012,
#   'OCCURRED_DATE': '2023-12-30',
#   'CITY': 'Baraboo',
#   'STATE': 'WI',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Increased UFO activity in Wisconsin',
#   'YEAR': 2023,
#   'CITYSTATE': 'Baraboo, WI',
#   'Lat': 43.47,
#   'Lng': -89.74},
#  {'Unnamed: 0': 13238,
#   'SIGHTING_ID': 1014,
#   'OCCURRED_DATE': '2023-12-29',
#   'CITY': 'Sterling',
#   'STATE': 'IL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Light was elevated above tree line, brighter than Venus. It disappeared, by reduction, and appearing to reappear 10-15° to the right.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Sterling, IL',
#   'Lat': 39.01,
#   'Lng': -77.43},
#  {'Unnamed: 0': 14770,
#   'SIGHTING_ID': 1013,
#   'OCCURRED_DATE': '2023-12-29',
#   'CITY': 'Missoula',
#   'STATE': 'MT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': "Looked like a string of lights after a rectangular shaped object sort of like a piece of paper angled like you’re looking at it's edge",
#   'YEAR': 2023,
#   'CITYSTATE': 'Missoula, MT',
#   'Lat': 47.02,
#   'Lng': -113.8},
#  {'Unnamed: 0': 14805,
#   'SIGHTING_ID': 1015,
#   'OCCURRED_DATE': '2023-12-29',
#   'CITY': 'Alta',
#   'STATE': 'IA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Saw multicolor flashing object staying in place',
#   'YEAR': 2023,
#   'CITYSTATE': 'Alta, IA',
#   'Lat': 69.97,
#   'Lng': 23.27},
#  {'Unnamed: 0': 14814,
#   'SIGHTING_ID': 1018,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Casselberry',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Saw two different moving items in the air. Moved under cloud cover.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Casselberry, FL',
#   'Lat': 28.68,
#   'Lng': -81.33},
#  {'Unnamed: 0': 14806,
#   'SIGHTING_ID': 1016,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Kannapolis',
#   'STATE': 'NC',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Oval',
#   'SUMMARY': 'Oval object with lights moving across the sky. The lights turned off & it became difficult to see it moving.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Kannapolis, NC',
#   'Lat': 35.49,
#   'Lng': -80.62},
#  {'Unnamed: 0': 14822,
#   'SIGHTING_ID': 1020,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Merritt Island',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Orb flying fades away',
#   'YEAR': 2023,
#   'CITYSTATE': 'Merritt Island, FL',
#   'Lat': 28.54,
#   'Lng': -80.67},
#  {'Unnamed: 0': 14833,
#   'SIGHTING_ID': 1021,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Byron',
#   'STATE': 'GA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Circle',
#   'SUMMARY': 'We heard a high frequency noise getting closer and closer we ran to the back door then we look up an see an orb above the trees',
#   'YEAR': 2023,
#   'CITYSTATE': 'Byron, GA',
#   'Lat': 44.03,
#   'Lng': -92.65},
#  {'Unnamed: 0': 14416,
#   'SIGHTING_ID': 1017,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Port St. Lucie',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Star',
#   'SUMMARY': 'Object moving erratically over rocket launch.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Port St. Lucie, FL',
#   'Lat': 27.29,
#   'Lng': -80.35},
#  {'Unnamed: 0': 14820,
#   'SIGHTING_ID': 1019,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Windermere',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Fireball',
#   'SUMMARY': 'Multiple burning lights in the sky moving erratically.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Windermere, FL',
#   'Lat': 54.38,
#   'Lng': -2.91},
#  {'Unnamed: 0': 14847,
#   'SIGHTING_ID': 1022,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Tehachapi',
#   'STATE': 'CA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': '3 objects appearing shortly after shooting star event',
#   'YEAR': 2023,
#   'CITYSTATE': 'Tehachapi, CA',
#   'Lat': 35.13,
#   'Lng': -118.45},
#  {'Unnamed: 0': 14863,
#   'SIGHTING_ID': 1023,
#   'OCCURRED_DATE': '2023-12-28',
#   'CITY': 'Tolono',
#   'STATE': 'IL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Disk',
#   'SUMMARY': '2 long disc like things in the sky, took ten mins too leave',
#   'YEAR': 2023,
#   'CITYSTATE': 'Tolono, IL',
#   'Lat': 39.99,
#   'Lng': -88.26},
#  {'Unnamed: 0': 40064,
#   'SIGHTING_ID': 1024,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'Salt Lake City',
#   'STATE': 'UT',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Lights don’t set behind eastern mountains in the morning',
#   'YEAR': 2023,
#   'CITYSTATE': 'Salt Lake City, UT',
#   'Lat': 40.76,
#   'Lng': -111.89},
#  {'Unnamed: 0': 14870,
#   'SIGHTING_ID': 1026,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'La Jara',
#   'STATE': 'CO',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Orb',
#   'SUMMARY': 'Bright lights that got extremely bright then dimmed out',
#   'YEAR': 2023,
#   'CITYSTATE': 'La Jara, CO',
#   'Lat': 37.28,
#   'Lng': -105.96},
#  {'Unnamed: 0': 14871,
#   'SIGHTING_ID': 1028,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'Country Club Hills',
#   'STATE': 'IL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'It appeared to be as small as a star but was moving, when I zoomed in it was changing shapes',
#   'YEAR': 2023,
#   'CITYSTATE': 'Country Club Hills, IL',
#   'Lat': 41.57,
#   'Lng': -87.72},
#  {'Unnamed: 0': 14873,
#   'SIGHTING_ID': 1029,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'Hawthorne',
#   'STATE': 'NV',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Sphere',
#   'SUMMARY': 'Orange/white changing orb',
#   'YEAR': 2023,
#   'CITYSTATE': 'Hawthorne, NV',
#   'Lat': 33.92,
#   'Lng': -118.35},
#  {'Unnamed: 0': 5859,
#   'SIGHTING_ID': 1027,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'Boston',
#   'STATE': 'MA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'Large floating object that appeared to keep changing from one object to four different objects',
#   'YEAR': 2023,
#   'CITYSTATE': 'Boston, MA',
#   'Lat': 42.36,
#   'Lng': -71.06},
#  {'Unnamed: 0': 14864,
#   'SIGHTING_ID': 1025,
#   'OCCURRED_DATE': '2023-12-27',
#   'CITY': 'Pullman',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Other',
#   'SUMMARY': 'Plane like craft flying at light speed',
#   'YEAR': 2023,
#   'CITYSTATE': 'Pullman, WA',
#   'Lat': 46.73,
#   'Lng': -117.18},
#  {'Unnamed: 0': 14883,
#   'SIGHTING_ID': 1031,
#   'OCCURRED_DATE': '2023-12-26',
#   'CITY': 'Bunnell',
#   'STATE': 'FL',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Changing',
#   'SUMMARY': 'What appeared as bright star like points of light which would suddenly appear increasing in brightness and then fade away.',
#   'YEAR': 2023,
#   'CITYSTATE': 'Bunnell, FL',
#   'Lat': 29.47,
#   'Lng': -81.26},
#  {'Unnamed: 0': 2869,
#   'SIGHTING_ID': 1035,
#   'OCCURRED_DATE': '2023-12-25',
#   'CITY': 'Tacoma',
#   'STATE': 'WA',
#   'COUNTRY': 'USA',
#   'SHAPE': 'Light',
#   'SUMMARY': 'Lights shinning thru upper bedroom, no noise',
#   'YEAR': 2023,
#   'CITYSTATE': 'Tacoma, WA',
#   'Lat': 47.25,
#   'Lng': -122.44},
#  ...]

# %%
# Insert all usa sightings into Mongo DB collection
usa_sightings.insert_many(usa_sightings_dict)
# Out:
# InsertManyResult([ObjectId('6689aaecfddd06dc92d7e37e'), ObjectId('6689aaecfddd06dc92d7e37f'), ObjectId('6689aaecfddd06dc92d7e380'), ObjectId('6689aaecfddd06dc92d7e381'), ObjectId('6689aaecfddd06dc92d7e382'), ObjectId('6689aaecfddd06dc92d7e383'), ObjectId('6689aaecfddd06dc92d7e384'), ObjectId('6689aaecfddd06dc92d7e385'), ObjectId('6689aaecfddd06dc92d7e386'), ObjectId('6689aaecfddd06dc92d7e387'), ObjectId('6689aaecfddd06dc92d7e388'), ObjectId('6689aaecfddd06dc92d7e389'), ObjectId('6689aaecfddd06dc92d7e38a'), ObjectId('6689aaecfddd06dc92d7e38b'), ObjectId('6689aaecfddd06dc92d7e38c'), ObjectId('6689aaecfddd06dc92d7e38d'), ObjectId('6689aaecfddd06dc92d7e38e'), ObjectId('6689aaecfddd06dc92d7e38f'), ObjectId('6689aaecfddd06dc92d7e390'), ObjectId('6689aaecfddd06dc92d7e391'), ObjectId('6689aaecfddd06dc92d7e392'), ObjectId('6689aaecfddd06dc92d7e393'), ObjectId('6689aaecfddd06dc92d7e394'), ObjectId('6689aaecfddd06dc92d7e395'), ObjectId('6689aaecfddd06dc92d7e396'), ObjectId('6689aaecfddd06dc92d7e397'), ObjectId('6689aaecfddd06dc92d7e398'), ObjectId('6689aaecfddd06dc92d7e399'), ObjectId('6689aaecfddd06dc92d7e39a'), ObjectId('6689aaecfddd06dc92d7e39b'), ObjectId('6689aaecfddd06dc92d7e39c'), ObjectId('6689aaecfddd06dc92d7e39d'), ObjectId('6689aaecfddd06dc92d7e39e'), ObjectId('6689aaecfddd06dc92d7e39f'), ObjectId('6689aaecfddd06dc92d7e3a0'), ObjectId('6689aaecfddd06dc92d7e3a1'), ObjectId('6689aaecfddd06dc92d7e3a2'), ObjectId('6689aaecfddd06dc92d7e3a3'), ObjectId('6689aaecfddd06dc92d7e3a4'), ObjectId('6689aaecfddd06dc92d7e3a5'), ObjectId('6689aaecfddd06dc92d7e3a6'), ObjectId('6689aaecfddd06dc92d7e3a7'), ObjectId('6689aaecfddd06dc92d7e3a8'), ObjectId('6689aaecfddd06dc92d7e3a9'), ObjectId('6689aaecfddd06dc92d7e3aa'), ObjectId('6689aaecfddd06dc92d7e3ab'), ObjectId('6689aaecfddd06dc92d7e3ac'), ObjectId('6689aaecfddd06dc92d7e3ad'), ObjectId('6689aaecfddd06dc92d7e3ae'), ObjectId('6689aaecfddd06dc92d7e3af'), ObjectId('6689aaecfddd06dc92d7e3b0'), ObjectId('6689aaecfddd06dc92d7e3b1'), ObjectId('6689aaecfddd06dc92d7e3b2'), ObjectId('6689aaecfddd06dc92d7e3b3'), ObjectId('6689aaecfddd06dc92d7e3b4'), ObjectId('6689aaecfddd06dc92d7e3b5'), ObjectId('6689aaecfddd06dc92d7e3b6'), ObjectId('6689aaecfddd06dc92d7e3b7'), ObjectId('6689aaecfddd06dc92d7e3b8'), ObjectId('6689aaecfddd06dc92d7e3b9'), ObjectId('6689aaecfddd06dc92d7e3ba'), ObjectId('6689aaecfddd06dc92d7e3bb'), ObjectId('6689aaecfddd06dc92d7e3bc'), ObjectId('6689aaecfddd06dc92d7e3bd'), ObjectId('6689aaecfddd06dc92d7e3be'), ObjectId('6689aaecfddd06dc92d7e3bf'), ObjectId('6689aaecfddd06dc92d7e3c0'), ObjectId('6689aaecfddd06dc92d7e3c1'), ObjectId('6689aaecfddd06dc92d7e3c2'), ObjectId('6689aaecfddd06dc92d7e3c3'), ObjectId('6689aaecfddd06dc92d7e3c4'), ObjectId('6689aaecfddd06dc92d7e3c5'), ObjectId('6689aaecfddd06dc92d7e3c6'), ObjectId('6689aaecfddd06dc92d7e3c7'), ObjectId('6689aaecfddd06dc92d7e3c8'), ObjectId('6689aaecfddd06dc92d7e3c9'), ObjectId('6689aaecfddd06dc92d7e3ca'), ObjectId('6689aaecfddd06dc92d7e3cb'), ObjectId('6689aaecfddd06dc92d7e3cc'), ObjectId('6689aaecfddd06dc92d7e3cd'), ObjectId('6689aaecfddd06dc92d7e3ce'), ObjectId('6689aaecfddd06dc92d7e3cf'), ObjectId('6689aaecfddd06dc92d7e3d0'), ObjectId('6689aaecfddd06dc92d7e3d1'), ObjectId('6689aaecfddd06dc92d7e3d2'), ObjectId('6689aaecfddd06dc92d7e3d3'), ObjectId('6689aaecfddd06dc92d7e3d4'), ObjectId('6689aaecfddd06dc92d7e3d5'), ObjectId('6689aaecfddd06dc92d7e3d6'), ObjectId('6689aaecfddd06dc92d7e3d7'), ObjectId('6689aaecfddd06dc92d7e3d8'), ObjectId('6689aaecfddd06dc92d7e3d9'), ObjectId('6689aaecfddd06dc92d7e3da'), ObjectId('6689aaecfddd06dc92d7e3db'), ObjectId('6689aaecfddd06dc92d7e3dc'), ObjectId('6689aaecfddd06dc92d7e3dd'), ObjectId('6689aaecfddd06dc92d7e3de'), ObjectId('6689aaecfddd06dc92d7e3df'), ObjectId('6689aaecfddd06dc92d7e3e0'), ObjectId('6689aaecfddd06dc92d7e3e1'), ObjectId('6689aaecfddd06dc92d7e3e2'), ObjectId('6689aaecfddd06dc92d7e3e3'), ObjectId('6689aaecfddd06dc92d7e3e4'), ObjectId('6689aaecfddd06dc92d7e3e5'), ObjectId('6689aaecfddd06dc92d7 ...

# %% [markdown]
# # Step 2: Load Air Force JSON

# %% [markdown]
# ### Step 2a: Empty the collection, as needed

# %%
# Empty the collection
airforce_bases.delete_many({})
# Out:
# DeleteResult({'n': 168, 'ok': 1.0}, acknowledged=True)

# %% [markdown]
# ### Step 2b: Create the collection

# %%
# assign the collection to a variable
airforce_bases = db['airforce_bases']

# %%
# Read in usa_sightings dataframe with lat / long
airforce_bases_json = pd.read_json('../Output/all_us_air_force_bases.json')

# %%
# Convert DataFrame to list of dictionaries
airforce_bases_dict = airforce_bases_json.to_dict(orient='records')
airforce_bases_dict
# Out:
# [{'name': 'Altus Air Force Base',
#   'location': 'Altus',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '97th Air Mobility Wing',
#   'primary_missions_and_units': 'The97th Air Mobility Wingtrains crews to operate theC-17A Globemaster III,KC-135R StratotankerandKC-46A Pegasus.[4]',
#   'latitude': 34.66639,
#   'longitude': -99.26806},
#  {'name': 'Joint Base Anacostia-Bolling',
#   'location': 'Southwest',
#   'state_or_area': 'Washington, D.C.',
#   'commanding_organization': 'Air Force District of Washington',
#   'host_wing_or_primary_unit': '11th Wing',
#   'primary_missions_and_units': 'USAF operatedjoint base. The11th Wingprovides base administration and support to tenants including theUSAF Honor GuardandUSAF Band, which support ceremonial operations in theNational Capital Region.[5]',
#   'latitude': 38.84278,
#   'longitude': -77.01611},
#  {'name': 'Joint Base Andrews-Naval Air Facility Washington',
#   'location': 'Camp Springs',
#   'state_or_area': 'Maryland',
#   'commanding_organization': 'Air Force District of Washington',
#   'host_wing_or_primary_unit': '316th Wing',
#   'primary_missions_and_units': "USAF operatedjoint base. The316th Wingprovides administrative and operational support in theNational Capital Regionand operates theUH-1N Iroquois. The89th Airlift Wingis assigned a variety of aircraft including twoVC-25A(Air Force One) in theSpecial Air Missionrole, providing support to US political and military leaders. Other USAF flying units include the459th Air Refueling Wing(KC-135R Stratotanker) and theD.C. Air National Guard's113th Wing(F-16C/D Fighting Falcon,C-38A CourierandC-40C).[6]",
#   'latitude': 38.81083,
#   'longitude': -76.86694},
#  {'name': 'Arnold Air Force Base',
#   'location': 'Tullahoma',
#   'state_or_area': 'Tennessee',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': 'Arnold Engineering Development Complex',
#   'primary_missions_and_units': 'Non-flying installation, part of theAir Force Test Center. It operates more than 68 aerodynamic and propulsionwind tunnels, rocket and turbine engine test cells, spaceenvironmental chambers, arc heaters, and ballistic ranges.[7]',
#   'latitude': 35.3925,
#   'longitude': -86.08583},
#  {'name': 'Barksdale Air Force Base',
#   'location': 'Bossier City',
#   'state_or_area': 'Louisiana',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '2nd Bomb Wing',
#   'primary_missions_and_units': 'The2nd Bomb Wingand307th Bomb Wingoperate theB-52H Stratofortress. Also home to the headquarters ofAir Force Global Strike Commandand theEighth Air Force.[8]',
#   'latitude': 32.50194,
#   'longitude': -93.66278},
#  {'name': 'Beale Air Force Base',
#   'location': 'Marysville',
#   'state_or_area': 'California',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '9th Reconnaissance Wing',
#   'primary_missions_and_units': "The USAF's high-altitudeIntelligence, Surveillance and Reconnaissancehub, operating theU-2S Dragon Lady,RQ-180,RQ-4B Global HawkandT-38A Talon. The940th Air Refueling Wingoperates theKC-135R Stratotanker.[9]",
#   'latitude': 39.13611,
#   'longitude': -121.43639},
#  {'name': 'Cannon Air Force Base',
#   'location': 'Clovis',
#   'state_or_area': 'New Mexico',
#   'commanding_organization': 'Air Force Special Operations Command',
#   'host_wing_or_primary_unit': '27th Special Operations Wing',
#   'primary_missions_and_units': 'One of four active duty special operations wings, operating theAC-130J Ghostrider,CV-22B Osprey,MQ-9A Reaper,MC-130J Commando IIandU-28A.[10]',
#   'latitude': 34.38278,
#   'longitude': -103.32222},
#  {'name': 'Joint Base Charleston',
#   'location': 'Charleston',
#   'state_or_area': 'South Carolina',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '628th Air Base Wing',
#   'primary_missions_and_units': 'USAF operatedjoint base. The437th Airlift Wingand315th Airlift Wingoperate theC-17A Globemaster III.',
#   'latitude': 32.89861,
#   'longitude': -80.04056},
#  {'name': 'Columbus Air Force Base',
#   'location': 'Columbus',
#   'state_or_area': 'Mississippi',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '14th Flying Training Wing',
#   'primary_missions_and_units': 'Provides specialized undergraduate pilot training in theT-1A Jayhawk,T-6A Texan IIandT-38C Talon[11]',
#   'latitude': 33.64389,
#   'longitude': -88.44389},
#  {'name': 'Creech Air Force Base',
#   'location': 'Indian Springs',
#   'state_or_area': 'Nevada',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '432nd Wing',
#   'primary_missions_and_units': "The USAF's primaryremotely piloted aircraft system(drone) base. The432nd Wingis supported by theAir Force Reserve's926th Wingand theNevada Air National Guard's232nd Operations Squadron, all operating theMQ-9A Reaper.[12]",
#   'latitude': 36.58722,
#   'longitude': -115.67333},
#  {'name': 'Davis–Monthan Air Force Base',
#   'location': 'Tucson',
#   'state_or_area': 'Arizona',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '355th Fighter Wing',
#   'primary_missions_and_units': "The355th Fighter Wingoperates theA-10C Thunderbolt II(both for training and operationally), theHH-60G Pave HawkandHC-130J Combat King II. Other flying units include the55th Electronic Combat Group(EC-130H Compass Call),920th Rescue Wing(HH-60G),924th Fighter Group(A-10C) and theArizona Air National Guard's214th Attack Group(MQ-9A Reaper).[13]The base is known for its aircraft storage facility, operated by the309th Aerospace Maintenance and Regeneration Groupand is also the headquarters of theTwelfth Air Force (Air Forces Southern).[14]",
#   'latitude': 32.16639,
#   'longitude': -110.88306},
#  {'name': 'Dover Air Force Base',
#   'location': 'Dover',
#   'state_or_area': 'Delaware',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '436th Airlift Wing',
#   'primary_missions_and_units': 'The436th Airlift Wingand512th Airlift Wingoperate theC-17A Globemaster IIIandC-5M Super Galaxyin the tactical and strategic airlift role. The base also hosts theCharles C. Carson Center for Mortuary Affairs.[15]',
#   'latitude': 39.12833,
#   'longitude': -75.46472},
#  {'name': 'Dyess Air Force Base',
#   'location': 'Abilene',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '7th Bomb Wing',
#   'primary_missions_and_units': 'TheB-1B Lancerstrategic bomber is operated by the7th Bomb Wingand307th Bomb Wing. Dyess is also home to the317th Airlift Wingflying theC-130J Super Hercules.[16]',
#   'latitude': 32.42083,
#   'longitude': -99.85472},
#  {'name': 'Edwards Air Force Base',
#   'location': 'Edwards',
#   'state_or_area': 'California',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '412th Test Wing',
#   'primary_missions_and_units': "The USAF's primary test and evaluation base and home of theAir Force Test Center. A wide range of aircraft are operated by the412th Test Wing,Air Force Test Pilot School,31st Test and Evaluation SquadronandAir Force Operational Test and Evaluation Center. Edwards also hostsNASA'sArmstrong Flight Research Center.[17]",
#   'latitude': 34.90556,
#   'longitude': -117.88361},
#  {'name': 'Eglin Air Force Base',
#   'location': 'Valparaiso',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '96th Test Wing',
#   'primary_missions_and_units': "The USAF's test and evaluation center for air-delivered weapons, navigation and guidance systems,command and controlsystems, and Air Force Special Operations Command systems (96th Test Wing) as well aselectronic warfare, armament andavionics,chemicaldefense,reconnaissance, and aircrew training devices (53rd Wing). Both wings operates theA-10C Thunderbolt II,F-15C/D/E EagleandF-16C/D Fighting Falcon. The33rd Fighter WingtrainsF-35A Lightning IIpilots from US and foreign air-arms.[18]",
#   'latitude': 30.483,
#   'longitude': -86.533},
#  {'name': 'Ellsworth Air Force Base',
#   'location': 'Box Elder',
#   'state_or_area': 'South Dakota',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '28th Bomb Wing',
#   'primary_missions_and_units': 'TheB-1B Lancerstrategic bomber is operated by the 28th Bomb Wing. Ellsworth also hosts the89th Attack Squadronwhich flies theMQ-9A Reaper.[19]',
#   'latitude': 44.145,
#   'longitude': -103.10361},
#  {'name': 'Francis E. Warren Air Force Base',
#   'location': 'Cheyenne',
#   'state_or_area': 'Wyoming',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '90th Missile Wing',
#   'primary_missions_and_units': "LGM-30G Minuteman IIIbase with launch facilities throughout south-east Wyoming, western Nebraska, and northern Colorado, supported by the wing'sUH-1N Iroquoishelicopters.  It hosts the headquarters of theTwentieth Air Force, which is responsible for the USAF'sIntercontinental Ballistic Missiles(ICBMs).[20]",
#   'latitude': 41.13306,
#   'longitude': -104.86694},
#  {'name': 'Fairchild Air Force Base',
#   'location': 'Spokane',
#   'state_or_area': 'Washington',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '92nd Air Refueling Wing',
#   'primary_missions_and_units': 'The92nd Air Refueling Wingand the141st Air Refueling Wingof theWashington Air National Guardoperate theKC-135R Stratotanker. Also hosts theUSAF Survival, Evasion, Resistance and Escape (SERE) School, which is supported byUH-1N Iroquoisoperated by the36th Rescue Squadron.[21]',
#   'latitude': 47.615,
#   'longitude': -117.65556},
#  {'name': 'Fort George G. Meade',
#   'location': 'Odenton',
#   'state_or_area': 'Maryland',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '70th Intelligence, Surveillance and Reconnaissance Wing',
#   'primary_missions_and_units': 'US Army installation hosting USAF intelligence units carrying outsignals intelligenceandcryptologicoperations.[22]',
#   'latitude': 39.10694,
#   'longitude': -76.74306},
#  {'name': 'Gila Bend Air Force Auxiliary Field',
#   'location': 'Gila Bend',
#   'state_or_area': 'Arizona',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '56th Range Management Office',
#   'primary_missions_and_units': 'Geographically Separate Unit of the56th Fighter WingatLuke AFB, located within theBarry M. Goldwater Air Force Range.[23]',
#   'latitude': 32.8875,
#   'longitude': -112.72},
#  {'name': 'Goodfellow Air Force Base',
#   'location': 'San Angelo',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '17th Training Wing',
#   'primary_missions_and_units': 'Non-flying installation deliveringcryptologic,intelligence, and other training to US and allied military and US government students.[24]',
#   'latitude': 31.42944,
#   'longitude': -100.39889},
#  {'name': 'Grand Forks Air Force Base',
#   'location': 'Grand Forks',
#   'state_or_area': 'North Dakota',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '319th Reconnaissance Wing',
#   'primary_missions_and_units': 'The319th Reconnaissance Wingoperates theRQ-4B Global Hawkin the high-altitudeintelligence, surveillance and reconnaissancerole.[25]',
#   'latitude': 47.96111,
#   'longitude': -97.40111},
#  {'name': 'Hanscom Air Force Base',
#   'location': 'Lincoln',
#   'state_or_area': 'Massachusetts',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '66th Air Base Group',
#   'primary_missions_and_units': 'Non-flying installation, hosting theElectronic Systems Center, part of theAir Force Life Cycle Management Center.[26]',
#   'latitude': 42.47,
#   'longitude': -71.28917},
#  {'name': 'Hill Air Force Base',
#   'location': 'Ogden',
#   'state_or_area': 'Utah',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '75th Air Base Wing',
#   'primary_missions_and_units': "The USAF's second largest base, home to theOgden Air Logistics Complex, the 748th Supply Chain Management Group and several directorates of theAir Force Life Cycle Management CenterandAir Force Nuclear Weapons Center. The388th Fighter Wingand419th Fighter Wingoperate theF-35A Lightning II.[27]",
#   'latitude': 41.12389,
#   'longitude': -111.97278},
#  {'name': 'Homey Airport',
#   'location': 'Groom Lake',
#   'state_or_area': 'Nevada',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': 'Air Force Test Center(Detachment 3)',
#   'primary_missions_and_units': 'Classified test facility popularly known as Area 51, located within theNevada Test and Training Range.[28]',
#   'latitude': 37.23333,
#   'longitude': -115.80833},
#  {'name': 'Holloman Air Force Base',
#   'location': 'Alamogordo',
#   'state_or_area': 'New Mexico',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '49th Wing',
#   'primary_missions_and_units': 'The49th Wingtrains crews to operate theMQ-9A ReaperandF-16C/D Fighting Falcon. Also home to the704th Test Groupwhich performs high speed sled track testing, navigation and guidance system testing, radar signature measurements and weapon systems flight testing. The group also operates theC-12J HuronandT-38C Talon.[29]',
#   'latitude': 32.8525,
#   'longitude': -106.10639},
#  {'name': 'Hurlburt Field',
#   'location': 'Mary Esther',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Force Special Operations Command',
#   'host_wing_or_primary_unit': '1st Special Operations Wing',
#   'primary_missions_and_units': 'Home to the1st Special Operations Wing,24th Special Operations Wing,492nd Special Operations Wing, HeadquartersAir Force Special Operations Commandand several special forces training and test & evaluation units. Aircraft flown includes theAC-130J Ghostrider,CV-22B Osprey,MC-130J Commando II,MQ-9A ReaperandU-28A Draco.505th Command and Control Wingprovides training and testing forcommand and controlsystems.',
#   'latitude': 30.42778,
#   'longitude': -86.68944},
#  {'name': 'Keesler Air Force Base',
#   'location': 'Biloxi',
#   'state_or_area': 'Mississippi',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '81st Training Wing',
#   'primary_missions_and_units': 'The81st Training Wingprovides a wide range of non-flying technical training. Also home to the403rd Wingoperating theWC-130J Super Hercules&C-130J Super Herculesand the Headquarters of theSecond Air Force.[30]',
#   'latitude': 30.41139,
#   'longitude': -88.92361},
#  {'name': 'Kegelman Air Force Auxiliary Field',
#   'location': 'Cherokee',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '71st Flying Training Wing',
#   'primary_missions_and_units': 'Airfield used for training byT-1A Jayhawk,T-6A Texan IIandT-38C Talonaircraft of the71st Flying Training WingatVance AFB.[31]',
#   'latitude': 36.73806,
#   'longitude': -98.12611},
#  {'name': 'Kirtland Air Force Base',
#   'location': 'Albuquerque',
#   'state_or_area': 'New Mexico',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '377th Air Base Wing',
#   'primary_missions_and_units': "Center for research, development and testing of non-conventional weapons, space and missile technology and laser warfare. Home to theAir Force Nuclear Weapons Center,Air Force Safety CenterandAir Force Operational Test and Evaluation Center. The58th Special Operations Wingand theNew Mexico Air National Guard's150th Special Operations Wingtrain special operations crews to operate theCV-22B Osprey,HC-130J Combat King II,MC-130J Commando II,HH-60G Pave HawkandUH-1N Iroquois.[32]",
#   'latitude': 35.04028,
#   'longitude': -106.60917},
#  {'name': 'Joint Base Langley–Eustis',
#   'location': 'Hampton',
#   'state_or_area': 'Virginia',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '633rd Air Base Wing',
#   'primary_missions_and_units': "USAF operatedjoint base. Home to the1st Fighter Wingand theVirginia Air National Guard's192d Fighter Wing, both flying theF-22A Raptor. The base also hosts the headquarters ofAir Combat Command, the363rd Intelligence, Surveillance, and Reconnaissance (ISR) Wingand the480th ISR Wing.[33]",
#   'latitude': 37.08278,
#   'longitude': -76.36056},
#  {'name': 'Laughlin Air Force Base',
#   'location': 'Del Rio',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '47th Flying Training Wing',
#   'primary_missions_and_units': 'Operates theT-1A Jayhawk,T-38C TalonandT-6A Texan IIin the pilot training role.[34]',
#   'latitude': 29.35944,
#   'longitude': -100.77806},
#  {'name': 'Joint Base Lewis-McChord',
#   'location': 'Tacoma',
#   'state_or_area': 'Washington',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '627th Air Base Group',
#   'primary_missions_and_units': 'US Armyoperatedjoint base. The62nd Airlift Wingand446th Airlift Wingoperate theC-17A Globemaster III. TheWashington Air National Guardoperates theWestern Air Defense Sector.[35]',
#   'latitude': 47.1475,
#   'longitude': -122.47944},
#  {'name': 'Little Rock Air Force Base',
#   'location': 'Jacksonville',
#   'state_or_area': 'Arkansas',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '19th Airlift Wing',
#   'primary_missions_and_units': "The189th Airlift Wingand theArkansas Air National Guard's314th Airlift Wingdeliver training toC-130 Herculesaircrews from across the US military and allied nations, whereas the19th Airlift Wingand913th Airlift Groupfly the Hercules operationally.[36]",
#   'latitude': 34.91694,
#   'longitude': -92.14639},
#  {'name': 'Luke Air Force Base',
#   'location': 'Glendale',
#   'state_or_area': 'Arizona',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '56th Fighter Wing',
#   'primary_missions_and_units': 'The56th Fighter Wing(the largest fighter wing in the USAF) and the944th Fighter Wingtrain pilots to operate theF-16 Fighting FalconandF-35A Lightning II.[37]',
#   'latitude': 33.535,
#   'longitude': -112.38306},
#  {'name': 'MacDill Air Force Base',
#   'location': 'Tampa',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '6th Air Refueling Wing',
#   'primary_missions_and_units': 'Home to the6th Air Refueling Wingand927th Air Refueling Wingoperating theKC-135R Stratotanker. Also home to the headquarters ofUS Central CommandandUS Special Operations Command.[38]',
#   'latitude': 27.84944,
#   'longitude': -82.52111},
#  {'name': 'Malmstrom Air Force Base',
#   'location': 'Great Falls',
#   'state_or_area': 'Montana',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '341st Missile Wing',
#   'primary_missions_and_units': "LGM-30G Minuteman IIIbase with launch facilities throughout central Montana, supported by the582nd Helicopter Group'sUH-1N Iroquoishelicopters.[39]",
#   'latitude': 47.50472,
#   'longitude': -111.18722},
#  {'name': 'Maxwell Air Force Base',
#   'location': 'Montgomery',
#   'state_or_area': 'Alabama',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '42nd Air Base Wing',
#   'primary_missions_and_units': 'Headquarters ofAir University. The908th Airlift Wing(AFRES)is transitioning from the C-130H Hercules to the MH-139 Grey Wolf Helicopter.',
#   'latitude': 32.37917,
#   'longitude': -86.3625},
#  {'name': 'McConnell Air Force Base',
#   'location': 'Wichita',
#   'state_or_area': 'Kansas',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '22d Air Refueling Wing',
#   'primary_missions_and_units': "The22nd Air Refueling Wingand931st Air Refueling Wingoperate theKC-135R/T Stratotanker. TheKansas Air National Guard's184th Wingperforms a variety of roles includingintelligence, surveillance and reconnaissanceandcyber warfare.[40]",
#   'latitude': 37.62306,
#   'longitude': -97.26722},
#  {'name': 'Joint Base McGuire–Dix–Lakehurst',
#   'location': 'Trenton',
#   'state_or_area': 'New Jersey',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '87th Air Base Wing',
#   'primary_missions_and_units': "USAF operatedjoint base. The305th Air Mobility Wingand514th Air Mobility Wingoperate theC-17A Globemaster IIIandKC-10A Extender.Also home to theNew Jersey Air National Guard's108th Wingoperating theKC-135R Stratotanker. The621st Contingency Response Wingis part of theUSAF Expeditionary Centerwhich is also based there.",
#   'latitude': 40.01917,
#   'longitude': -74.52278},
#  {'name': 'Minot Air Force Base',
#   'location': 'Minot',
#   'state_or_area': 'North Dakota',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '5th Bomb Wing',
#   'primary_missions_and_units': "The5th Bomb Wingoperate theB-52H Stratofortress. The91st Missile WingmanLGM-30G Minuteman IIIlaunch facilities throughout North Dakota, supported by the582nd Helicopter Group'sUH-1N Iroquoishelicopters[41]",
#   'latitude': 48.41583,
#   'longitude': -101.35806},
#  {'name': 'Moody Air Force Base',
#   'location': 'Valdosta',
#   'state_or_area': 'Georgia',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '23rd Wing',
#   'primary_missions_and_units': 'The23rd Wingoperates theA-10C Thunderbolt II,HC-130J Combat King IIandHH-60G Pave Hawkin theclose air supportandcombat search and rescueroles. Other units include The476th Fighter Groupalso operates the A-10A and the93rd Air Ground Operations Wingprovidesforce protectioncapability.[42]',
#   'latitude': 30.96778,
#   'longitude': -83.19278},
#  {'name': 'Mountain Home Air Force Base',
#   'location': 'Mountain Home',
#   'state_or_area': 'Idaho',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '366th Fighter Wing',
#   'primary_missions_and_units': 'The366th Fighter Wingoperates theF-15E Strike Eagle.[43]',
#   'latitude': 43.04361,
#   'longitude': -115.8725},
#  {'name': 'Nellis Air Force Base',
#   'location': 'Las Vegas',
#   'state_or_area': 'Nevada',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '99th Air Base Wing',
#   'primary_missions_and_units': "Home of theUSAF Warfare Center, the air force's advanced air combat training center, comprising the53rd Test and Evaluation Group, the57th WingandUS Air Force Weapons School. The563rd Rescue Group,926th Wingand theUSAF Air Demonstration Squadron(Thunderbirds) are also based at Nellis.[44]",
#   'latitude': 36.23611,
#   'longitude': -115.03417},
#  {'name': 'North Auxiliary Airfield',
#   'location': 'North',
#   'state_or_area': 'South Carolina',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '628th Civil Engineer Squadron',
#   'primary_missions_and_units': 'Geographically Separate Unit of the628th Air Base WingatJoint Base Charleston, utilised for training byC-17A Globemaster IIIaircraft of the437thand315th Airlift Wings.[45]',
#   'latitude': 33.61694,
#   'longitude': -81.08306},
#  {'name': 'Offutt Air Force Base',
#   'location': 'Bellevue',
#   'state_or_area': 'Nebraska',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '55th Wing',
#   'primary_missions_and_units': "The55th WingandNebraska Air National Guard's170th Groupoperate a range ofOC-135,RC-135andWC-135aircraft in the intelligence gathering, reconnaissance and surveillance roles. Offut is also home to the557th Weather Wingand595th Command and Control Groupoperating theE-4B Advanced Airborne Command Postand the headquarters ofUS Strategic Command.[46]",
#   'latitude': 41.11944,
#   'longitude': -95.90861},
#  {'name': 'Patrick Space Force Base',
#   'location': 'Brevard County',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Various',
#   'host_wing_or_primary_unit': 'N/A',
#   'primary_missions_and_units': "US Space Force installation hosting theAir Force Technical Applications Center.[47]Also home to theAir Force Reserve Commands920th Rescue Wingwhich operates theHC-130N Combat KingandHH-60G Pave Hawk, as well as theFlorida Air National Guard's114th Space Control Squadron.[48]",
#   'latitude': 28.235,
#   'longitude': -80.61},
#  {'name': 'Naval Air Station Pensacola',
#   'location': 'Pensacola',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '479th Flying Training Group',
#   'primary_missions_and_units': "US Navy operated installation hosting the USAF's479th Flying Training Group(part of the12th Flying Training Wing) which operates theT-1A JayhawkandT-6A Texan II.[49]",
#   'latitude': 30.3525,
#   'longitude': -87.31778},
#  {'name': 'Peterson Space Force Base',
#   'location': 'Colorado Springs',
#   'state_or_area': 'Colorado',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '561st Network Operations Squadron',
#   'primary_missions_and_units': 'US Space Force installation hosting a Geographically Separate Unit of the690th Cyberspace Operations Group.[50]',
#   'latitude': 38.82361,
#   'longitude': -104.695},
#  {'name': 'Pope Field',
#   'location': 'Fayetteville',
#   'state_or_area': 'North Carolina',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '43rd Air Mobility Operations Group',
#   'primary_missions_and_units': "US Armyinstallation (part ofFort Liberty) hosting the USAF's43rd Air Mobility Operations Group,18th Air Support Operations Groupand several units ofAir Force Special Operations Command.[51]",
#   'latitude': 35.17083,
#   'longitude': -79.01444},
#  {'name': 'Robins Air Force Base',
#   'location': 'Warner Robins',
#   'state_or_area': 'Georgia',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '78th Air Base Wing',
#   'primary_missions_and_units': 'TheWarner Robins Air Logistics Complexis the primary logistics support depot for theF-15 Eagle,C-130 Hercules,C-5M GalaxyandC-17A Globemaster III. Robins is also home to various directorates of theAir Force Life Cycle Management Center, the headquarters of Air Force Reserve Command and the461st Air Control Wing&116th Air Control Wing(Georgia Air National Guard) both operating theE-8C JSTARS.[52]',
#   'latitude': 32.64,
#   'longitude': -83.59167},
#  {'name': 'Rome Research Site',
#   'location': 'Rome',
#   'state_or_area': 'New York',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': 'AFRL Information Directorate',
#   'primary_missions_and_units': 'Non-flying installation, home to the Information Directorate ofAir Force Research Laboratory(AFRL).[53]',
#   'latitude': 43.221361,
#   'longitude': -75.408556},
#  {'name': 'Joint Base San Antonio',
#   'location': 'San Antonio',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '502nd Air Base Wing',
#   'primary_missions_and_units': 'USAF operatedjoint baseacross several sites.JBSA-Randolphis home to the12th Flying Training Wingand provides s undergraduate pilot training, flying theT-6A Texan II,T-1A JayhawkandT-38C Talon.JBSA-Lacklandis a non-flying facility that provides basic and technical training andKelly Field Annexis home to the149th Fighter Wing(F-16C/D Fighting Falcon)433rd Airlift Wing(C-5M Galaxy).[54]',
#   'latitude': 29.44889,
#   'longitude': -98.44889},
#  {'name': 'Scott Air Force Base',
#   'location': 'Belleville',
#   'state_or_area': 'Illinois',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '375th Air Mobility Wing',
#   'primary_missions_and_units': "The375th Air Mobility Wingoperates theC-21A Learjet,C-40C ClipperandKC-135R Stratotanker. TheIllinois Air National Guard's126th Air Refueling Wingalso operates the KC-135R and the932nd Airlift Wingthe C-40C. Also home to the headquarters ofAir Mobility Commandand theEighteenth Air Force.[55]",
#   'latitude': 38.54528,
#   'longitude': -89.83528},
#  {'name': 'Seymour Johnson Air Force Base',
#   'location': 'Goldsboro',
#   'state_or_area': 'North Carolina',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '4th Fighter Wing',
#   'primary_missions_and_units': 'The4th Fighter Wingand414th Fighter Groupoperate theF-15E Strike Eagleand the916th Air Refueling WingtheKC-135R Stratotanker.[56]',
#   'latitude': 35.33944,
#   'longitude': -77.96056},
#  {'name': 'Shaw Air Force Base',
#   'location': 'Sumter',
#   'state_or_area': 'South Carolina',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '20th Fighter Wing',
#   'primary_missions_and_units': 'The20th Fighter Wingoperates theF-16C/D Fighting Falconand the25th Attack GrouptheMQ-9A Reaper. Also home to the headquarters of theNinth Air Force.[57]',
#   'latitude': 33.97306,
#   'longitude': -80.47278},
#  {'name': 'Sheppard Air Force Base',
#   'location': 'Wichita Falls',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '82nd Training Wing',
#   'primary_missions_and_units': 'The82nd Training Wingprovides ground technical training, whilst the80th Flying Training Wingand340th Flying Training Groupprovide flying training and operate theT-6A Texan IIandT-38C Talon.[58]',
#   'latitude': 33.98889,
#   'longitude': -98.49194},
#  {'name': 'Tinker Air Force Base',
#   'location': 'Oklahoma City',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '72nd Air Base Wing',
#   'primary_missions_and_units': 'TheOklahoma City Air Logistics Complexis the primary logistics support depot forB-1B Lancer,B-2A Spirit,B-52H Stratofortress,KC-135R StratotankerandE-3 Sentry. The552nd Air Control Wingand513th Air Control Groupoperate the E-3 Sentry and the507th Air Refueling Wingthe KC-135R Stratotanker.[59][60][61]',
#   'latitude': 35.41472,
#   'longitude': -97.38667},
#  {'name': 'Tonopah Test Range Airport',
#   'location': 'Tonopah',
#   'state_or_area': 'Nevada',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '30th Reconnaissance Squadron',
#   'primary_missions_and_units': 'The30th Reconnaissance Squadronis a Geographically Separate Unit of the432nd Wingand operates theRQ-170 SentinelUAV.[62]',
#   'latitude': 37.79472,
#   'longitude': -116.77861},
#  {'name': 'Travis Air Force Base',
#   'location': 'Fairfield',
#   'state_or_area': 'California',
#   'commanding_organization': 'Air Mobility Command',
#   'host_wing_or_primary_unit': '60th Air Mobility Wing',
#   'primary_missions_and_units': 'The60th Air Mobility Wingand349th Air Mobility Wingoperate theC-5M Galaxy,C-17A Globemaster IIIandKC-10A Extender. Also home to theDavid Grant USAF Medical Center.[63]',
#   'latitude': 38.26278,
#   'longitude': -121.9275},
#  {'name': 'Tyndall Air Force Base',
#   'location': 'Panama City',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Combat Command',
#   'host_wing_or_primary_unit': '325th Fighter Wing',
#   'primary_missions_and_units': 'The325th Fighter Wingand44th Fighter Groupoperate theF-22A RaptorandT-38A/B/C Talonand the82nd Aerial Targets Squadrona range of drone targets. Also home to the headquarters of theFirst Air Forceand the601st Air and Space Operations Center, providing Command and control for air defense, homeland security and civil support missions forNorth American Aerospace Defense Command(NORAD).[64]',
#   'latitude': 30.07861,
#   'longitude': -85.57639},
#  {'name': 'United States Air Force Academy',
#   'location': 'Colorado Springs',
#   'state_or_area': 'Colorado',
#   'commanding_organization': 'Chief of Staff of the Air Force',
#   'host_wing_or_primary_unit': '10th Air Base Wing',
#   'primary_missions_and_units': 'Military academyfor the US Air Force and US Space Force. It is both a military organization and a university, much of which is set up like most other Air Force bases, but theSuperintendent, Commandant, Dean of Faculty and cadet wing are set up like a civilian university. The306th Flying Training Groupoperates a variety of light training aircraft and gliders.[65][66]',
#   'latitude': 38.99028,
#   'longitude': -104.85833},
#  {'name': 'Vance Air Force Base',
#   'location': 'Enid',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Air Education and Training Command',
#   'host_wing_or_primary_unit': '71st Flying Training Wing',
#   'primary_missions_and_units': '71st Flying Training Wingand5th Flying Training Squadronprovide undergraduate pilot training, flying theT-1A Jayhawk,T-6A Texan IIandT-38C Talon.T-38C Talon.[67][68]',
#   'latitude': 36.33944,
#   'longitude': -97.91722},
#  {'name': 'Vandenberg Space Force Base',
#   'location': 'Lompoc',
#   'state_or_area': 'California',
#   'commanding_organization': 'Various',
#   'host_wing_or_primary_unit': 'N/A',
#   'primary_missions_and_units': 'US Space Force installation hosting the532nd Training Squadronand576th Flight Test Squadron.[69]',
#   'latitude': 34.7325,
#   'longitude': -120.56806},
#  {'name': 'Whiteman Air Force Base',
#   'location': 'Knob Noster',
#   'state_or_area': 'Missouri',
#   'commanding_organization': 'Air Force Global Strike Command',
#   'host_wing_or_primary_unit': '509th Bomb Wing',
#   'primary_missions_and_units': "The509th Bomb Wingand theMissouri Air National Guard's131st Bomb Wingoperates theB-2A Spirit,T-38A Talon. Other units include the442nd Fighter Wing(A-10C Thunderbolt II) and the20th Attack Squadron(MQ-9A Reaper).[70]",
#   'latitude': 38.73028,
#   'longitude': -93.54806},
#  {'name': 'Wright-Patterson Air Force Base',
#   'location': 'Dayton',
#   'state_or_area': 'Ohio',
#   'commanding_organization': 'Air Force Materiel Command',
#   'host_wing_or_primary_unit': '88th Air Base Wing',
#   'primary_missions_and_units': 'Headquarters ofAir Force Materiel Command, supporting a wide range of logistics, research & development and acquisition activities. Organisations include theAir Force Life Cycle Management Center,Air Force Research Laboratory,Air Force Institute of Technologyand theNational Air and Space Intelligence Center. The445th Airlift Wingoperates theC-17A Globemaster III. Also home to theNational Museum of the US Air Force.[71]',
#   'latitude': 39.82306,
#   'longitude': -84.04944},
#  {'name': 'Abston Air National Guard Station',
#   'location': 'Montgomery',
#   'state_or_area': 'Alabama',
#   'commanding_organization': 'Alabama Air National Guard',
#   'host_wing_or_primary_unit': '226th Combat Communications Group',
#   'primary_missions_and_units': 'Non-flying installation. The226th Combat Communications Groupoperates in the combat communications role.[74]',
#   'latitude': 32.35611,
#   'longitude': -86.34667},
#  {'name': 'Atlantic City Air National Guard Base',
#   'location': 'Atlantic City',
#   'state_or_area': 'New Jersey',
#   'commanding_organization': 'New Jersey Air National Guard',
#   'host_wing_or_primary_unit': '177th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withAtlantic City International Airport. The177th Fighter Wingoperates theF-16C Fighting Falconmulti-role fighter.[75]',
#   'latitude': 39.44806,
#   'longitude': -74.58167},
#  {'name': 'Bangor Air National Guard Base',
#   'location': 'Bangor',
#   'state_or_area': 'Maine',
#   'commanding_organization': 'Maine Air National Guard',
#   'host_wing_or_primary_unit': '101st Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withBangor International Airport. The101st Air Refueling Wingoperates theKC-135R Stratotanker.[76]',
#   'latitude': 44.81417,
#   'longitude': -68.83083},
#  {'name': 'Barnes Air National Guard Base',
#   'location': 'Westfield',
#   'state_or_area': 'Massachusetts',
#   'commanding_organization': 'Massachusetts Air National Guard',
#   'host_wing_or_primary_unit': '104th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withWestfield-Barnes Regional Airport. The104th Fighter Wingoperates theF-15C Eagleair superiority fighter.[77]',
#   'latitude': 42.16556,
#   'longitude': -72.72056},
#  {'name': 'Battle Creek Air National Guard Base',
#   'location': 'Springfield',
#   'state_or_area': 'Michigan',
#   'commanding_organization': 'Michigan Air National Guard',
#   'host_wing_or_primary_unit': '110th Wing',
#   'primary_missions_and_units': 'Airfield shared withW. K. Kellogg Airport. The110th Wingoperates theMQ-9A Reaper.[78]',
#   'latitude': 42.307278,
#   'longitude': -85.251472},
#  {'name': 'Berry Field Air National Guard Base',
#   'location': 'Nashville',
#   'state_or_area': 'Tennessee',
#   'commanding_organization': 'Tennessee Air National Guard',
#   'host_wing_or_primary_unit': '118th Wing',
#   'primary_missions_and_units': 'Airfield shared withNashville International Airport. The118th Wingoperates theMQ-9A Reaperand also performs in the intelligence, cyber systems andintelligence, surveillance and reconnaissance(ISR) roles.[79]',
#   'latitude': 36.12667,
#   'longitude': -86.68194},
#  {'name': 'Biddle Air National Guard Base',
#   'location': 'Horsham Township',
#   'state_or_area': 'Pennsylvania',
#   'commanding_organization': 'Pennsylvania Air National Guard',
#   'host_wing_or_primary_unit': '111th Attack Wing',
#   'primary_missions_and_units': 'The111th Attack Wingoperates theMQ-9A Reaper.[80]',
#   'latitude': 40.19972,
#   'longitude': -75.14806},
#  {'name': 'Bradley Air National Guard Base',
#   'location': 'Windsor Locks',
#   'state_or_area': 'Connecticut',
#   'commanding_organization': 'Connecticut Air National Guard',
#   'host_wing_or_primary_unit': '103rd Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withBradley International Airport. The103rd Airlift Wingoperates theC-130H Herculesin the airlift role.[81]',
#   'latitude': 41.93889,
#   'longitude': -72.68333},
#  {'name': 'Brunswick Air National Guard Station',
#   'location': 'Brunswick',
#   'state_or_area': 'Georgia',
#   'commanding_organization': 'Georgia Air National Guard',
#   'host_wing_or_primary_unit': '224th Joint Communications Support Squadron',
#   'primary_missions_and_units': 'Non-flying installation. The224th Joint Communications Support Squadronis a Geographically Separate Unit of the165th Airlift Wingand provides deployabletactical communicationsfor Joint and Special Operations Task Force Headquarters.[82]',
#   'latitude': 31.24775,
#   'longitude': -81.48583},
#  {'name': 'Buckley Space Force Base',
#   'location': 'Aurora',
#   'state_or_area': 'Colorado',
#   'commanding_organization': 'Colorado Air National Guard',
#   'host_wing_or_primary_unit': '140th Wing',
#   'primary_missions_and_units': 'US Space Force basehosting the140th Wing(operating theF-16C Fighting Falcon) and other space related USAF units. Also hosts theAir Reserve Personnel Center.[83]',
#   'latitude': 39.70167,
#   'longitude': -104.75167},
#  {'name': 'Burlington Air National Guard Base',
#   'location': 'Burlington',
#   'state_or_area': 'Vermont',
#   'commanding_organization': 'Vermont Air National Guard',
#   'host_wing_or_primary_unit': '158th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withBurlington International Airport. The158th Fighter Wingoperates theF-35A Lighting IImulti-role fighter.[84]',
#   'latitude': 44.47278,
#   'longitude': -73.14667},
#  {'name': 'Camp Murray Air National Guard Station',
#   'location': 'Tacoma',
#   'state_or_area': 'Washington',
#   'commanding_organization': 'Washington Air National Guard',
#   'host_wing_or_primary_unit': '194th Wing',
#   'primary_missions_and_units': 'Camp Murray is located adjacent to Joint Base Lewis–McChord, Washington. It is home to the Washington Joint Forces Headquarters, including: theWashington Army National Guard, theWashington State Guard, theWashington Air National Guard, and the Washington State Emergency Operations Center.[85]',
#   'latitude': 47.11806,
#   'longitude': -122.56},
#  {'name': 'Camp Rilea',
#   'location': 'Warrenton',
#   'state_or_area': 'Oregon',
#   'commanding_organization': 'Oregon Air National Guard',
#   'host_wing_or_primary_unit': '116th Air Control Squadron',
#   'primary_missions_and_units': "Oregon National Guard Training Complex under the jurisdiction of the Oregon Military Department, the 116th Air Control Squadron provides command and control capabilities for Oregon's North Coast emergency response and recovery operations.[86][87]",
#   'latitude': 46.12917,
#   'longitude': -123.94389},
#  {'name': 'Capital Airport Air National Guard Station',
#   'location': 'Springfield',
#   'state_or_area': 'Illinois',
#   'commanding_organization': 'Illinois Air National Guard',
#   'host_wing_or_primary_unit': '183d Wing',
#   'primary_missions_and_units': "Airfield shared withAbraham Lincoln Capital Airport. The183d Wingis a Centralized Intermediate Repair Facility which repairs and maintainsGeneral Electric F110engines used in the Air Force'sF-16 Fighting Falcon.[88]",
#   'latitude': 39.84417,
#   'longitude': -89.67806},
#  {'name': 'Channel Islands Air National Guard Station',
#   'location': 'Oxnard',
#   'state_or_area': 'California',
#   'commanding_organization': 'California Air National Guard',
#   'host_wing_or_primary_unit': '146th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withNaval Air Station Point Mugu. The146th Airlift Wingoperates theC-130J Super Herculesin the airlift andaerial firefightingroles, also home to the 562nd Air Force Band.[89]',
#   'latitude': 34.115,
#   'longitude': -119.11028},
#  {'name': 'Charlotte Air National Guard Base',
#   'location': 'Charlotte',
#   'state_or_area': 'North Carolina',
#   'commanding_organization': 'North Carolina Air National Guard',
#   'host_wing_or_primary_unit': '145th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withCharlotte Douglas International Airport. The145th Airlift Wingoperates theC-17A Globemaster IIIin the airlift role.[90]',
#   'latitude': 35.21611,
#   'longitude': -80.93194},
#  {'name': 'Dallas Air Guard Station',
#   'location': 'Grand Prairie',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Texas Air National Guard',
#   'host_wing_or_primary_unit': '254th Combat Communications Group',
#   'primary_missions_and_units': 'Non-flying installation, forming part of theGrand Prairie Armed Forces Reserve Complex. Geographically Separate Unit of the136th Airlift Wing.[91]',
#   'latitude': 32.74,
#   'longitude': -96.97},
#  {'name': 'Des Moines Air National Guard Base',
#   'location': 'Des Moines',
#   'state_or_area': 'Iowa',
#   'commanding_organization': 'Iowa Air National Guard',
#   'host_wing_or_primary_unit': '132nd Wing',
#   'primary_missions_and_units': 'Airfield shared withDes Moines International Airport. The132nd Wingoperates theMQ-9A Reaper.[92]',
#   'latitude': 41.53833,
#   'longitude': -93.65944},
#  {'name': 'Dobbins Air Reserve Base',
#   'location': 'Marietta',
#   'state_or_area': 'Georgia',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '94th Airlift Wing',
#   'primary_missions_and_units': 'The94th Airlift Wingoperates theC-130H Herculesin the airlift role, also home to the headquarters of theTwenty-Second Air Force[93]',
#   'latitude': 33.91528,
#   'longitude': -84.51639},
#  {'name': 'Duke Field',
#   'location': 'Crestview',
#   'state_or_area': 'Florida',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '919th Special Operations Wing',
#   'primary_missions_and_units': 'The919th Special Operations Wingand elements of the492nd Special Operations Wingoperate theC-146A Wolfhound.[94]Elements of the96th Operations Groupoperate a range of special operations aircraft in the test and evaluation role.',
#   'latitude': 30.65028,
#   'longitude': -86.52278},
#  {'name': 'Duluth Air National Guard Base',
#   'location': 'Duluth',
#   'state_or_area': 'Minnesota',
#   'commanding_organization': 'Minnesota Air National Guard',
#   'host_wing_or_primary_unit': '148th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withDuluth International Airport. The177th Fighter Wingoperates theF-16C Fighting Falconmulti-role fighter.[95]',
#   'latitude': 46.84222,
#   'longitude': -92.19361},
#  {'name': 'Eastern Air Defense Sector',
#   'location': 'Rome',
#   'state_or_area': 'New York',
#   'commanding_organization': 'New York Air National Guard',
#   'host_wing_or_primary_unit': '224th Air Defense Group',
#   'primary_missions_and_units': "Non-flying installation. Air defence command and control unit permanently assigned toNORADand manned by theNew York Air National Guard's224th Air Defense Group.[96]",
#   'latitude': 43.216611,
#   'longitude': -75.404833},
#  {'name': 'Ebbing Air National Guard Base',
#   'location': 'Fort Smith',
#   'state_or_area': 'Arkansas',
#   'commanding_organization': 'Arkansas Air National Guard',
#   'host_wing_or_primary_unit': '188th Wing',
#   'primary_missions_and_units': 'Airfield shared withFort Smith Regional Airport. The188th Wingoperates theMQ-9A Reaperand also performs in theintelligence, surveillance and reconnaissance(ISR) role.[97]',
#   'latitude': 35.33667,
#   'longitude': -94.3675},
#  {'name': 'Ellington Field Joint Reserve Base',
#   'location': 'Houston',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Texas Air National Guard',
#   'host_wing_or_primary_unit': '147th Attack Wing',
#   'primary_missions_and_units': 'Airfield shared withEllington Airport. The147th Attack Wingoperates theMQ-9A Reaper.[98]',
#   'latitude': 29.60722,
#   'longitude': -95.15889},
#  {'name': 'Fargo Air National Guard Base',
#   'location': 'Fargo',
#   'state_or_area': 'North Dakota',
#   'commanding_organization': 'North Dakota Air National Guard',
#   'host_wing_or_primary_unit': '119th Wing',
#   'primary_missions_and_units': 'Airfield shared withHector International Airport. The119th Wingoperates theMQ-9A Reaper.[99]',
#   'latitude': 46.92056,
#   'longitude': -96.81583},
#  {'name': 'Forbes Field Air National Guard Base',
#   'location': 'Topeka',
#   'state_or_area': 'Kansas',
#   'commanding_organization': 'Kansas Air National Guard',
#   'host_wing_or_primary_unit': '190th Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withTopeka Regional Airport. The190th Air Refueling Wingoperates theKC-135 Stratotanker.[100]',
#   'latitude': 38.95111,
#   'longitude': -95.66583},
#  {'name': 'Fort Bliss',
#   'location': 'El Paso',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Texas Air National Guard',
#   'host_wing_or_primary_unit': '204th Security Forces Squadron',
#   'primary_missions_and_units': 'An Active DutyUS ArmyInstallation hosting a Geographically Separate Unit of the149th Fighter Wing. The 204th Security Forces Squadron specifically occupiesBiggs Army Airfieldand operates as the only heavy weapons Security Forces unit in the Air National Guard.[101][102]',
#   'latitude': 31.80194,
#   'longitude': -106.42472},
#  {'name': 'Fort Dodge Air National Guard Station',
#   'location': 'Fort Dodge',
#   'state_or_area': 'Iowa',
#   'commanding_organization': 'Iowa Air National Guard',
#   'host_wing_or_primary_unit': '133rd Test Squadron',
#   'primary_missions_and_units': 'Non-flying installation. The 133rd Test Squadron provides testing and evaluation of command, control, communications, computers andIntelligence, Surveillance, and Reconnaissance(ISR) systems.[103]',
#   'latitude': 42.550694,
#   'longitude': -94.17925},
#  {'name': 'Fort Wayne Air National Guard Base',
#   'location': 'Fort Wayne',
#   'state_or_area': 'Indiana',
#   'commanding_organization': 'Indiana Air National Guard',
#   'host_wing_or_primary_unit': '122nd Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withFort Wayne International Airport. The122nd Fighteroperates theA-10C Thunderbolt II.[104]',
#   'latitude': 40.97833,
#   'longitude': -85.195},
#  {'name': 'Naval Air Station Joint Reserve Base Fort Worth',
#   'location': 'Fort Worth',
#   'state_or_area': 'Texas',
#   'commanding_organization': 'Various',
#   'host_wing_or_primary_unit': 'N/A',
# ...
#   'latitude': 29.82528,
#   'longitude': -90.035},
#  {'name': 'Niagara Falls Air Reserve Station',
#   'location': 'Niagara Falls',
#   'state_or_area': 'New York',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '914th Air Refueling Wing',
#   'primary_missions_and_units': "Airfield shared withNiagara Falls International Airport. The914th Air Refueling Wingoperates theKC-135R Stratotankerand theNew York Air National Guard's107th Attack WingtheMQ-9A Reaper.[145]",
#   'latitude': 43.11333,
#   'longitude': -78.9475},
#  {'name': 'North Highlands Air National Guard Station',
#   'location': 'Sacramento, California',
#   'state_or_area': 'California',
#   'commanding_organization': 'California Air National Guard',
#   'host_wing_or_primary_unit': '162nd Combat Communications Group',
#   'primary_missions_and_units': 'Non-flying installation. The162nd Combat Communications Groupoperates in the combat communications role.[146]',
#   'latitude': 38.64,
#   'longitude': -121.4025},
#  {'name': 'North Smithfield Air National Guard Station',
#   'location': 'North Smithfield',
#   'state_or_area': 'Rhode Island',
#   'commanding_organization': 'Rhode Island Air National Guard',
#   'host_wing_or_primary_unit': '282nd Combat Communications Squadron',
#   'primary_missions_and_units': 'Non-flying installation. The 282nd Combat Communications Squadron operates in the combat communications role.[147]',
#   'latitude': 41.97028,
#   'longitude': -71.575667},
#  {'name': 'Otis Air National Guard Base',
#   'location': 'Mashpee',
#   'state_or_area': 'Massachusetts',
#   'commanding_organization': 'Massachusetts Air National Guard',
#   'host_wing_or_primary_unit': '102nd Intelligence Wing',
#   'primary_missions_and_units': 'Non-flying installation, part ofJoint Base Cape Cod. The102nd Intelligence Wingoperates in the intelligence andcommand and controlroles.[148]The267th Combat Communications Squadrondeploys, operates and maintains strategic emergency communications.',
#   'latitude': 41.65861,
#   'longitude': -70.52139},
#  {'name': 'Pease Air National Guard Base',
#   'location': 'Portsmouth',
#   'state_or_area': 'New Hampshire',
#   'commanding_organization': 'New Hampshire Air National Guard',
#   'host_wing_or_primary_unit': '157th Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withPortsmouth International Airport at Pease. The157th Air Refueling Wingoperates theKC-46A Pegasus.[149]',
#   'latitude': 43.07806,
#   'longitude': -70.82333},
#  {'name': 'Peoria Air National Guard Base',
#   'location': 'Peoria',
#   'state_or_area': 'Illinois',
#   'commanding_organization': 'Illinois Air National Guard',
#   'host_wing_or_primary_unit': '182nd Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withGeneral Wayne A. Downing Peoria International Airport. The182nd Airlift Wingoperates theC-130H Hercules.[150]',
#   'latitude': 40.66056,
#   'longitude': -89.69556},
#  {'name': 'Peterson Space Force Base',
#   'location': 'Colorado Springs',
#   'state_or_area': 'Colorado',
#   'commanding_organization': 'US Space Force',
#   'host_wing_or_primary_unit': '302nd Airlift Wing',
#   'primary_missions_and_units': 'US Space Force instillation hosting the302nd Airlift Wingoperate theC-130H Hercules.[151]',
#   'latitude': 38.82361,
#   'longitude': -104.695},
#  {'name': 'Pittsburgh International Airport Air Reserve Station',
#   'location': 'Pittsburgh',
#   'state_or_area': 'Pennsylvania',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '911th Airlift Wing',
#   'primary_missions_and_units': "Airfield shared withPittsburgh International Airport. The911th Airlift Wingoperates theC-17A Globemaster IIIand thePennsylvania Air National Guard's171st Air Refueling WingtheKC-135R Stratotanker.[152][153]",
#   'latitude': 40.4945806,
#   'longitude': -80.215475},
#  {'name': 'Portland Air National Guard Base',
#   'location': 'Portland',
#   'state_or_area': 'Oregon',
#   'commanding_organization': 'Oregon Air National Guard',
#   'host_wing_or_primary_unit': '142nd Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withPortland International Airport. The142nd Fighter Wingoperates theF-15C/D Eagleair superiority fighter, also home to the125th Special Tactics Squadron.[154]',
#   'latitude': 45.58222,
#   'longitude': -122.58972},
#  {'name': 'Quonset Point Air National Guard Station',
#   'location': 'North Kingstown',
#   'state_or_area': 'Rhode Island',
#   'commanding_organization': 'Rhode Island Air National Guard',
#   'host_wing_or_primary_unit': '143rd Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withQuonset State Airport. The143rd Airlift Wingoperates theC-130J Super Hercules, also home to the 102nd Network Warfare Squadron.[155]',
#   'latitude': 41.59722,
#   'longitude': -71.41222},
#  {'name': 'Reno Air National Guard Base',
#   'location': 'Reno',
#   'state_or_area': 'Nevada',
#   'commanding_organization': 'Nevada Air National Guard',
#   'host_wing_or_primary_unit': '152nd Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withReno-Tahoe International Airport. The152nd Airlift Wingoperates theC-130H Hercules.[156]',
#   'latitude': 39.49917,
#   'longitude': -119.76806},
#  {'name': 'Rickenbacker Air National Guard Base',
#   'location': 'Columbus',
#   'state_or_area': 'Ohio',
#   'commanding_organization': 'Ohio Air National Guard',
#   'host_wing_or_primary_unit': '121st Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withRickenbacker International Airport. The121st Air Refueling Wingoperates theKC-135R Stratotanker.[157]',
#   'latitude': 39.81361,
#   'longitude': -82.94667},
#  {'name': 'Roland R. Wright Air National Guard Base',
#   'location': 'Salt Lake City',
#   'state_or_area': 'Utah',
#   'commanding_organization': 'Utah Air National Guard',
#   'host_wing_or_primary_unit': '151st Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withSalt Lake City International Airport. The151st Air Refueling Wingoperates theKC-135R Stratotanker.[158]',
#   'latitude': 40.78833,
#   'longitude': -111.97778},
#  {'name': 'Rosecrans Air National Guard Base',
#   'location': 'St. Joseph',
#   'state_or_area': 'Missouri',
#   'commanding_organization': 'Missouri Air National Guard',
#   'host_wing_or_primary_unit': '139th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withRosecrans Memorial Airport. The139th Airlift Wingoperates theC-130H Hercules.[159]',
#   'latitude': 39.77194,
#   'longitude': -94.9097056},
#  {'name': 'San Diego Air National Guard Station',
#   'location': 'San Diego',
#   'state_or_area': 'California',
#   'commanding_organization': 'California Air National Guard',
#   'host_wing_or_primary_unit': '147th Combat Communications Squadron',
#   'primary_missions_and_units': 'Non-flying installation home to a Geographically Separate Unit of the195th Wing.[160]',
#   'latitude': 32.83611,
#   'longitude': -117.16056},
#  {'name': 'Savannah Air National Guard Base',
#   'location': 'Savannah',
#   'state_or_area': 'Georgia',
#   'commanding_organization': 'Georgia Air National Guard',
#   'host_wing_or_primary_unit': '165th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withSavannah/Hilton Head International Airport. The165th Airlift Wingoperates theC-130H Hercules, also home to the Air Dominance Center.[161]',
#   'latitude': 32.1275,
#   'longitude': -81.20194},
#  {'name': 'Schriever Space Force Base',
#   'location': 'Colorado Springs',
#   'state_or_area': 'Colorado',
#   'commanding_organization': 'US Space Force',
#   'host_wing_or_primary_unit': '310th Space Wing',
#   'primary_missions_and_units': "US Space Forceinstallation, hosting the USAF's the Air Force Reserves310th Space Wing.[162]",
#   'latitude': 38.80333,
#   'longitude': -104.52556},
#  {'name': 'Selfridge Air National Guard Base',
#   'location': 'Mount Clemens',
#   'state_or_area': 'Michigan',
#   'commanding_organization': 'Michigan Air National Guard',
#   'host_wing_or_primary_unit': '127th Wing',
#   'primary_missions_and_units': 'The127th Wingoperates theKC-135R StratotankerandA-10 Thunderbolt II.[163]',
#   'latitude': 42.60833,
#   'longitude': -82.83556},
#  {'name': 'Sepulveda Air National Guard Station',
#   'location': 'Van Nuys',
#   'state_or_area': 'California',
#   'commanding_organization': 'California National Guard',
#   'host_wing_or_primary_unit': '261st Cyber Operations Squadron',
#   'primary_missions_and_units': 'Non-flying installation. Geographically Separate Unit of the195th Wing.[164]',
#   'latitude': 34.185944,
#   'longitude': -118.48},
#  {'name': 'Shepherd Field Air National Guard Base',
#   'location': 'Martinsburg',
#   'state_or_area': 'West Virginia',
#   'commanding_organization': 'West Virginia Air National Guard',
#   'host_wing_or_primary_unit': '167th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withEastern West Virginia Regional Airport. The167th Airlift Wingoperates theC-17A Globemaster III.[165]',
#   'latitude': 39.40194,
#   'longitude': -77.98444},
#  {'name': 'Sioux City Air National Guard Base',
#   'location': 'Sioux City',
#   'state_or_area': 'Iowa',
#   'commanding_organization': 'Iowa Air National Guard',
#   'host_wing_or_primary_unit': '185th Air Refueling Wing',
#   'primary_missions_and_units': 'Airfield shared withSioux Gateway Airport. The185th Air Refueling Wingoperates theKC-135R Stratotanker.[166]',
#   'latitude': 42.39833,
#   'longitude': -96.37194},
#  {'name': 'South Portland Air National Guard Station',
#   'location': 'South Portland',
#   'state_or_area': 'Maine',
#   'commanding_organization': 'Maine Air National Guard',
#   'host_wing_or_primary_unit': 'N/A',
#   'primary_missions_and_units': 'Non-flying installation. Home to the 265th Combat Communications Squadron and 243rd Engineering and Installation Squadron, both Geographically Separate Units of the101st Air Refueling Wing.[167]',
#   'latitude': 43.633583,
#   'longitude': -70.316306},
#  {'name': 'Springfield Air National Guard Base',
#   'location': 'Springfield',
#   'state_or_area': 'Ohio',
#   'commanding_organization': 'Ohio Air National Guard',
#   'host_wing_or_primary_unit': '178th Wing',
#   'primary_missions_and_units': 'Airfield shared withSpringfield-Beckley Municipal Airport. The178th Wingoperates theMQ-9A Predator.[168]',
#   'latitude': 39.84028,
#   'longitude': -83.84028},
#  {'name': 'Stewart Air National Guard Base',
#   'location': 'Newburgh',
#   'state_or_area': 'New York',
#   'commanding_organization': 'New York Air National Guard',
#   'host_wing_or_primary_unit': '105th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withStewart International Airport. The105th Airlift Wingoperates theC-17A Globemaster III.[169]',
#   'latitude': 41.50417,
#   'longitude': -74.10472},
#  {'name': 'Stratton Air National Guard Base',
#   'location': 'Schenectady',
#   'state_or_area': 'New York',
#   'commanding_organization': 'New York Air National Guard',
#   'host_wing_or_primary_unit': '109th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withSchenectady County Airport. The109th Airlift Wingis the only Air Force unit equipped with ski-equippedLC-130H Herculesfor Arctic ice/snow landing missions in support of theNational Science Foundation.[170]',
#   'latitude': 42.8525,
#   'longitude': -73.9225},
#  {'name': 'Sumpter Smith Air National Guard Base',
#   'location': 'Birmingham',
#   'state_or_area': 'Alabama',
#   'commanding_organization': 'Alabama Air National Guard',
#   'host_wing_or_primary_unit': '117th Air Refueling Wing',
#   'primary_missions_and_units': 'The117th Air Refueling Wingoperates theKC-135R Stratotanker.[171]',
#   'latitude': 33.56389,
#   'longitude': -86.75222},
#  {'name': 'Toledo Air National Guard Base',
#   'location': 'Toledo',
#   'state_or_area': 'Ohio',
#   'commanding_organization': 'Ohio Air National Guard',
#   'host_wing_or_primary_unit': '180th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withToledo Express Airport. The180th Fighter Wingoperates theF-16C Fighting Falconmulti-role fighter.[172]',
#   'latitude': 41.586806,
#   'longitude': -83.807833},
#  {'name': 'Truax Field Air National Guard Base',
#   'location': 'Madison',
#   'state_or_area': 'Wisconsin',
#   'commanding_organization': 'Wisconsin Air National Guard',
#   'host_wing_or_primary_unit': '115th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withDane County Regional Airport. The115th Fighter Wingoperates theF-16C Fighting Falconmulti-role fighter.[173]In 2020, Traux Field ANG base was announced to have been selected as a base for theF-35A Lightning II, which would replace the F-16C.[140]',
#   'latitude': 43.13972,
#   'longitude': -89.3375},
#  {'name': 'Tulsa Air National Guard Base',
#   'location': 'Tulsa',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Oklahoma Air National Guard',
#   'host_wing_or_primary_unit': '138th Fighter Wing',
#   'primary_missions_and_units': 'Airfield shared withTulsa International Airport. The138th Fighter Wingoperates theF-16C Fighting Falconmulti-role fighter.[174]',
#   'latitude': 36.19833,
#   'longitude': -95.88806},
#  {'name': 'Volk Field Air National Guard Base',
#   'location': 'New Lisbon',
#   'state_or_area': 'Wisconsin',
#   'commanding_organization': 'Wisconsin Air National Guard',
#   'host_wing_or_primary_unit': 'Volk Field Combat Readiness Training Center',
#   'primary_missions_and_units': 'Home of one of four Air National Guard Combat Readiness Training Centers.[175]',
#   'latitude': 43.93639,
#   'longitude': -90.25972},
#  {'name': 'Volunteer Air National Guard Station',
#   'location': 'Chattanooga',
#   'state_or_area': 'Tennessee',
#   'commanding_organization': 'Tennessee Air National Guard',
#   'host_wing_or_primary_unit': '241st Engineering Installation Squadron',
#   'primary_missions_and_units': 'A non-flying installation hosting a Geographically Separate Unit of the134th Air Refueling Wing.[176][177]',
#   'latitude': 35.0735861,
#   'longitude': -85.1635},
#  {'name': 'Warfield Air National Guard Base',
#   'location': 'Middle River',
#   'state_or_area': 'Maryland',
#   'commanding_organization': 'Maryland Air National Guard',
#   'host_wing_or_primary_unit': '175th Wing',
#   'primary_missions_and_units': 'Airfield shared withMartin State Airport. The175th Wingoperates theA-10C Thunderbolt II.[178]',
#   'latitude': 39.3256611,
#   'longitude': -76.4137639},
#  {'name': 'Westover Air Reserve Base',
#   'location': 'Chicopee',
#   'state_or_area': 'Massachusetts',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '439th Airlift Wing',
#   'primary_missions_and_units': 'The439th Airlift Wingoperates theC-5M Super Galaxy.[179]',
#   'latitude': 42.19389,
#   'longitude': -72.53472},
#  {'name': 'Will Rogers Air National Guard Base',
#   'location': 'Oklahoma City',
#   'state_or_area': 'Oklahoma',
#   'commanding_organization': 'Oklahoma Air National Guard',
#   'host_wing_or_primary_unit': '137th Special Operations Wing',
#   'primary_missions_and_units': 'Airfield shared withWill Rogers World Airport. The137th Special Operations Wingoperates theMC-12W Libertyin theIntelligence, Surveillance & Reconnaissance(ISR) role.[180]',
#   'latitude': 35.39306,
#   'longitude': -97.60083},
#  {'name': 'Wyoming Air National Guard Base',
#   'location': 'Cheyenne',
#   'state_or_area': 'Wyoming',
#   'commanding_organization': 'Wyoming Air National Guard',
#   'host_wing_or_primary_unit': '153d Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withCheyenne Regional Airport. Operates theC-130H Herculesin the airlift andaerial firefightingroles. Also homes to the243rd Air Traffic Control Squadron.[181]',
#   'latitude': 41.16139,
#   'longitude': -104.81944},
#  {'name': 'Youngstown Air Reserve Station',
#   'location': 'Youngstown',
#   'state_or_area': 'Ohio',
#   'commanding_organization': 'Air Force Reserve Command',
#   'host_wing_or_primary_unit': '910th Airlift Wing',
#   'primary_missions_and_units': 'Airfield shared withYoungstown-Warren Regional Airport. The910th Airlift Wingoperates theC-130H Herculesin theaerial sprayrole.[182]',
#   'latitude': 41.2607333,
#   'longitude': -80.6790944}]

# %%
# Insert all usa sightings into Mongo DB collection
airforce_bases.insert_many(airforce_bases_dict)
# Out:
# InsertManyResult([ObjectId('6689ab0dfddd06dc92d892ff'), ObjectId('6689ab0dfddd06dc92d89300'), ObjectId('6689ab0dfddd06dc92d89301'), ObjectId('6689ab0dfddd06dc92d89302'), ObjectId('6689ab0dfddd06dc92d89303'), ObjectId('6689ab0dfddd06dc92d89304'), ObjectId('6689ab0dfddd06dc92d89305'), ObjectId('6689ab0dfddd06dc92d89306'), ObjectId('6689ab0dfddd06dc92d89307'), ObjectId('6689ab0dfddd06dc92d89308'), ObjectId('6689ab0dfddd06dc92d89309'), ObjectId('6689ab0dfddd06dc92d8930a'), ObjectId('6689ab0dfddd06dc92d8930b'), ObjectId('6689ab0dfddd06dc92d8930c'), ObjectId('6689ab0dfddd06dc92d8930d'), ObjectId('6689ab0dfddd06dc92d8930e'), ObjectId('6689ab0dfddd06dc92d8930f'), ObjectId('6689ab0dfddd06dc92d89310'), ObjectId('6689ab0dfddd06dc92d89311'), ObjectId('6689ab0dfddd06dc92d89312'), ObjectId('6689ab0dfddd06dc92d89313'), ObjectId('6689ab0dfddd06dc92d89314'), ObjectId('6689ab0dfddd06dc92d89315'), ObjectId('6689ab0dfddd06dc92d89316'), ObjectId('6689ab0dfddd06dc92d89317'), ObjectId('6689ab0dfddd06dc92d89318'), ObjectId('6689ab0dfddd06dc92d89319'), ObjectId('6689ab0dfddd06dc92d8931a'), ObjectId('6689ab0dfddd06dc92d8931b'), ObjectId('6689ab0dfddd06dc92d8931c'), ObjectId('6689ab0dfddd06dc92d8931d'), ObjectId('6689ab0dfddd06dc92d8931e'), ObjectId('6689ab0dfddd06dc92d8931f'), ObjectId('6689ab0dfddd06dc92d89320'), ObjectId('6689ab0dfddd06dc92d89321'), ObjectId('6689ab0dfddd06dc92d89322'), ObjectId('6689ab0dfddd06dc92d89323'), ObjectId('6689ab0dfddd06dc92d89324'), ObjectId('6689ab0dfddd06dc92d89325'), ObjectId('6689ab0dfddd06dc92d89326'), ObjectId('6689ab0dfddd06dc92d89327'), ObjectId('6689ab0dfddd06dc92d89328'), ObjectId('6689ab0dfddd06dc92d89329'), ObjectId('6689ab0dfddd06dc92d8932a'), ObjectId('6689ab0dfddd06dc92d8932b'), ObjectId('6689ab0dfddd06dc92d8932c'), ObjectId('6689ab0dfddd06dc92d8932d'), ObjectId('6689ab0dfddd06dc92d8932e'), ObjectId('6689ab0dfddd06dc92d8932f'), ObjectId('6689ab0dfddd06dc92d89330'), ObjectId('6689ab0dfddd06dc92d89331'), ObjectId('6689ab0dfddd06dc92d89332'), ObjectId('6689ab0dfddd06dc92d89333'), ObjectId('6689ab0dfddd06dc92d89334'), ObjectId('6689ab0dfddd06dc92d89335'), ObjectId('6689ab0dfddd06dc92d89336'), ObjectId('6689ab0dfddd06dc92d89337'), ObjectId('6689ab0dfddd06dc92d89338'), ObjectId('6689ab0dfddd06dc92d89339'), ObjectId('6689ab0dfddd06dc92d8933a'), ObjectId('6689ab0dfddd06dc92d8933b'), ObjectId('6689ab0dfddd06dc92d8933c'), ObjectId('6689ab0dfddd06dc92d8933d'), ObjectId('6689ab0dfddd06dc92d8933e'), ObjectId('6689ab0dfddd06dc92d8933f'), ObjectId('6689ab0dfddd06dc92d89340'), ObjectId('6689ab0dfddd06dc92d89341'), ObjectId('6689ab0dfddd06dc92d89342'), ObjectId('6689ab0dfddd06dc92d89343'), ObjectId('6689ab0dfddd06dc92d89344'), ObjectId('6689ab0dfddd06dc92d89345'), ObjectId('6689ab0dfddd06dc92d89346'), ObjectId('6689ab0dfddd06dc92d89347'), ObjectId('6689ab0dfddd06dc92d89348'), ObjectId('6689ab0dfddd06dc92d89349'), ObjectId('6689ab0dfddd06dc92d8934a'), ObjectId('6689ab0dfddd06dc92d8934b'), ObjectId('6689ab0dfddd06dc92d8934c'), ObjectId('6689ab0dfddd06dc92d8934d'), ObjectId('6689ab0dfddd06dc92d8934e'), ObjectId('6689ab0dfddd06dc92d8934f'), ObjectId('6689ab0dfddd06dc92d89350'), ObjectId('6689ab0dfddd06dc92d89351'), ObjectId('6689ab0dfddd06dc92d89352'), ObjectId('6689ab0dfddd06dc92d89353'), ObjectId('6689ab0dfddd06dc92d89354'), ObjectId('6689ab0dfddd06dc92d89355'), ObjectId('6689ab0dfddd06dc92d89356'), ObjectId('6689ab0dfddd06dc92d89357'), ObjectId('6689ab0dfddd06dc92d89358'), ObjectId('6689ab0dfddd06dc92d89359'), ObjectId('6689ab0dfddd06dc92d8935a'), ObjectId('6689ab0dfddd06dc92d8935b'), ObjectId('6689ab0dfddd06dc92d8935c'), ObjectId('6689ab0dfddd06dc92d8935d'), ObjectId('6689ab0dfddd06dc92d8935e'), ObjectId('6689ab0dfddd06dc92d8935f'), ObjectId('6689ab0dfddd06dc92d89360'), ObjectId('6689ab0dfddd06dc92d89361'), ObjectId('6689ab0dfddd06dc92d89362'), ObjectId('6689ab0dfddd06dc92d89363'), ObjectId('6689ab0dfddd06dc92d89364'), ObjectId('6689ab0dfddd06dc92d89365'), ObjectId('6689ab0dfddd06dc92d89366'), ObjectId('6689ab0dfddd06dc92d8 ...
