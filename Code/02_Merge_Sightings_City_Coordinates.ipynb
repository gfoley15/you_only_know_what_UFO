# %%
import pandas as pd
from pathlib import Path
import numpy as np
import time
import requests

# %%
sightings_file = pd.read_csv('../Output/usa_sightings_df_.csv')
complete_file = pd.read_csv('../Output//city Data Complete.csv')

# %%
sightings_df = pd.DataFrame(sightings_file)
complete_df = pd.DataFrame(complete_file)

# %%
complete_df1=complete_df.drop(['Unnamed: 0'], axis = 1)

# %%
complete_df1  =complete_df1.rename(columns={'City': 'CITY'})
complete_df1
# Out:
#                CITY      Lat       Lng
# 0          Cranston  41.7798  -71.4373
# 1          Key West  24.5557  -81.7826
# 2     Oklahoma City  35.4676  -97.5164
# 3     Valley Stream  40.6643  -73.7085
# 4      Jacksonville  30.3322  -81.6556
# ...             ...      ...       ...
# 9108    Scottsville  36.7534  -86.1905
# 9109         Tehama  40.1332 -122.3011
# 9110          Wirtz  37.0765  -79.8895
# 9111      Lame Deer  45.6231 -106.6667
# 9112     Warr Acres  35.5226  -97.6189
#
# [9113 rows x 3 columns]

# %%
#performing right join.
city_complete_df = pd.merge(sightings_df,  
                      complete_df1,  
                      on ='CITY', 
                      how ='right')

# %%
city_complete_df.head(20)
# Out:
#     SIGHTING_ID OCCURRED_DATE      CITY STATE COUNTRY     SHAPE  \
# 0           1.0    2024-06-20  Cranston    RI     USA     Flash
# 1       10490.0    2021-06-17  Cranston    RI     USA    Circle
# 2       18342.0    2019-12-19  Cranston    RI     USA  Fireball
# 3       21138.0    2019-07-15  Cranston    RI     USA     Other
# 4       21951.0    2019-05-25  Cranston    RI     USA    Circle
# 5       22817.0    2019-03-16  Cranston    RI     USA    Sphere
# 6       23160.0    2019-01-26  Cranston    RI     USA     Other
# 7       24829.0    2018-07-21  Cranston    RI     USA    Circle
# 8       27952.0    2017-09-26  Cranston    RI     USA    Circle
# 9       30367.0    2017-03-20  Cranston    RI     USA     Light
# 10      34297.0    2016-07-03  Cranston    RI     USA      Oval
# 11      34430.0    2016-06-25  Cranston    RI     USA  Cylinder
# 12      34602.0    2016-06-11  Cranston    RI     USA       Orb
# 13      36769.0    2015-12-24  Cranston    RI     USA      Oval
# ...

# %%
# Convert SIGHTING_ID and YEAR to integers
city_complete_df['SIGHTING_ID'] = city_complete_df['SIGHTING_ID'].fillna(0).astype(int)
city_complete_df['YEAR'] = city_complete_df['YEAR'].fillna(0).astype(int)

# %%
# Remove NaN values from Lat and Lng columns
city_complete_df['Lat'] = city_complete_df['Lat'].fillna(0.0) 
city_complete_df['Lng'] = city_complete_df['Lng'].fillna(0.0)

# %%
# Drop rows where both Lat and Lng are NaN
city_complete_df = city_complete_df.dropna(subset=['Lat', 'Lng'])
city_complete_df = city_complete_df.dropna(subset=['CITYSTATE'])

# %%
# Round Lat / Lng for processing performance improvement in mapping
city_complete_df['Lat'] = city_complete_df['Lat'].round(2)
city_complete_df['Lng'] = city_complete_df['Lng'].round(2)

# %%
# Sort dataframe
city_complete_df = city_complete_df.sort_values(by=["OCCURRED_DATE"], ascending=False)

# %%
# Removing duplicates
city_complete_df = city_complete_df.drop_duplicates()

# %%
city_complete_df
# Out:
#        SIGHTING_ID OCCURRED_DATE           CITY STATE COUNTRY     SHAPE  \
# 0                1    2024-06-20       Cranston    RI     USA     Flash
# 14               2    2024-06-20       Key West    FL     USA     Light
# 47463            3    2024-06-20  Oklahoma City    OK     USA     Light
# 94               4    2024-06-19  Valley Stream    NY     USA    Sphere
# 101              5    2024-06-19   Jacksonville    FL     USA  Triangle
# ...            ...           ...            ...   ...     ...       ...
# 34650        50221    2014-02-18         Tucson    AZ     USA       Orb
# 9338         50219    2014-02-18        Houston    TX     USA      Disk
# 24507        50222    2014-02-18      Fallbrook    CA     USA       Orb
# 22963        50223    2014-02-18       Chandler    IN     USA     Other
# 63253        50226    2014-02-18      Lame Deer    MT     USA   Unknown
#
#                                                  SUMMARY  YEAR  \
# ...

# %%
city_complete_df.to_csv('../Output/City_latlng_merge.csv')
